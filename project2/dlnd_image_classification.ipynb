# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    lower_bound = 0
    higher_bound = 1
    max_val = np.max(x)
    min_val = np.min(x)
    return min_val + (higher_bound - lower_bound) * (x - min_val) / (max_val - min_val)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
label_map = {i : i for i in range(0, 10)}
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    one_hot = np.zeros((len(x), len(label_map)))
    for i in range(len(x)):
        one_hot[i, label_map[x[i]]] = 1
    return one_hot


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, [None, *image_shape], name = "x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, [None, n_classes], name = "y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name = "keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    depth = x_tensor.get_shape().as_list()[-1]
    weight = tf.Variable(tf.truncated_normal([*conv_ksize, depth, conv_num_outputs], stddev = 0.1), name = "conv_weights")
    bias = tf.Variable(tf.truncated_normal([conv_num_outputs], stddev = 0.1), name = "conv_bias")
    layer = tf.nn.conv2d(x_tensor, weight, strides = [1, *conv_strides, 1], padding = "SAME")
    layer = tf.nn.bias_add(layer, bias)
    layer = tf.nn.elu(layer) # that's not a typo, I've intended to use Exponential Linear Unit :)
    layer = tf.nn.max_pool(layer, [1, *pool_ksize, 1], [1, *pool_strides, 1], padding = "SAME")    
    return layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    b, h, w, d = x_tensor.get_shape().as_list()
    return tf.reshape(x_tensor, [-1, h * w * d])

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weight = tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[1], num_outputs], stddev = 0.1), name = "conn_weight")
    bias = tf.Variable(tf.truncated_normal([num_outputs], stddev = 0.1), name = "conn_bias")
    layer = tf.add(tf.matmul(x_tensor, weight), bias)
    layer = tf.nn.relu(layer)
    return layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weight = tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[1], num_outputs], stddev = 0.1), name = "output_weight")
    bias = tf.Variable(tf.truncated_normal([num_outputs], stddev = 0.1), name = "output_bias")
    return tf.add(tf.matmul(x_tensor, weight), bias)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    layer = conv2d_maxpool(x, 16, [8, 8], [1, 1], [2, 2], [2, 2])
    layer = conv2d_maxpool(layer, 32, [5, 5], [1, 1], [2, 2], [2, 2])
    layer = conv2d_maxpool(layer, 64, [3, 3], [1, 1], [2, 2], [2, 2])

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    layer = flatten(layer)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    layer = fully_conn(layer, 32)
    layer = tf.nn.dropout(layer, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    layer = output(layer, 10)
    
    # TODO: return output
    return layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict = {x: feature_batch, y: label_batch, keep_prob: keep_probability})
    

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict = {x: feature_batch, y: label_batch, keep_prob: 1.0})
    acc = session.run(accuracy, feed_dict = {x: valid_features, y: valid_labels, keep_prob: 1.0})
    print("loss is {:.6f}, validation accuracy is {:.6f}".format(loss, acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 200
batch_size = 4096
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  loss is 2.289852, validation accuracy is 0.122400
# Epoch  2, CIFAR-10 Batch 1:  loss is 2.270296, validation accuracy is 0.146000
# Epoch  3, CIFAR-10 Batch 1:  loss is 2.207223, validation accuracy is 0.218600
# Epoch  4, CIFAR-10 Batch 1:  loss is 2.173422, validation accuracy is 0.214800
# Epoch  5, CIFAR-10 Batch 1:  loss is 2.117258, validation accuracy is 0.238400
# Epoch  6, CIFAR-10 Batch 1:  loss is 2.071276, validation accuracy is 0.240600
# Epoch  7, CIFAR-10 Batch 1:  loss is 2.036271, validation accuracy is 0.246400
# Epoch  8, CIFAR-10 Batch 1:  loss is 2.010497, validation accuracy is 0.266800
# Epoch  9, CIFAR-10 Batch 1:  loss is 1.984146, validation accuracy is 0.295000
# Epoch 10, CIFAR-10 Batch 1:  loss is 1.940932, validation accuracy is 0.309600
# Epoch 11, CIFAR-10 Batch 1:  loss is 1.933551, validation accuracy is 0.316200
# Epoch 12, CIFAR-10 Batch 1:  loss is 1.915516, validation accuracy is 0.317200
# Epoch 13, CIFAR-10 Batch 1:  loss is 1.878878, validation accuracy is 0.325200
# Epoch 14, CIFAR-10 Batch 1:  loss is 1.864865, validation accuracy is 0.336800
# Epoch 15, CIFAR-10 Batch 1:  loss is 1.849141, validation accuracy is 0.348200
# Epoch 16, CIFAR-10 Batch 1:  loss is 1.807635, validation accuracy is 0.361400
# Epoch 17, CIFAR-10 Batch 1:  loss is 1.782044, validation accuracy is 0.373200
# Epoch 18, CIFAR-10 Batch 1:  loss is 1.778896, validation accuracy is 0.378000
# Epoch 19, CIFAR-10 Batch 1:  loss is 1.751074, validation accuracy is 0.378800
# Epoch 20, CIFAR-10 Batch 1:  loss is 1.716024, validation accuracy is 0.374800
# Epoch 21, CIFAR-10 Batch 1:  loss is 1.689517, validation accuracy is 0.392600
# Epoch 22, CIFAR-10 Batch 1:  loss is 1.674762, validation accuracy is 0.391000
# Epoch 23, CIFAR-10 Batch 1:  loss is 1.657640, validation accuracy is 0.396400
# Epoch 24, CIFAR-10 Batch 1:  loss is 1.626333, validation accuracy is 0.413200
# Epoch 25, CIFAR-10 Batch 1:  loss is 1.596909, validation accuracy is 0.412800
# Epoch 26, CIFAR-10 Batch 1:  loss is 1.589281, validation accuracy is 0.411000
# Epoch 27, CIFAR-10 Batch 1:  loss is 1.571289, validation accuracy is 0.415800
# Epoch 28, CIFAR-10 Batch 1:  loss is 1.547783, validation accuracy is 0.428600
# Epoch 29, CIFAR-10 Batch 1:  loss is 1.519151, validation accuracy is 0.432000
# Epoch 30, CIFAR-10 Batch 1:  loss is 1.496868, validation accuracy is 0.428600
# Epoch 31, CIFAR-10 Batch 1:  loss is 1.478724, validation accuracy is 0.435600
# Epoch 32, CIFAR-10 Batch 1:  loss is 1.461669, validation accuracy is 0.436000
# Epoch 33, CIFAR-10 Batch 1:  loss is 1.449456, validation accuracy is 0.439000
# Epoch 34, CIFAR-10 Batch 1:  loss is 1.427685, validation accuracy is 0.442800
# Epoch 35, CIFAR-10 Batch 1:  loss is 1.405542, validation accuracy is 0.449200
# Epoch 36, CIFAR-10 Batch 1:  loss is 1.380289, validation accuracy is 0.457600
# Epoch 37, CIFAR-10 Batch 1:  loss is 1.364412, validation accuracy is 0.462000
# Epoch 38, CIFAR-10 Batch 1:  loss is 1.350951, validation accuracy is 0.462800
# Epoch 39, CIFAR-10 Batch 1:  loss is 1.339765, validation accuracy is 0.459800
# Epoch 40, CIFAR-10 Batch 1:  loss is 1.328103, validation accuracy is 0.462800
# Epoch 41, CIFAR-10 Batch 1:  loss is 1.301685, validation accuracy is 0.468400
# Epoch 42, CIFAR-10 Batch 1:  loss is 1.276680, validation accuracy is 0.476000
# Epoch 43, CIFAR-10 Batch 1:  loss is 1.266161, validation accuracy is 0.474000
# Epoch 44, CIFAR-10 Batch 1:  loss is 1.270437, validation accuracy is 0.474800
# Epoch 45, CIFAR-10 Batch 1:  loss is 1.238891, validation accuracy is 0.485200
# Epoch 46, CIFAR-10 Batch 1:  loss is 1.226406, validation accuracy is 0.480800
# Epoch 47, CIFAR-10 Batch 1:  loss is 1.220020, validation accuracy is 0.484800
# Epoch 48, CIFAR-10 Batch 1:  loss is 1.196513, validation accuracy is 0.489200
# Epoch 49, CIFAR-10 Batch 1:  loss is 1.182504, validation accuracy is 0.488600
# Epoch 50, CIFAR-10 Batch 1:  loss is 1.176431, validation accuracy is 0.492800
# Epoch 51, CIFAR-10 Batch 1:  loss is 1.167438, validation accuracy is 0.489400
# Epoch 52, CIFAR-10 Batch 1:  loss is 1.143370, validation accuracy is 0.490800
# Epoch 53, CIFAR-10 Batch 1:  loss is 1.126246, validation accuracy is 0.492800
# Epoch 54, CIFAR-10 Batch 1:  loss is 1.106898, validation accuracy is 0.492000
# Epoch 55, CIFAR-10 Batch 1:  loss is 1.106174, validation accuracy is 0.492600
# Epoch 56, CIFAR-10 Batch 1:  loss is 1.114133, validation accuracy is 0.495400
# Epoch 57, CIFAR-10 Batch 1:  loss is 1.096223, validation accuracy is 0.489800
# Epoch 58, CIFAR-10 Batch 1:  loss is 1.083759, validation accuracy is 0.490400
# Epoch 59, CIFAR-10 Batch 1:  loss is 1.074658, validation accuracy is 0.498000
# Epoch 60, CIFAR-10 Batch 1:  loss is 1.072431, validation accuracy is 0.497200
# Epoch 61, CIFAR-10 Batch 1:  loss is 1.069994, validation accuracy is 0.493600
# Epoch 62, CIFAR-10 Batch 1:  loss is 1.047124, validation accuracy is 0.502600
# Epoch 63, CIFAR-10 Batch 1:  loss is 1.014644, validation accuracy is 0.499400
# Epoch 64, CIFAR-10 Batch 1:  loss is 0.997110, validation accuracy is 0.505400
# Epoch 65, CIFAR-10 Batch 1:  loss is 1.004827, validation accuracy is 0.504200
# Epoch 66, CIFAR-10 Batch 1:  loss is 0.991894, validation accuracy is 0.505400
# Epoch 67, CIFAR-10 Batch 1:  loss is 0.980175, validation accuracy is 0.507600
# Epoch 68, CIFAR-10 Batch 1:  loss is 0.967728, validation accuracy is 0.512600
# Epoch 69, CIFAR-10 Batch 1:  loss is 0.968629, validation accuracy is 0.508200
# Epoch 70, CIFAR-10 Batch 1:  loss is 0.951048, validation accuracy is 0.514400
# Epoch 71, CIFAR-10 Batch 1:  loss is 0.939060, validation accuracy is 0.510000
# Epoch 72, CIFAR-10 Batch 1:  loss is 0.937880, validation accuracy is 0.511800
# Epoch 73, CIFAR-10 Batch 1:  loss is 0.942087, validation accuracy is 0.505800
# Epoch 74, CIFAR-10 Batch 1:  loss is 0.922253, validation accuracy is 0.507000
# Epoch 75, CIFAR-10 Batch 1:  loss is 0.932611, validation accuracy is 0.505800
# Epoch 76, CIFAR-10 Batch 1:  loss is 0.912868, validation accuracy is 0.516400
# Epoch 77, CIFAR-10 Batch 1:  loss is 0.882179, validation accuracy is 0.515400
# Epoch 78, CIFAR-10 Batch 1:  loss is 0.885291, validation accuracy is 0.507400
# Epoch 79, CIFAR-10 Batch 1:  loss is 0.881445, validation accuracy is 0.516200
# Epoch 80, CIFAR-10 Batch 1:  loss is 0.871588, validation accuracy is 0.518200
# Epoch 81, CIFAR-10 Batch 1:  loss is 0.868123, validation accuracy is 0.519400
# Epoch 82, CIFAR-10 Batch 1:  loss is 0.851515, validation accuracy is 0.520200
# Epoch 83, CIFAR-10 Batch 1:  loss is 0.845199, validation accuracy is 0.516800
# Epoch 84, CIFAR-10 Batch 1:  loss is 0.834961, validation accuracy is 0.525200
# Epoch 85, CIFAR-10 Batch 1:  loss is 0.824115, validation accuracy is 0.522800
# Epoch 86, CIFAR-10 Batch 1:  loss is 0.816424, validation accuracy is 0.525600
# Epoch 87, CIFAR-10 Batch 1:  loss is 0.809131, validation accuracy is 0.523600
# Epoch 88, CIFAR-10 Batch 1:  loss is 0.790538, validation accuracy is 0.528000
# Epoch 89, CIFAR-10 Batch 1:  loss is 0.789325, validation accuracy is 0.526800
# Epoch 90, CIFAR-10 Batch 1:  loss is 0.794646, validation accuracy is 0.526000
# Epoch 91, CIFAR-10 Batch 1:  loss is 0.776052, validation accuracy is 0.530200
# Epoch 92, CIFAR-10 Batch 1:  loss is 0.774682, validation accuracy is 0.526200
# Epoch 93, CIFAR-10 Batch 1:  loss is 0.762711, validation accuracy is 0.528800
# Epoch 94, CIFAR-10 Batch 1:  loss is 0.749431, validation accuracy is 0.528400
# Epoch 95, CIFAR-10 Batch 1:  loss is 0.743388, validation accuracy is 0.534200
# Epoch 96, CIFAR-10 Batch 1:  loss is 0.744438, validation accuracy is 0.529800
# Epoch 97, CIFAR-10 Batch 1:  loss is 0.742490, validation accuracy is 0.527200
# Epoch 98, CIFAR-10 Batch 1:  loss is 0.723824, validation accuracy is 0.531000
# Epoch 99, CIFAR-10 Batch 1:  loss is 0.728737, validation accuracy is 0.532400
# Epoch 100, CIFAR-10 Batch 1:  loss is 0.723977, validation accuracy is 0.528800
# Epoch 101, CIFAR-10 Batch 1:  loss is 0.706674, validation accuracy is 0.531200
# Epoch 102, CIFAR-10 Batch 1:  loss is 0.702358, validation accuracy is 0.534200
# Epoch 103, CIFAR-10 Batch 1:  loss is 0.699547, validation accuracy is 0.523200
# Epoch 104, CIFAR-10 Batch 1:  loss is 0.681336, validation accuracy is 0.533600
# Epoch 105, CIFAR-10 Batch 1:  loss is 0.679275, validation accuracy is 0.537400
# Epoch 106, CIFAR-10 Batch 1:  loss is 0.675204, validation accuracy is 0.535400
# Epoch 107, CIFAR-10 Batch 1:  loss is 0.668436, validation accuracy is 0.538400
# Epoch 108, CIFAR-10 Batch 1:  loss is 0.655882, validation accuracy is 0.537600
# Epoch 109, CIFAR-10 Batch 1:  loss is 0.643512, validation accuracy is 0.542200
# Epoch 110, CIFAR-10 Batch 1:  loss is 0.637299, validation accuracy is 0.540600
# Epoch 111, CIFAR-10 Batch 1:  loss is 0.648578, validation accuracy is 0.532200
# Epoch 112, CIFAR-10 Batch 1:  loss is 0.630910, validation accuracy is 0.539200
# Epoch 113, CIFAR-10 Batch 1:  loss is 0.626082, validation accuracy is 0.543000
# Epoch 114, CIFAR-10 Batch 1:  loss is 0.623263, validation accuracy is 0.539800
# Epoch 115, CIFAR-10 Batch 1:  loss is 0.631950, validation accuracy is 0.532000
# Epoch 116, CIFAR-10 Batch 1:  loss is 0.622754, validation accuracy is 0.532400
# Epoch 117, CIFAR-10 Batch 1:  loss is 0.612573, validation accuracy is 0.535600
# Epoch 118, CIFAR-10 Batch 1:  loss is 0.615534, validation accuracy is 0.535600
# Epoch 119, CIFAR-10 Batch 1:  loss is 0.591162, validation accuracy is 0.545200
# Epoch 120, CIFAR-10 Batch 1:  loss is 0.594719, validation accuracy is 0.541000
# Epoch 121, CIFAR-10 Batch 1:  loss is 0.574854, validation accuracy is 0.542400
# Epoch 122, CIFAR-10 Batch 1:  loss is 0.572809, validation accuracy is 0.541800
# Epoch 123, CIFAR-10 Batch 1:  loss is 0.583054, validation accuracy is 0.538000
# Epoch 124, CIFAR-10 Batch 1:  loss is 0.574134, validation accuracy is 0.538800
# Epoch 125, CIFAR-10 Batch 1:  loss is 0.553663, validation accuracy is 0.548800
# Epoch 126, CIFAR-10 Batch 1:  loss is 0.545657, validation accuracy is 0.548600
# Epoch 127, CIFAR-10 Batch 1:  loss is 0.566146, validation accuracy is 0.544400
# Epoch 128, CIFAR-10 Batch 1:  loss is 0.553116, validation accuracy is 0.546200
# Epoch 129, CIFAR-10 Batch 1:  loss is 0.539146, validation accuracy is 0.545600
# Epoch 130, CIFAR-10 Batch 1:  loss is 0.536430, validation accuracy is 0.546600
# Epoch 131, CIFAR-10 Batch 1:  loss is 0.523742, validation accuracy is 0.545800
# Epoch 132, CIFAR-10 Batch 1:  loss is 0.518573, validation accuracy is 0.553600
# Epoch 133, CIFAR-10 Batch 1:  loss is 0.518228, validation accuracy is 0.550000
# Epoch 134, CIFAR-10 Batch 1:  loss is 0.506494, validation accuracy is 0.552600
# Epoch 135, CIFAR-10 Batch 1:  loss is 0.515785, validation accuracy is 0.542400
# Epoch 136, CIFAR-10 Batch 1:  loss is 0.495641, validation accuracy is 0.550400
# Epoch 137, CIFAR-10 Batch 1:  loss is 0.500171, validation accuracy is 0.550800
# Epoch 138, CIFAR-10 Batch 1:  loss is 0.496409, validation accuracy is 0.547800
# Epoch 139, CIFAR-10 Batch 1:  loss is 0.483502, validation accuracy is 0.556200
# Epoch 140, CIFAR-10 Batch 1:  loss is 0.471412, validation accuracy is 0.552200
# Epoch 141, CIFAR-10 Batch 1:  loss is 0.477183, validation accuracy is 0.551200
# Epoch 142, CIFAR-10 Batch 1:  loss is 0.469007, validation accuracy is 0.551000
# Epoch 143, CIFAR-10 Batch 1:  loss is 0.462285, validation accuracy is 0.553800
# Epoch 144, CIFAR-10 Batch 1:  loss is 0.459155, validation accuracy is 0.555000
# Epoch 145, CIFAR-10 Batch 1:  loss is 0.458596, validation accuracy is 0.563000
# Epoch 146, CIFAR-10 Batch 1:  loss is 0.457148, validation accuracy is 0.552800
# Epoch 147, CIFAR-10 Batch 1:  loss is 0.444208, validation accuracy is 0.555200
# Epoch 148, CIFAR-10 Batch 1:  loss is 0.439454, validation accuracy is 0.557400
# Epoch 149, CIFAR-10 Batch 1:  loss is 0.448610, validation accuracy is 0.554400
# Epoch 150, CIFAR-10 Batch 1:  loss is 0.453310, validation accuracy is 0.547200
# Epoch 151, CIFAR-10 Batch 1:  loss is 0.427011, validation accuracy is 0.547000
# Epoch 152, CIFAR-10 Batch 1:  loss is 0.434804, validation accuracy is 0.555600
# Epoch 153, CIFAR-10 Batch 1:  loss is 0.426497, validation accuracy is 0.554200
# Epoch 154, CIFAR-10 Batch 1:  loss is 0.417276, validation accuracy is 0.554600
# Epoch 155, CIFAR-10 Batch 1:  loss is 0.427205, validation accuracy is 0.552800
# Epoch 156, CIFAR-10 Batch 1:  loss is 0.426148, validation accuracy is 0.555000
# Epoch 157, CIFAR-10 Batch 1:  loss is 0.415652, validation accuracy is 0.555600
# Epoch 158, CIFAR-10 Batch 1:  loss is 0.402378, validation accuracy is 0.555000
# Epoch 159, CIFAR-10 Batch 1:  loss is 0.402220, validation accuracy is 0.559600
# Epoch 160, CIFAR-10 Batch 1:  loss is 0.388686, validation accuracy is 0.558000
# Epoch 161, CIFAR-10 Batch 1:  loss is 0.390308, validation accuracy is 0.552200
# Epoch 162, CIFAR-10 Batch 1:  loss is 0.393755, validation accuracy is 0.555800
# Epoch 163, CIFAR-10 Batch 1:  loss is 0.385375, validation accuracy is 0.553800
# Epoch 164, CIFAR-10 Batch 1:  loss is 0.370650, validation accuracy is 0.558400
# Epoch 165, CIFAR-10 Batch 1:  loss is 0.376944, validation accuracy is 0.559000
# Epoch 166, CIFAR-10 Batch 1:  loss is 0.368273, validation accuracy is 0.560600
# Epoch 167, CIFAR-10 Batch 1:  loss is 0.359555, validation accuracy is 0.560600
# Epoch 168, CIFAR-10 Batch 1:  loss is 0.360225, validation accuracy is 0.556800
# Epoch 169, CIFAR-10 Batch 1:  loss is 0.365168, validation accuracy is 0.555200
# Epoch 170, CIFAR-10 Batch 1:  loss is 0.353126, validation accuracy is 0.560000
# Epoch 171, CIFAR-10 Batch 1:  loss is 0.368885, validation accuracy is 0.551800
# Epoch 172, CIFAR-10 Batch 1:  loss is 0.361968, validation accuracy is 0.553600
# Epoch 173, CIFAR-10 Batch 1:  loss is 0.360973, validation accuracy is 0.556000
# Epoch 174, CIFAR-10 Batch 1:  loss is 0.377517, validation accuracy is 0.538600
# Epoch 175, CIFAR-10 Batch 1:  loss is 0.351181, validation accuracy is 0.552600
# Epoch 176, CIFAR-10 Batch 1:  loss is 0.356043, validation accuracy is 0.559600
# Epoch 177, CIFAR-10 Batch 1:  loss is 0.346365, validation accuracy is 0.553800
# Epoch 178, CIFAR-10 Batch 1:  loss is 0.336006, validation accuracy is 0.555400
# Epoch 179, CIFAR-10 Batch 1:  loss is 0.333311, validation accuracy is 0.562800
# Epoch 180, CIFAR-10 Batch 1:  loss is 0.325906, validation accuracy is 0.555800
# Epoch 181, CIFAR-10 Batch 1:  loss is 0.329751, validation accuracy is 0.556000
# Epoch 182, CIFAR-10 Batch 1:  loss is 0.322517, validation accuracy is 0.561000
# Epoch 183, CIFAR-10 Batch 1:  loss is 0.319363, validation accuracy is 0.555600
# Epoch 184, CIFAR-10 Batch 1:  loss is 0.313963, validation accuracy is 0.561800
# Epoch 185, CIFAR-10 Batch 1:  loss is 0.316819, validation accuracy is 0.556600
# Epoch 186, CIFAR-10 Batch 1:  loss is 0.311583, validation accuracy is 0.558800
# Epoch 187, CIFAR-10 Batch 1:  loss is 0.304936, validation accuracy is 0.557200
# Epoch 188, CIFAR-10 Batch 1:  loss is 0.295153, validation accuracy is 0.558200
# Epoch 189, CIFAR-10 Batch 1:  loss is 0.306201, validation accuracy is 0.561200
# Epoch 190, CIFAR-10 Batch 1:  loss is 0.291719, validation accuracy is 0.559200
# Epoch 191, CIFAR-10 Batch 1:  loss is 0.296633, validation accuracy is 0.553600
# Epoch 192, CIFAR-10 Batch 1:  loss is 0.295079, validation accuracy is 0.554000
# Epoch 193, CIFAR-10 Batch 1:  loss is 0.287897, validation accuracy is 0.559200
# Epoch 194, CIFAR-10 Batch 1:  loss is 0.293172, validation accuracy is 0.550600
# Epoch 195, CIFAR-10 Batch 1:  loss is 0.285623, validation accuracy is 0.554800
# Epoch 196, CIFAR-10 Batch 1:  loss is 0.282911, validation accuracy is 0.561000
# Epoch 197, CIFAR-10 Batch 1:  loss is 0.272351, validation accuracy is 0.558800
# Epoch 198, CIFAR-10 Batch 1:  loss is 0.282962, validation accuracy is 0.564200
# Epoch 199, CIFAR-10 Batch 1:  loss is 0.279994, validation accuracy is 0.555600
# Epoch 200, CIFAR-10 Batch 1:  loss is 0.280182, validation accuracy is 0.558400

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  loss is 2.277601, validation accuracy is 0.127400
# Epoch  1, CIFAR-10 Batch 2:  loss is 2.279465, validation accuracy is 0.131600
# Epoch  1, CIFAR-10 Batch 3:  loss is 2.261547, validation accuracy is 0.150200
# Epoch  1, CIFAR-10 Batch 4:  loss is 2.252430, validation accuracy is 0.174600
# Epoch  1, CIFAR-10 Batch 5:  loss is 2.229382, validation accuracy is 0.167000
# Epoch  2, CIFAR-10 Batch 1:  loss is 2.210015, validation accuracy is 0.176200
# Epoch  2, CIFAR-10 Batch 2:  loss is 2.190543, validation accuracy is 0.190000
# Epoch  2, CIFAR-10 Batch 3:  loss is 2.143822, validation accuracy is 0.210000
# Epoch  2, CIFAR-10 Batch 4:  loss is 2.160076, validation accuracy is 0.210000
# Epoch  2, CIFAR-10 Batch 5:  loss is 2.129879, validation accuracy is 0.216000
# Epoch  3, CIFAR-10 Batch 1:  loss is 2.077863, validation accuracy is 0.231000
# Epoch  3, CIFAR-10 Batch 2:  loss is 2.076492, validation accuracy is 0.252200
# Epoch  3, CIFAR-10 Batch 3:  loss is 2.031776, validation accuracy is 0.257600
# Epoch  3, CIFAR-10 Batch 4:  loss is 2.025168, validation accuracy is 0.268000
# Epoch  3, CIFAR-10 Batch 5:  loss is 2.006764, validation accuracy is 0.284800
# Epoch  4, CIFAR-10 Batch 1:  loss is 1.990079, validation accuracy is 0.278800
# Epoch  4, CIFAR-10 Batch 2:  loss is 1.957385, validation accuracy is 0.309400
# Epoch  4, CIFAR-10 Batch 3:  loss is 1.907848, validation accuracy is 0.324400
# Epoch  4, CIFAR-10 Batch 4:  loss is 1.892952, validation accuracy is 0.329400
# Epoch  4, CIFAR-10 Batch 5:  loss is 1.887474, validation accuracy is 0.349200
# Epoch  5, CIFAR-10 Batch 1:  loss is 1.878802, validation accuracy is 0.350000
# Epoch  5, CIFAR-10 Batch 2:  loss is 1.843677, validation accuracy is 0.357000
# Epoch  5, CIFAR-10 Batch 3:  loss is 1.819695, validation accuracy is 0.361000
# Epoch  5, CIFAR-10 Batch 4:  loss is 1.790421, validation accuracy is 0.373600
# Epoch  5, CIFAR-10 Batch 5:  loss is 1.804201, validation accuracy is 0.379800
# Epoch  6, CIFAR-10 Batch 1:  loss is 1.814222, validation accuracy is 0.368000
# Epoch  6, CIFAR-10 Batch 2:  loss is 1.772069, validation accuracy is 0.373600
# Epoch  6, CIFAR-10 Batch 3:  loss is 1.755538, validation accuracy is 0.374600
# Epoch  6, CIFAR-10 Batch 4:  loss is 1.737548, validation accuracy is 0.390600
# Epoch  6, CIFAR-10 Batch 5:  loss is 1.744906, validation accuracy is 0.400800
# Epoch  7, CIFAR-10 Batch 1:  loss is 1.749056, validation accuracy is 0.394000
# Epoch  7, CIFAR-10 Batch 2:  loss is 1.701012, validation accuracy is 0.400400
# Epoch  7, CIFAR-10 Batch 3:  loss is 1.671295, validation accuracy is 0.407200
# Epoch  7, CIFAR-10 Batch 4:  loss is 1.673605, validation accuracy is 0.409600
# Epoch  7, CIFAR-10 Batch 5:  loss is 1.698950, validation accuracy is 0.409200
# Epoch  8, CIFAR-10 Batch 1:  loss is 1.686696, validation accuracy is 0.408800
# Epoch  8, CIFAR-10 Batch 2:  loss is 1.648225, validation accuracy is 0.420400
# Epoch  8, CIFAR-10 Batch 3:  loss is 1.621690, validation accuracy is 0.423000
# Epoch  8, CIFAR-10 Batch 4:  loss is 1.620853, validation accuracy is 0.416000
# Epoch  8, CIFAR-10 Batch 5:  loss is 1.639627, validation accuracy is 0.423000
# Epoch  9, CIFAR-10 Batch 1:  loss is 1.631565, validation accuracy is 0.423600
# Epoch  9, CIFAR-10 Batch 2:  loss is 1.625058, validation accuracy is 0.417600
# Epoch  9, CIFAR-10 Batch 3:  loss is 1.594844, validation accuracy is 0.426800
# Epoch  9, CIFAR-10 Batch 4:  loss is 1.568856, validation accuracy is 0.427200
# Epoch  9, CIFAR-10 Batch 5:  loss is 1.586355, validation accuracy is 0.434600
# Epoch 10, CIFAR-10 Batch 1:  loss is 1.591426, validation accuracy is 0.434400
# Epoch 10, CIFAR-10 Batch 2:  loss is 1.557853, validation accuracy is 0.436400
# Epoch 10, CIFAR-10 Batch 3:  loss is 1.537881, validation accuracy is 0.440800
# Epoch 10, CIFAR-10 Batch 4:  loss is 1.526872, validation accuracy is 0.439200
# Epoch 10, CIFAR-10 Batch 5:  loss is 1.559137, validation accuracy is 0.451200
# Epoch 11, CIFAR-10 Batch 1:  loss is 1.565698, validation accuracy is 0.450200
# Epoch 11, CIFAR-10 Batch 2:  loss is 1.527816, validation accuracy is 0.442600
# Epoch 11, CIFAR-10 Batch 3:  loss is 1.535708, validation accuracy is 0.442400
# Epoch 11, CIFAR-10 Batch 4:  loss is 1.512182, validation accuracy is 0.445400
# Epoch 11, CIFAR-10 Batch 5:  loss is 1.519759, validation accuracy is 0.455000
# Epoch 12, CIFAR-10 Batch 1:  loss is 1.531113, validation accuracy is 0.447400
# Epoch 12, CIFAR-10 Batch 2:  loss is 1.489803, validation accuracy is 0.465200
# Epoch 12, CIFAR-10 Batch 3:  loss is 1.487213, validation accuracy is 0.453400
# Epoch 12, CIFAR-10 Batch 4:  loss is 1.481125, validation accuracy is 0.460600
# Epoch 12, CIFAR-10 Batch 5:  loss is 1.487370, validation accuracy is 0.464200
# Epoch 13, CIFAR-10 Batch 1:  loss is 1.481612, validation accuracy is 0.469400
# Epoch 13, CIFAR-10 Batch 2:  loss is 1.461541, validation accuracy is 0.461400
# Epoch 13, CIFAR-10 Batch 3:  loss is 1.459668, validation accuracy is 0.472400
# Epoch 13, CIFAR-10 Batch 4:  loss is 1.453396, validation accuracy is 0.456200
# Epoch 13, CIFAR-10 Batch 5:  loss is 1.462808, validation accuracy is 0.466600
# Epoch 14, CIFAR-10 Batch 1:  loss is 1.483779, validation accuracy is 0.460600
# Epoch 14, CIFAR-10 Batch 2:  loss is 1.445614, validation accuracy is 0.476000
# Epoch 14, CIFAR-10 Batch 3:  loss is 1.417256, validation accuracy is 0.469400
# Epoch 14, CIFAR-10 Batch 4:  loss is 1.402802, validation accuracy is 0.481800
# Epoch 14, CIFAR-10 Batch 5:  loss is 1.430526, validation accuracy is 0.477800
# Epoch 15, CIFAR-10 Batch 1:  loss is 1.443747, validation accuracy is 0.472400
# Epoch 15, CIFAR-10 Batch 2:  loss is 1.428702, validation accuracy is 0.488000
# Epoch 15, CIFAR-10 Batch 3:  loss is 1.394965, validation accuracy is 0.482600
# Epoch 15, CIFAR-10 Batch 4:  loss is 1.384287, validation accuracy is 0.481400
# Epoch 15, CIFAR-10 Batch 5:  loss is 1.426841, validation accuracy is 0.474800
# Epoch 16, CIFAR-10 Batch 1:  loss is 1.433697, validation accuracy is 0.480200
# Epoch 16, CIFAR-10 Batch 2:  loss is 1.398008, validation accuracy is 0.476200
# Epoch 16, CIFAR-10 Batch 3:  loss is 1.351148, validation accuracy is 0.489400
# Epoch 16, CIFAR-10 Batch 4:  loss is 1.365871, validation accuracy is 0.486800
# Epoch 16, CIFAR-10 Batch 5:  loss is 1.387939, validation accuracy is 0.488800
# Epoch 17, CIFAR-10 Batch 1:  loss is 1.389036, validation accuracy is 0.497600
# Epoch 17, CIFAR-10 Batch 2:  loss is 1.382103, validation accuracy is 0.481800
# Epoch 17, CIFAR-10 Batch 3:  loss is 1.347893, validation accuracy is 0.491400
# Epoch 17, CIFAR-10 Batch 4:  loss is 1.357794, validation accuracy is 0.485400
# Epoch 17, CIFAR-10 Batch 5:  loss is 1.366368, validation accuracy is 0.492600
# Epoch 18, CIFAR-10 Batch 1:  loss is 1.371842, validation accuracy is 0.494800
# Epoch 18, CIFAR-10 Batch 2:  loss is 1.370694, validation accuracy is 0.486400
# Epoch 18, CIFAR-10 Batch 3:  loss is 1.322397, validation accuracy is 0.499400
# Epoch 18, CIFAR-10 Batch 4:  loss is 1.346042, validation accuracy is 0.491600
# Epoch 18, CIFAR-10 Batch 5:  loss is 1.335249, validation accuracy is 0.503400
# Epoch 19, CIFAR-10 Batch 1:  loss is 1.334511, validation accuracy is 0.504200
# Epoch 19, CIFAR-10 Batch 2:  loss is 1.339180, validation accuracy is 0.502200
# Epoch 19, CIFAR-10 Batch 3:  loss is 1.310283, validation accuracy is 0.504200
# Epoch 19, CIFAR-10 Batch 4:  loss is 1.321321, validation accuracy is 0.497000
# Epoch 19, CIFAR-10 Batch 5:  loss is 1.326878, validation accuracy is 0.495400
# Epoch 20, CIFAR-10 Batch 1:  loss is 1.317800, validation accuracy is 0.501600
# Epoch 20, CIFAR-10 Batch 2:  loss is 1.310545, validation accuracy is 0.503600
# Epoch 20, CIFAR-10 Batch 3:  loss is 1.290666, validation accuracy is 0.508800
# Epoch 20, CIFAR-10 Batch 4:  loss is 1.295130, validation accuracy is 0.506000
# Epoch 20, CIFAR-10 Batch 5:  loss is 1.294564, validation accuracy is 0.506200
# Epoch 21, CIFAR-10 Batch 1:  loss is 1.292794, validation accuracy is 0.510400
# Epoch 21, CIFAR-10 Batch 2:  loss is 1.292418, validation accuracy is 0.507800
# Epoch 21, CIFAR-10 Batch 3:  loss is 1.253789, validation accuracy is 0.513600
# Epoch 21, CIFAR-10 Batch 4:  loss is 1.271488, validation accuracy is 0.510000
# Epoch 21, CIFAR-10 Batch 5:  loss is 1.267272, validation accuracy is 0.517800
# Epoch 22, CIFAR-10 Batch 1:  loss is 1.278373, validation accuracy is 0.516200
# Epoch 22, CIFAR-10 Batch 2:  loss is 1.273785, validation accuracy is 0.518400
# Epoch 22, CIFAR-10 Batch 3:  loss is 1.241831, validation accuracy is 0.508600
# Epoch 22, CIFAR-10 Batch 4:  loss is 1.261925, validation accuracy is 0.507600
# Epoch 22, CIFAR-10 Batch 5:  loss is 1.264137, validation accuracy is 0.513400
# Epoch 23, CIFAR-10 Batch 1:  loss is 1.272156, validation accuracy is 0.510000
# Epoch 23, CIFAR-10 Batch 2:  loss is 1.261700, validation accuracy is 0.516400
# Epoch 23, CIFAR-10 Batch 3:  loss is 1.229673, validation accuracy is 0.515800
# Epoch 23, CIFAR-10 Batch 4:  loss is 1.224201, validation accuracy is 0.520400
# Epoch 23, CIFAR-10 Batch 5:  loss is 1.227173, validation accuracy is 0.522600
# Epoch 24, CIFAR-10 Batch 1:  loss is 1.248175, validation accuracy is 0.518400
# Epoch 24, CIFAR-10 Batch 2:  loss is 1.250418, validation accuracy is 0.509800
# Epoch 24, CIFAR-10 Batch 3:  loss is 1.228919, validation accuracy is 0.516800
# Epoch 24, CIFAR-10 Batch 4:  loss is 1.218088, validation accuracy is 0.518000
# Epoch 24, CIFAR-10 Batch 5:  loss is 1.208270, validation accuracy is 0.528200
# Epoch 25, CIFAR-10 Batch 1:  loss is 1.217648, validation accuracy is 0.524600
# Epoch 25, CIFAR-10 Batch 2:  loss is 1.213296, validation accuracy is 0.530000
# Epoch 25, CIFAR-10 Batch 3:  loss is 1.210023, validation accuracy is 0.531200
# Epoch 25, CIFAR-10 Batch 4:  loss is 1.202695, validation accuracy is 0.519600
# Epoch 25, CIFAR-10 Batch 5:  loss is 1.197361, validation accuracy is 0.533400
# Epoch 26, CIFAR-10 Batch 1:  loss is 1.208191, validation accuracy is 0.524400
# Epoch 26, CIFAR-10 Batch 2:  loss is 1.210756, validation accuracy is 0.523800
# Epoch 26, CIFAR-10 Batch 3:  loss is 1.189290, validation accuracy is 0.526600
# Epoch 26, CIFAR-10 Batch 4:  loss is 1.170418, validation accuracy is 0.522200
# Epoch 26, CIFAR-10 Batch 5:  loss is 1.176803, validation accuracy is 0.535800
# Epoch 27, CIFAR-10 Batch 1:  loss is 1.198028, validation accuracy is 0.528000
# Epoch 27, CIFAR-10 Batch 2:  loss is 1.184243, validation accuracy is 0.535200
# Epoch 27, CIFAR-10 Batch 3:  loss is 1.162983, validation accuracy is 0.538200
# Epoch 27, CIFAR-10 Batch 4:  loss is 1.175437, validation accuracy is 0.526600
# Epoch 27, CIFAR-10 Batch 5:  loss is 1.173390, validation accuracy is 0.537400
# Epoch 28, CIFAR-10 Batch 1:  loss is 1.182861, validation accuracy is 0.538800
# Epoch 28, CIFAR-10 Batch 2:  loss is 1.171659, validation accuracy is 0.535000
# Epoch 28, CIFAR-10 Batch 3:  loss is 1.137661, validation accuracy is 0.536600
# Epoch 28, CIFAR-10 Batch 4:  loss is 1.136567, validation accuracy is 0.533400
# Epoch 28, CIFAR-10 Batch 5:  loss is 1.149750, validation accuracy is 0.544200
# Epoch 29, CIFAR-10 Batch 1:  loss is 1.165972, validation accuracy is 0.537400
# Epoch 29, CIFAR-10 Batch 2:  loss is 1.142119, validation accuracy is 0.544200
# Epoch 29, CIFAR-10 Batch 3:  loss is 1.134361, validation accuracy is 0.541200
# Epoch 29, CIFAR-10 Batch 4:  loss is 1.136729, validation accuracy is 0.534800
# Epoch 29, CIFAR-10 Batch 5:  loss is 1.150194, validation accuracy is 0.536400
# Epoch 30, CIFAR-10 Batch 1:  loss is 1.156327, validation accuracy is 0.530000
# Epoch 30, CIFAR-10 Batch 2:  loss is 1.157178, validation accuracy is 0.543400
# Epoch 30, CIFAR-10 Batch 3:  loss is 1.133532, validation accuracy is 0.535400
# Epoch 30, CIFAR-10 Batch 4:  loss is 1.115280, validation accuracy is 0.540200
# Epoch 30, CIFAR-10 Batch 5:  loss is 1.118533, validation accuracy is 0.544800
# Epoch 31, CIFAR-10 Batch 1:  loss is 1.127821, validation accuracy is 0.547600
# Epoch 31, CIFAR-10 Batch 2:  loss is 1.122895, validation accuracy is 0.551400
# Epoch 31, CIFAR-10 Batch 3:  loss is 1.091154, validation accuracy is 0.553600
# Epoch 31, CIFAR-10 Batch 4:  loss is 1.099450, validation accuracy is 0.543600
# Epoch 31, CIFAR-10 Batch 5:  loss is 1.104435, validation accuracy is 0.548200
# Epoch 32, CIFAR-10 Batch 1:  loss is 1.107496, validation accuracy is 0.553600
# Epoch 32, CIFAR-10 Batch 2:  loss is 1.115550, validation accuracy is 0.544000
# Epoch 32, CIFAR-10 Batch 3:  loss is 1.095621, validation accuracy is 0.546000
# Epoch 32, CIFAR-10 Batch 4:  loss is 1.082420, validation accuracy is 0.544600
# Epoch 32, CIFAR-10 Batch 5:  loss is 1.081278, validation accuracy is 0.554000
# Epoch 33, CIFAR-10 Batch 1:  loss is 1.102146, validation accuracy is 0.549400
# Epoch 33, CIFAR-10 Batch 2:  loss is 1.096602, validation accuracy is 0.547800
# Epoch 33, CIFAR-10 Batch 3:  loss is 1.070897, validation accuracy is 0.551400
# Epoch 33, CIFAR-10 Batch 4:  loss is 1.081054, validation accuracy is 0.549800
# Epoch 33, CIFAR-10 Batch 5:  loss is 1.070709, validation accuracy is 0.553200
# Epoch 34, CIFAR-10 Batch 1:  loss is 1.099641, validation accuracy is 0.544000
# Epoch 34, CIFAR-10 Batch 2:  loss is 1.096397, validation accuracy is 0.552200
# Epoch 34, CIFAR-10 Batch 3:  loss is 1.094730, validation accuracy is 0.547000
# Epoch 34, CIFAR-10 Batch 4:  loss is 1.057755, validation accuracy is 0.546000
# Epoch 34, CIFAR-10 Batch 5:  loss is 1.063862, validation accuracy is 0.546400
# Epoch 35, CIFAR-10 Batch 1:  loss is 1.072272, validation accuracy is 0.555000
# Epoch 35, CIFAR-10 Batch 2:  loss is 1.066460, validation accuracy is 0.558800
# Epoch 35, CIFAR-10 Batch 3:  loss is 1.034274, validation accuracy is 0.554200
# Epoch 35, CIFAR-10 Batch 4:  loss is 1.037808, validation accuracy is 0.555800
# Epoch 35, CIFAR-10 Batch 5:  loss is 1.053199, validation accuracy is 0.555400
# Epoch 36, CIFAR-10 Batch 1:  loss is 1.049115, validation accuracy is 0.559200
# Epoch 36, CIFAR-10 Batch 2:  loss is 1.045695, validation accuracy is 0.564600
# Epoch 36, CIFAR-10 Batch 3:  loss is 1.042740, validation accuracy is 0.558200
# Epoch 36, CIFAR-10 Batch 4:  loss is 1.040022, validation accuracy is 0.551800
# Epoch 36, CIFAR-10 Batch 5:  loss is 1.022327, validation accuracy is 0.563800
# Epoch 37, CIFAR-10 Batch 1:  loss is 1.041239, validation accuracy is 0.563200
# Epoch 37, CIFAR-10 Batch 2:  loss is 1.035219, validation accuracy is 0.566000
# Epoch 37, CIFAR-10 Batch 3:  loss is 1.016582, validation accuracy is 0.569000
# Epoch 37, CIFAR-10 Batch 4:  loss is 0.994113, validation accuracy is 0.572800
# Epoch 37, CIFAR-10 Batch 5:  loss is 0.987113, validation accuracy is 0.570800
# Epoch 38, CIFAR-10 Batch 1:  loss is 1.027298, validation accuracy is 0.566600
# Epoch 38, CIFAR-10 Batch 2:  loss is 1.028368, validation accuracy is 0.564600
# Epoch 38, CIFAR-10 Batch 3:  loss is 1.007839, validation accuracy is 0.562600
# Epoch 38, CIFAR-10 Batch 4:  loss is 0.990580, validation accuracy is 0.571400
# Epoch 38, CIFAR-10 Batch 5:  loss is 0.986993, validation accuracy is 0.575200
# Epoch 39, CIFAR-10 Batch 1:  loss is 1.016568, validation accuracy is 0.575200
# Epoch 39, CIFAR-10 Batch 2:  loss is 1.011136, validation accuracy is 0.569000
# Epoch 39, CIFAR-10 Batch 3:  loss is 0.981397, validation accuracy is 0.570800
# Epoch 39, CIFAR-10 Batch 4:  loss is 0.972132, validation accuracy is 0.566400
# Epoch 39, CIFAR-10 Batch 5:  loss is 0.967995, validation accuracy is 0.574000
# Epoch 40, CIFAR-10 Batch 1:  loss is 1.002991, validation accuracy is 0.577600
# Epoch 40, CIFAR-10 Batch 2:  loss is 0.988311, validation accuracy is 0.574400
# Epoch 40, CIFAR-10 Batch 3:  loss is 0.968860, validation accuracy is 0.579400
# Epoch 40, CIFAR-10 Batch 4:  loss is 0.949909, validation accuracy is 0.573600
# Epoch 40, CIFAR-10 Batch 5:  loss is 0.959545, validation accuracy is 0.575000
# Epoch 41, CIFAR-10 Batch 1:  loss is 0.982729, validation accuracy is 0.576800
# Epoch 41, CIFAR-10 Batch 2:  loss is 0.992192, validation accuracy is 0.568000
# Epoch 41, CIFAR-10 Batch 3:  loss is 0.961883, validation accuracy is 0.570200
# Epoch 41, CIFAR-10 Batch 4:  loss is 0.955976, validation accuracy is 0.570800
# Epoch 41, CIFAR-10 Batch 5:  loss is 0.950867, validation accuracy is 0.582600
# Epoch 42, CIFAR-10 Batch 1:  loss is 0.971027, validation accuracy is 0.579200
# Epoch 42, CIFAR-10 Batch 2:  loss is 0.947836, validation accuracy is 0.585000
# Epoch 42, CIFAR-10 Batch 3:  loss is 0.934138, validation accuracy is 0.580800
# Epoch 42, CIFAR-10 Batch 4:  loss is 0.928570, validation accuracy is 0.575200
# Epoch 42, CIFAR-10 Batch 5:  loss is 0.928105, validation accuracy is 0.585000
# Epoch 43, CIFAR-10 Batch 1:  loss is 0.955973, validation accuracy is 0.585200
# Epoch 43, CIFAR-10 Batch 2:  loss is 0.941958, validation accuracy is 0.580200
# Epoch 43, CIFAR-10 Batch 3:  loss is 0.929632, validation accuracy is 0.585200
# Epoch 43, CIFAR-10 Batch 4:  loss is 0.924830, validation accuracy is 0.577000
# Epoch 43, CIFAR-10 Batch 5:  loss is 0.911342, validation accuracy is 0.584200
# Epoch 44, CIFAR-10 Batch 1:  loss is 0.956434, validation accuracy is 0.581200
# Epoch 44, CIFAR-10 Batch 2:  loss is 0.927304, validation accuracy is 0.584400
# Epoch 44, CIFAR-10 Batch 3:  loss is 0.929260, validation accuracy is 0.584200
# Epoch 44, CIFAR-10 Batch 4:  loss is 0.913597, validation accuracy is 0.581200
# Epoch 44, CIFAR-10 Batch 5:  loss is 0.900749, validation accuracy is 0.588000
# Epoch 45, CIFAR-10 Batch 1:  loss is 0.941883, validation accuracy is 0.583200
# Epoch 45, CIFAR-10 Batch 2:  loss is 0.935725, validation accuracy is 0.579400
# Epoch 45, CIFAR-10 Batch 3:  loss is 0.924275, validation accuracy is 0.578000
# Epoch 45, CIFAR-10 Batch 4:  loss is 0.887757, validation accuracy is 0.589800
# Epoch 45, CIFAR-10 Batch 5:  loss is 0.890252, validation accuracy is 0.592600
# Epoch 46, CIFAR-10 Batch 1:  loss is 0.927383, validation accuracy is 0.585600
# Epoch 46, CIFAR-10 Batch 2:  loss is 0.928888, validation accuracy is 0.580000
# Epoch 46, CIFAR-10 Batch 3:  loss is 0.897379, validation accuracy is 0.596600
# Epoch 46, CIFAR-10 Batch 4:  loss is 0.884917, validation accuracy is 0.590800
# Epoch 46, CIFAR-10 Batch 5:  loss is 0.877606, validation accuracy is 0.592200
# Epoch 47, CIFAR-10 Batch 1:  loss is 0.894053, validation accuracy is 0.594800
# Epoch 47, CIFAR-10 Batch 2:  loss is 0.883713, validation accuracy is 0.593400
# Epoch 47, CIFAR-10 Batch 3:  loss is 0.883128, validation accuracy is 0.591000
# Epoch 47, CIFAR-10 Batch 4:  loss is 0.869116, validation accuracy is 0.590200
# Epoch 47, CIFAR-10 Batch 5:  loss is 0.860073, validation accuracy is 0.596800
# Epoch 48, CIFAR-10 Batch 1:  loss is 0.886285, validation accuracy is 0.602400
# Epoch 48, CIFAR-10 Batch 2:  loss is 0.865081, validation accuracy is 0.597200
# Epoch 48, CIFAR-10 Batch 3:  loss is 0.876791, validation accuracy is 0.598000
# Epoch 48, CIFAR-10 Batch 4:  loss is 0.852549, validation accuracy is 0.594800
# Epoch 48, CIFAR-10 Batch 5:  loss is 0.834583, validation accuracy is 0.594000
# Epoch 49, CIFAR-10 Batch 1:  loss is 0.879302, validation accuracy is 0.590600
# Epoch 49, CIFAR-10 Batch 2:  loss is 0.866219, validation accuracy is 0.597400
# Epoch 49, CIFAR-10 Batch 3:  loss is 0.862011, validation accuracy is 0.599600
# Epoch 49, CIFAR-10 Batch 4:  loss is 0.841681, validation accuracy is 0.599200
# Epoch 49, CIFAR-10 Batch 5:  loss is 0.834341, validation accuracy is 0.597200
# Epoch 50, CIFAR-10 Batch 1:  loss is 0.868823, validation accuracy is 0.592400
# Epoch 50, CIFAR-10 Batch 2:  loss is 0.849816, validation accuracy is 0.597200
# Epoch 50, CIFAR-10 Batch 3:  loss is 0.859790, validation accuracy is 0.593200
# Epoch 50, CIFAR-10 Batch 4:  loss is 0.825793, validation accuracy is 0.598000
# Epoch 50, CIFAR-10 Batch 5:  loss is 0.843040, validation accuracy is 0.592800
# Epoch 51, CIFAR-10 Batch 1:  loss is 0.848760, validation accuracy is 0.603200
# Epoch 51, CIFAR-10 Batch 2:  loss is 0.855843, validation accuracy is 0.591600
# Epoch 51, CIFAR-10 Batch 3:  loss is 0.843922, validation accuracy is 0.601000
# Epoch 51, CIFAR-10 Batch 4:  loss is 0.835662, validation accuracy is 0.594400
# Epoch 51, CIFAR-10 Batch 5:  loss is 0.826974, validation accuracy is 0.603600
# Epoch 52, CIFAR-10 Batch 1:  loss is 0.839344, validation accuracy is 0.606000
# Epoch 52, CIFAR-10 Batch 2:  loss is 0.820418, validation accuracy is 0.597400
# Epoch 52, CIFAR-10 Batch 3:  loss is 0.837936, validation accuracy is 0.592600
# Epoch 52, CIFAR-10 Batch 4:  loss is 0.820557, validation accuracy is 0.595800
# Epoch 52, CIFAR-10 Batch 5:  loss is 0.814937, validation accuracy is 0.599400
# Epoch 53, CIFAR-10 Batch 1:  loss is 0.846058, validation accuracy is 0.600400
# Epoch 53, CIFAR-10 Batch 2:  loss is 0.829042, validation accuracy is 0.602200
# Epoch 53, CIFAR-10 Batch 3:  loss is 0.816004, validation accuracy is 0.602000
# Epoch 53, CIFAR-10 Batch 4:  loss is 0.803952, validation accuracy is 0.602600
# Epoch 53, CIFAR-10 Batch 5:  loss is 0.802437, validation accuracy is 0.605400
# Epoch 54, CIFAR-10 Batch 1:  loss is 0.820871, validation accuracy is 0.610000
# Epoch 54, CIFAR-10 Batch 2:  loss is 0.792517, validation accuracy is 0.605400
# Epoch 54, CIFAR-10 Batch 3:  loss is 0.798458, validation accuracy is 0.606400
# Epoch 54, CIFAR-10 Batch 4:  loss is 0.794541, validation accuracy is 0.595000
# Epoch 54, CIFAR-10 Batch 5:  loss is 0.784430, validation accuracy is 0.606400
# Epoch 55, CIFAR-10 Batch 1:  loss is 0.829957, validation accuracy is 0.600000
# Epoch 55, CIFAR-10 Batch 2:  loss is 0.794085, validation accuracy is 0.609000
# Epoch 55, CIFAR-10 Batch 3:  loss is 0.795219, validation accuracy is 0.606400
# Epoch 55, CIFAR-10 Batch 4:  loss is 0.785496, validation accuracy is 0.592800
# Epoch 55, CIFAR-10 Batch 5:  loss is 0.775875, validation accuracy is 0.609400
# Epoch 56, CIFAR-10 Batch 1:  loss is 0.801442, validation accuracy is 0.607600
# Epoch 56, CIFAR-10 Batch 2:  loss is 0.781073, validation accuracy is 0.611600
# Epoch 56, CIFAR-10 Batch 3:  loss is 0.782016, validation accuracy is 0.610400
# Epoch 56, CIFAR-10 Batch 4:  loss is 0.759023, validation accuracy is 0.607200
# Epoch 56, CIFAR-10 Batch 5:  loss is 0.751207, validation accuracy is 0.611600
# Epoch 57, CIFAR-10 Batch 1:  loss is 0.789176, validation accuracy is 0.610200
# Epoch 57, CIFAR-10 Batch 2:  loss is 0.780445, validation accuracy is 0.609800
# Epoch 57, CIFAR-10 Batch 3:  loss is 0.775473, validation accuracy is 0.610200
# Epoch 57, CIFAR-10 Batch 4:  loss is 0.766724, validation accuracy is 0.594800
# Epoch 57, CIFAR-10 Batch 5:  loss is 0.749888, validation accuracy is 0.606600
# Epoch 58, CIFAR-10 Batch 1:  loss is 0.781993, validation accuracy is 0.613000
# Epoch 58, CIFAR-10 Batch 2:  loss is 0.761853, validation accuracy is 0.611800
# Epoch 58, CIFAR-10 Batch 3:  loss is 0.768178, validation accuracy is 0.607000
# Epoch 58, CIFAR-10 Batch 4:  loss is 0.744899, validation accuracy is 0.602400
# Epoch 58, CIFAR-10 Batch 5:  loss is 0.740799, validation accuracy is 0.612600
# Epoch 59, CIFAR-10 Batch 1:  loss is 0.765285, validation accuracy is 0.617800
# Epoch 59, CIFAR-10 Batch 2:  loss is 0.756907, validation accuracy is 0.610400
# Epoch 59, CIFAR-10 Batch 3:  loss is 0.747755, validation accuracy is 0.612800
# Epoch 59, CIFAR-10 Batch 4:  loss is 0.740920, validation accuracy is 0.607800
# Epoch 59, CIFAR-10 Batch 5:  loss is 0.730763, validation accuracy is 0.611800
# Epoch 60, CIFAR-10 Batch 1:  loss is 0.758199, validation accuracy is 0.617000
# Epoch 60, CIFAR-10 Batch 2:  loss is 0.731703, validation accuracy is 0.614600
# Epoch 60, CIFAR-10 Batch 3:  loss is 0.737046, validation accuracy is 0.613600
# Epoch 60, CIFAR-10 Batch 4:  loss is 0.714323, validation accuracy is 0.614600
# Epoch 60, CIFAR-10 Batch 5:  loss is 0.706902, validation accuracy is 0.615000
# Epoch 61, CIFAR-10 Batch 1:  loss is 0.744689, validation accuracy is 0.613800
# Epoch 61, CIFAR-10 Batch 2:  loss is 0.725737, validation accuracy is 0.615000
# Epoch 61, CIFAR-10 Batch 3:  loss is 0.721868, validation accuracy is 0.618000
# Epoch 61, CIFAR-10 Batch 4:  loss is 0.710993, validation accuracy is 0.612200
# Epoch 61, CIFAR-10 Batch 5:  loss is 0.705550, validation accuracy is 0.614200
# Epoch 62, CIFAR-10 Batch 1:  loss is 0.748335, validation accuracy is 0.617400
# Epoch 62, CIFAR-10 Batch 2:  loss is 0.725437, validation accuracy is 0.611200
# Epoch 62, CIFAR-10 Batch 3:  loss is 0.722472, validation accuracy is 0.622400
# Epoch 62, CIFAR-10 Batch 4:  loss is 0.707843, validation accuracy is 0.617800
# Epoch 62, CIFAR-10 Batch 5:  loss is 0.697939, validation accuracy is 0.614000
# Epoch 63, CIFAR-10 Batch 1:  loss is 0.717925, validation accuracy is 0.622200
# Epoch 63, CIFAR-10 Batch 2:  loss is 0.694724, validation accuracy is 0.622000
# Epoch 63, CIFAR-10 Batch 3:  loss is 0.713171, validation accuracy is 0.624200
# Epoch 63, CIFAR-10 Batch 4:  loss is 0.703199, validation accuracy is 0.615400
# Epoch 63, CIFAR-10 Batch 5:  loss is 0.691350, validation accuracy is 0.615000
# Epoch 64, CIFAR-10 Batch 1:  loss is 0.725198, validation accuracy is 0.612400
# Epoch 64, CIFAR-10 Batch 2:  loss is 0.701332, validation accuracy is 0.623000
# Epoch 64, CIFAR-10 Batch 3:  loss is 0.710795, validation accuracy is 0.621600
# Epoch 64, CIFAR-10 Batch 4:  loss is 0.695271, validation accuracy is 0.615600
# Epoch 64, CIFAR-10 Batch 5:  loss is 0.677259, validation accuracy is 0.622000
# Epoch 65, CIFAR-10 Batch 1:  loss is 0.716440, validation accuracy is 0.618000
# Epoch 65, CIFAR-10 Batch 2:  loss is 0.690771, validation accuracy is 0.625400
# Epoch 65, CIFAR-10 Batch 3:  loss is 0.698116, validation accuracy is 0.624600
# Epoch 65, CIFAR-10 Batch 4:  loss is 0.699435, validation accuracy is 0.606800
# Epoch 65, CIFAR-10 Batch 5:  loss is 0.672590, validation accuracy is 0.624000
# Epoch 66, CIFAR-10 Batch 1:  loss is 0.695940, validation accuracy is 0.623800
# Epoch 66, CIFAR-10 Batch 2:  loss is 0.687714, validation accuracy is 0.619600
# Epoch 66, CIFAR-10 Batch 3:  loss is 0.694766, validation accuracy is 0.620600
# Epoch 66, CIFAR-10 Batch 4:  loss is 0.669592, validation accuracy is 0.620200
# Epoch 66, CIFAR-10 Batch 5:  loss is 0.679843, validation accuracy is 0.612600
# Epoch 67, CIFAR-10 Batch 1:  loss is 0.702334, validation accuracy is 0.620600
# Epoch 67, CIFAR-10 Batch 2:  loss is 0.684432, validation accuracy is 0.623000
# Epoch 67, CIFAR-10 Batch 3:  loss is 0.667986, validation accuracy is 0.624600
# Epoch 67, CIFAR-10 Batch 4:  loss is 0.654828, validation accuracy is 0.612000
# Epoch 67, CIFAR-10 Batch 5:  loss is 0.658621, validation accuracy is 0.625600
# Epoch 68, CIFAR-10 Batch 1:  loss is 0.697736, validation accuracy is 0.621200
# Epoch 68, CIFAR-10 Batch 2:  loss is 0.673647, validation accuracy is 0.620800
# Epoch 68, CIFAR-10 Batch 3:  loss is 0.676370, validation accuracy is 0.620800
# Epoch 68, CIFAR-10 Batch 4:  loss is 0.654245, validation accuracy is 0.619000
# Epoch 68, CIFAR-10 Batch 5:  loss is 0.659391, validation accuracy is 0.619200
# Epoch 69, CIFAR-10 Batch 1:  loss is 0.676190, validation accuracy is 0.627200
# Epoch 69, CIFAR-10 Batch 2:  loss is 0.658622, validation accuracy is 0.626600
# Epoch 69, CIFAR-10 Batch 3:  loss is 0.667583, validation accuracy is 0.622200
# Epoch 69, CIFAR-10 Batch 4:  loss is 0.631191, validation accuracy is 0.623200
# Epoch 69, CIFAR-10 Batch 5:  loss is 0.636860, validation accuracy is 0.620200
# Epoch 70, CIFAR-10 Batch 1:  loss is 0.694740, validation accuracy is 0.622000
# Epoch 70, CIFAR-10 Batch 2:  loss is 0.665134, validation accuracy is 0.618600
# Epoch 70, CIFAR-10 Batch 3:  loss is 0.649018, validation accuracy is 0.623800
# Epoch 70, CIFAR-10 Batch 4:  loss is 0.634553, validation accuracy is 0.619000
# Epoch 70, CIFAR-10 Batch 5:  loss is 0.613545, validation accuracy is 0.627200
# Epoch 71, CIFAR-10 Batch 1:  loss is 0.666149, validation accuracy is 0.628800
# Epoch 71, CIFAR-10 Batch 2:  loss is 0.661672, validation accuracy is 0.620000
# Epoch 71, CIFAR-10 Batch 3:  loss is 0.650926, validation accuracy is 0.625800
# Epoch 71, CIFAR-10 Batch 4:  loss is 0.635451, validation accuracy is 0.624400
# Epoch 71, CIFAR-10 Batch 5:  loss is 0.634468, validation accuracy is 0.625800
# Epoch 72, CIFAR-10 Batch 1:  loss is 0.667878, validation accuracy is 0.627600
# Epoch 72, CIFAR-10 Batch 2:  loss is 0.640776, validation accuracy is 0.627600
# Epoch 72, CIFAR-10 Batch 3:  loss is 0.641231, validation accuracy is 0.624000
# Epoch 72, CIFAR-10 Batch 4:  loss is 0.621158, validation accuracy is 0.627400
# Epoch 72, CIFAR-10 Batch 5:  loss is 0.624501, validation accuracy is 0.622200
# Epoch 73, CIFAR-10 Batch 1:  loss is 0.651013, validation accuracy is 0.636000
# Epoch 73, CIFAR-10 Batch 2:  loss is 0.635317, validation accuracy is 0.630400
# Epoch 73, CIFAR-10 Batch 3:  loss is 0.638734, validation accuracy is 0.626000
# Epoch 73, CIFAR-10 Batch 4:  loss is 0.606029, validation accuracy is 0.625400
# Epoch 73, CIFAR-10 Batch 5:  loss is 0.595071, validation accuracy is 0.628800
# Epoch 74, CIFAR-10 Batch 1:  loss is 0.635826, validation accuracy is 0.627000
# Epoch 74, CIFAR-10 Batch 2:  loss is 0.615105, validation accuracy is 0.627600
# Epoch 74, CIFAR-10 Batch 3:  loss is 0.615075, validation accuracy is 0.625200
# Epoch 74, CIFAR-10 Batch 4:  loss is 0.607786, validation accuracy is 0.623000
# Epoch 74, CIFAR-10 Batch 5:  loss is 0.591165, validation accuracy is 0.627600
# Epoch 75, CIFAR-10 Batch 1:  loss is 0.623708, validation accuracy is 0.631800
# Epoch 75, CIFAR-10 Batch 2:  loss is 0.610212, validation accuracy is 0.634000
# Epoch 75, CIFAR-10 Batch 3:  loss is 0.623350, validation accuracy is 0.624000
# Epoch 75, CIFAR-10 Batch 4:  loss is 0.602318, validation accuracy is 0.628800
# Epoch 75, CIFAR-10 Batch 5:  loss is 0.599920, validation accuracy is 0.628000
# Epoch 76, CIFAR-10 Batch 1:  loss is 0.624284, validation accuracy is 0.631400
# Epoch 76, CIFAR-10 Batch 2:  loss is 0.594757, validation accuracy is 0.633200
# Epoch 76, CIFAR-10 Batch 3:  loss is 0.603832, validation accuracy is 0.630200
# Epoch 76, CIFAR-10 Batch 4:  loss is 0.602551, validation accuracy is 0.628800
# Epoch 76, CIFAR-10 Batch 5:  loss is 0.596657, validation accuracy is 0.625800
# Epoch 77, CIFAR-10 Batch 1:  loss is 0.611735, validation accuracy is 0.628200
# Epoch 77, CIFAR-10 Batch 2:  loss is 0.596164, validation accuracy is 0.634200
# Epoch 77, CIFAR-10 Batch 3:  loss is 0.611812, validation accuracy is 0.631400
# Epoch 77, CIFAR-10 Batch 4:  loss is 0.599682, validation accuracy is 0.617600
# Epoch 77, CIFAR-10 Batch 5:  loss is 0.581287, validation accuracy is 0.630000
# Epoch 78, CIFAR-10 Batch 1:  loss is 0.615554, validation accuracy is 0.626000
# Epoch 78, CIFAR-10 Batch 2:  loss is 0.594740, validation accuracy is 0.634600
# Epoch 78, CIFAR-10 Batch 3:  loss is 0.610674, validation accuracy is 0.621000
# Epoch 78, CIFAR-10 Batch 4:  loss is 0.564342, validation accuracy is 0.629800
# Epoch 78, CIFAR-10 Batch 5:  loss is 0.569477, validation accuracy is 0.631800
# Epoch 79, CIFAR-10 Batch 1:  loss is 0.592551, validation accuracy is 0.639000
# Epoch 79, CIFAR-10 Batch 2:  loss is 0.581429, validation accuracy is 0.629800
# Epoch 79, CIFAR-10 Batch 3:  loss is 0.580814, validation accuracy is 0.632200
# Epoch 79, CIFAR-10 Batch 4:  loss is 0.565851, validation accuracy is 0.627000
# Epoch 79, CIFAR-10 Batch 5:  loss is 0.558806, validation accuracy is 0.628200
# Epoch 80, CIFAR-10 Batch 1:  loss is 0.578711, validation accuracy is 0.634800
# Epoch 80, CIFAR-10 Batch 2:  loss is 0.590406, validation accuracy is 0.631800
# Epoch 80, CIFAR-10 Batch 3:  loss is 0.574169, validation accuracy is 0.633400
# Epoch 80, CIFAR-10 Batch 4:  loss is 0.583136, validation accuracy is 0.615600
# Epoch 80, CIFAR-10 Batch 5:  loss is 0.548592, validation accuracy is 0.633200
# Epoch 81, CIFAR-10 Batch 1:  loss is 0.583295, validation accuracy is 0.633200
# Epoch 81, CIFAR-10 Batch 2:  loss is 0.574000, validation accuracy is 0.631200
# Epoch 81, CIFAR-10 Batch 3:  loss is 0.575758, validation accuracy is 0.633600
# Epoch 81, CIFAR-10 Batch 4:  loss is 0.569328, validation accuracy is 0.622200
# Epoch 81, CIFAR-10 Batch 5:  loss is 0.549547, validation accuracy is 0.632800
# Epoch 82, CIFAR-10 Batch 1:  loss is 0.569044, validation accuracy is 0.634200
# Epoch 82, CIFAR-10 Batch 2:  loss is 0.565128, validation accuracy is 0.635600
# Epoch 82, CIFAR-10 Batch 3:  loss is 0.577657, validation accuracy is 0.637800
# Epoch 82, CIFAR-10 Batch 4:  loss is 0.551297, validation accuracy is 0.630600
# Epoch 82, CIFAR-10 Batch 5:  loss is 0.538706, validation accuracy is 0.634000
# Epoch 83, CIFAR-10 Batch 1:  loss is 0.570037, validation accuracy is 0.636800
# Epoch 83, CIFAR-10 Batch 2:  loss is 0.549117, validation accuracy is 0.635800
# Epoch 83, CIFAR-10 Batch 3:  loss is 0.562743, validation accuracy is 0.627200
# Epoch 83, CIFAR-10 Batch 4:  loss is 0.560124, validation accuracy is 0.621400
# Epoch 83, CIFAR-10 Batch 5:  loss is 0.550379, validation accuracy is 0.633200
# Epoch 84, CIFAR-10 Batch 1:  loss is 0.554181, validation accuracy is 0.639400
# Epoch 84, CIFAR-10 Batch 2:  loss is 0.534697, validation accuracy is 0.641800
# Epoch 84, CIFAR-10 Batch 3:  loss is 0.541971, validation accuracy is 0.634800
# Epoch 84, CIFAR-10 Batch 4:  loss is 0.532118, validation accuracy is 0.633600
# Epoch 84, CIFAR-10 Batch 5:  loss is 0.527834, validation accuracy is 0.636800
# Epoch 85, CIFAR-10 Batch 1:  loss is 0.552890, validation accuracy is 0.641000
# Epoch 85, CIFAR-10 Batch 2:  loss is 0.528474, validation accuracy is 0.638000
# Epoch 85, CIFAR-10 Batch 3:  loss is 0.528626, validation accuracy is 0.638200
# Epoch 85, CIFAR-10 Batch 4:  loss is 0.531729, validation accuracy is 0.628800
# Epoch 85, CIFAR-10 Batch 5:  loss is 0.538034, validation accuracy is 0.629800
# Epoch 86, CIFAR-10 Batch 1:  loss is 0.555073, validation accuracy is 0.641000
# Epoch 86, CIFAR-10 Batch 2:  loss is 0.533028, validation accuracy is 0.638400
# Epoch 86, CIFAR-10 Batch 3:  loss is 0.540946, validation accuracy is 0.641400
# Epoch 86, CIFAR-10 Batch 4:  loss is 0.520124, validation accuracy is 0.636800
# Epoch 86, CIFAR-10 Batch 5:  loss is 0.520434, validation accuracy is 0.639800
# Epoch 87, CIFAR-10 Batch 1:  loss is 0.537293, validation accuracy is 0.643200
# Epoch 87, CIFAR-10 Batch 2:  loss is 0.515159, validation accuracy is 0.641600
# Epoch 87, CIFAR-10 Batch 3:  loss is 0.536930, validation accuracy is 0.637200
# Epoch 87, CIFAR-10 Batch 4:  loss is 0.523017, validation accuracy is 0.630200
# Epoch 87, CIFAR-10 Batch 5:  loss is 0.506920, validation accuracy is 0.638800
# Epoch 88, CIFAR-10 Batch 1:  loss is 0.532857, validation accuracy is 0.637600
# Epoch 88, CIFAR-10 Batch 2:  loss is 0.514733, validation accuracy is 0.642600
# Epoch 88, CIFAR-10 Batch 3:  loss is 0.527348, validation accuracy is 0.639800
# Epoch 88, CIFAR-10 Batch 4:  loss is 0.511105, validation accuracy is 0.636200
# Epoch 88, CIFAR-10 Batch 5:  loss is 0.506341, validation accuracy is 0.638000
# Epoch 89, CIFAR-10 Batch 1:  loss is 0.532821, validation accuracy is 0.639000
# Epoch 89, CIFAR-10 Batch 2:  loss is 0.507741, validation accuracy is 0.639600
# Epoch 89, CIFAR-10 Batch 3:  loss is 0.524493, validation accuracy is 0.641600
# Epoch 89, CIFAR-10 Batch 4:  loss is 0.502579, validation accuracy is 0.634800
# Epoch 89, CIFAR-10 Batch 5:  loss is 0.496664, validation accuracy is 0.640800
# Epoch 90, CIFAR-10 Batch 1:  loss is 0.520894, validation accuracy is 0.635000
# Epoch 90, CIFAR-10 Batch 2:  loss is 0.510954, validation accuracy is 0.639600
# Epoch 90, CIFAR-10 Batch 3:  loss is 0.524002, validation accuracy is 0.636600
# Epoch 90, CIFAR-10 Batch 4:  loss is 0.499847, validation accuracy is 0.635200
# Epoch 90, CIFAR-10 Batch 5:  loss is 0.488567, validation accuracy is 0.642200
# Epoch 91, CIFAR-10 Batch 1:  loss is 0.526036, validation accuracy is 0.639400
# Epoch 91, CIFAR-10 Batch 2:  loss is 0.501474, validation accuracy is 0.645400
# Epoch 91, CIFAR-10 Batch 3:  loss is 0.523582, validation accuracy is 0.635600
# Epoch 91, CIFAR-10 Batch 4:  loss is 0.492673, validation accuracy is 0.631600
# Epoch 91, CIFAR-10 Batch 5:  loss is 0.500737, validation accuracy is 0.636200
# Epoch 92, CIFAR-10 Batch 1:  loss is 0.524087, validation accuracy is 0.644800
# Epoch 92, CIFAR-10 Batch 2:  loss is 0.484995, validation accuracy is 0.646200
# Epoch 92, CIFAR-10 Batch 3:  loss is 0.508316, validation accuracy is 0.640600
# Epoch 92, CIFAR-10 Batch 4:  loss is 0.488268, validation accuracy is 0.636200
# Epoch 92, CIFAR-10 Batch 5:  loss is 0.491466, validation accuracy is 0.639600
# Epoch 93, CIFAR-10 Batch 1:  loss is 0.509063, validation accuracy is 0.641600
# Epoch 93, CIFAR-10 Batch 2:  loss is 0.488459, validation accuracy is 0.640200
# Epoch 93, CIFAR-10 Batch 3:  loss is 0.508556, validation accuracy is 0.642000
# Epoch 93, CIFAR-10 Batch 4:  loss is 0.493645, validation accuracy is 0.631000
# Epoch 93, CIFAR-10 Batch 5:  loss is 0.487216, validation accuracy is 0.640400
# Epoch 94, CIFAR-10 Batch 1:  loss is 0.506393, validation accuracy is 0.640400
# Epoch 94, CIFAR-10 Batch 2:  loss is 0.478189, validation accuracy is 0.638200
# Epoch 94, CIFAR-10 Batch 3:  loss is 0.480313, validation accuracy is 0.640400
# Epoch 94, CIFAR-10 Batch 4:  loss is 0.491953, validation accuracy is 0.633400
# Epoch 94, CIFAR-10 Batch 5:  loss is 0.470552, validation accuracy is 0.647200
# Epoch 95, CIFAR-10 Batch 1:  loss is 0.495909, validation accuracy is 0.641200
# Epoch 95, CIFAR-10 Batch 2:  loss is 0.482655, validation accuracy is 0.640600
# Epoch 95, CIFAR-10 Batch 3:  loss is 0.509350, validation accuracy is 0.637400
# Epoch 95, CIFAR-10 Batch 4:  loss is 0.484131, validation accuracy is 0.633800
# Epoch 95, CIFAR-10 Batch 5:  loss is 0.480853, validation accuracy is 0.635600
# Epoch 96, CIFAR-10 Batch 1:  loss is 0.502590, validation accuracy is 0.639800
# Epoch 96, CIFAR-10 Batch 2:  loss is 0.477401, validation accuracy is 0.640200
# Epoch 96, CIFAR-10 Batch 3:  loss is 0.506270, validation accuracy is 0.637000
# Epoch 96, CIFAR-10 Batch 4:  loss is 0.508323, validation accuracy is 0.627400
# Epoch 96, CIFAR-10 Batch 5:  loss is 0.479121, validation accuracy is 0.636400
# Epoch 97, CIFAR-10 Batch 1:  loss is 0.513975, validation accuracy is 0.635400
# Epoch 97, CIFAR-10 Batch 2:  loss is 0.483205, validation accuracy is 0.639200
# Epoch 97, CIFAR-10 Batch 3:  loss is 0.474990, validation accuracy is 0.640600
# Epoch 97, CIFAR-10 Batch 4:  loss is 0.473332, validation accuracy is 0.631000
# Epoch 97, CIFAR-10 Batch 5:  loss is 0.489061, validation accuracy is 0.634800
# Epoch 98, CIFAR-10 Batch 1:  loss is 0.497537, validation accuracy is 0.639400
# Epoch 98, CIFAR-10 Batch 2:  loss is 0.472086, validation accuracy is 0.635600
# Epoch 98, CIFAR-10 Batch 3:  loss is 0.490128, validation accuracy is 0.638200
# Epoch 98, CIFAR-10 Batch 4:  loss is 0.471525, validation accuracy is 0.637400
# Epoch 98, CIFAR-10 Batch 5:  loss is 0.478454, validation accuracy is 0.634000
# Epoch 99, CIFAR-10 Batch 1:  loss is 0.503505, validation accuracy is 0.631600
# Epoch 99, CIFAR-10 Batch 2:  loss is 0.472880, validation accuracy is 0.638600
# Epoch 99, CIFAR-10 Batch 3:  loss is 0.478454, validation accuracy is 0.637000
# Epoch 99, CIFAR-10 Batch 4:  loss is 0.472407, validation accuracy is 0.642400
# Epoch 99, CIFAR-10 Batch 5:  loss is 0.474735, validation accuracy is 0.634200
# Epoch 100, CIFAR-10 Batch 1:  loss is 0.513338, validation accuracy is 0.632600
# Epoch 100, CIFAR-10 Batch 2:  loss is 0.470690, validation accuracy is 0.643600
# Epoch 100, CIFAR-10 Batch 3:  loss is 0.472094, validation accuracy is 0.643400
# Epoch 100, CIFAR-10 Batch 4:  loss is 0.467678, validation accuracy is 0.641200
# Epoch 100, CIFAR-10 Batch 5:  loss is 0.456169, validation accuracy is 0.637000
# Epoch 101, CIFAR-10 Batch 1:  loss is 0.490392, validation accuracy is 0.641800
# Epoch 101, CIFAR-10 Batch 2:  loss is 0.459771, validation accuracy is 0.648800
# Epoch 101, CIFAR-10 Batch 3:  loss is 0.474190, validation accuracy is 0.636600
# Epoch 101, CIFAR-10 Batch 4:  loss is 0.461501, validation accuracy is 0.643000
# Epoch 101, CIFAR-10 Batch 5:  loss is 0.452465, validation accuracy is 0.640400
# Epoch 102, CIFAR-10 Batch 1:  loss is 0.470941, validation accuracy is 0.645800
# Epoch 102, CIFAR-10 Batch 2:  loss is 0.451310, validation accuracy is 0.639000
# Epoch 102, CIFAR-10 Batch 3:  loss is 0.467815, validation accuracy is 0.644800
# Epoch 102, CIFAR-10 Batch 4:  loss is 0.445919, validation accuracy is 0.641800
# Epoch 102, CIFAR-10 Batch 5:  loss is 0.451956, validation accuracy is 0.639200
# Epoch 103, CIFAR-10 Batch 1:  loss is 0.468408, validation accuracy is 0.647800
# Epoch 103, CIFAR-10 Batch 2:  loss is 0.441544, validation accuracy is 0.636800
# Epoch 103, CIFAR-10 Batch 3:  loss is 0.450868, validation accuracy is 0.646400
# Epoch 103, CIFAR-10 Batch 4:  loss is 0.449446, validation accuracy is 0.637400
# Epoch 103, CIFAR-10 Batch 5:  loss is 0.434138, validation accuracy is 0.643000
# Epoch 104, CIFAR-10 Batch 1:  loss is 0.455139, validation accuracy is 0.652000
# Epoch 104, CIFAR-10 Batch 2:  loss is 0.437409, validation accuracy is 0.647600
# Epoch 104, CIFAR-10 Batch 3:  loss is 0.439633, validation accuracy is 0.643400
# Epoch 104, CIFAR-10 Batch 4:  loss is 0.425809, validation accuracy is 0.647400
# Epoch 104, CIFAR-10 Batch 5:  loss is 0.429937, validation accuracy is 0.644400
# Epoch 105, CIFAR-10 Batch 1:  loss is 0.452552, validation accuracy is 0.646400
# Epoch 105, CIFAR-10 Batch 2:  loss is 0.435568, validation accuracy is 0.643000
# Epoch 105, CIFAR-10 Batch 3:  loss is 0.440918, validation accuracy is 0.647400
# Epoch 105, CIFAR-10 Batch 4:  loss is 0.428008, validation accuracy is 0.646600
# Epoch 105, CIFAR-10 Batch 5:  loss is 0.423456, validation accuracy is 0.642600
# Epoch 106, CIFAR-10 Batch 1:  loss is 0.455866, validation accuracy is 0.645400
# Epoch 106, CIFAR-10 Batch 2:  loss is 0.433841, validation accuracy is 0.646600
# Epoch 106, CIFAR-10 Batch 3:  loss is 0.440427, validation accuracy is 0.650200
# Epoch 106, CIFAR-10 Batch 4:  loss is 0.429583, validation accuracy is 0.652800
# Epoch 106, CIFAR-10 Batch 5:  loss is 0.412267, validation accuracy is 0.642200
# Epoch 107, CIFAR-10 Batch 1:  loss is 0.443174, validation accuracy is 0.648600
# Epoch 107, CIFAR-10 Batch 2:  loss is 0.422398, validation accuracy is 0.644400
# Epoch 107, CIFAR-10 Batch 3:  loss is 0.428647, validation accuracy is 0.647200
# Epoch 107, CIFAR-10 Batch 4:  loss is 0.416723, validation accuracy is 0.649800
# Epoch 107, CIFAR-10 Batch 5:  loss is 0.421056, validation accuracy is 0.650200
# Epoch 108, CIFAR-10 Batch 1:  loss is 0.442831, validation accuracy is 0.648400
# Epoch 108, CIFAR-10 Batch 2:  loss is 0.421948, validation accuracy is 0.644800
# Epoch 108, CIFAR-10 Batch 3:  loss is 0.432611, validation accuracy is 0.648600
# Epoch 108, CIFAR-10 Batch 4:  loss is 0.411927, validation accuracy is 0.650000
# Epoch 108, CIFAR-10 Batch 5:  loss is 0.407753, validation accuracy is 0.642200
# Epoch 109, CIFAR-10 Batch 1:  loss is 0.441900, validation accuracy is 0.650800
# Epoch 109, CIFAR-10 Batch 2:  loss is 0.425114, validation accuracy is 0.650600
# Epoch 109, CIFAR-10 Batch 3:  loss is 0.433899, validation accuracy is 0.647200
# Epoch 109, CIFAR-10 Batch 4:  loss is 0.412895, validation accuracy is 0.646200
# Epoch 109, CIFAR-10 Batch 5:  loss is 0.412480, validation accuracy is 0.643000
# Epoch 110, CIFAR-10 Batch 1:  loss is 0.434070, validation accuracy is 0.644800
# Epoch 110, CIFAR-10 Batch 2:  loss is 0.403643, validation accuracy is 0.649600
# Epoch 110, CIFAR-10 Batch 3:  loss is 0.417890, validation accuracy is 0.648000
# Epoch 110, CIFAR-10 Batch 4:  loss is 0.412048, validation accuracy is 0.647200
# Epoch 110, CIFAR-10 Batch 5:  loss is 0.410332, validation accuracy is 0.646600
# Epoch 111, CIFAR-10 Batch 1:  loss is 0.433176, validation accuracy is 0.644400
# Epoch 111, CIFAR-10 Batch 2:  loss is 0.413976, validation accuracy is 0.644200
# Epoch 111, CIFAR-10 Batch 3:  loss is 0.422035, validation accuracy is 0.646000
# Epoch 111, CIFAR-10 Batch 4:  loss is 0.424164, validation accuracy is 0.640600
# Epoch 111, CIFAR-10 Batch 5:  loss is 0.417700, validation accuracy is 0.641000
# Epoch 112, CIFAR-10 Batch 1:  loss is 0.430445, validation accuracy is 0.650800
# Epoch 112, CIFAR-10 Batch 2:  loss is 0.407475, validation accuracy is 0.648200
# Epoch 112, CIFAR-10 Batch 3:  loss is 0.427165, validation accuracy is 0.641400
# Epoch 112, CIFAR-10 Batch 4:  loss is 0.400986, validation accuracy is 0.639600
# Epoch 112, CIFAR-10 Batch 5:  loss is 0.421325, validation accuracy is 0.636200
# Epoch 113, CIFAR-10 Batch 1:  loss is 0.425695, validation accuracy is 0.645600
# Epoch 113, CIFAR-10 Batch 2:  loss is 0.411277, validation accuracy is 0.653400
# Epoch 113, CIFAR-10 Batch 3:  loss is 0.417792, validation accuracy is 0.649600
# Epoch 113, CIFAR-10 Batch 4:  loss is 0.396332, validation accuracy is 0.646600
# Epoch 113, CIFAR-10 Batch 5:  loss is 0.396634, validation accuracy is 0.654000
# Epoch 114, CIFAR-10 Batch 1:  loss is 0.415442, validation accuracy is 0.655400
# Epoch 114, CIFAR-10 Batch 2:  loss is 0.388841, validation accuracy is 0.655400
# Epoch 114, CIFAR-10 Batch 3:  loss is 0.405567, validation accuracy is 0.649600
# Epoch 114, CIFAR-10 Batch 4:  loss is 0.410230, validation accuracy is 0.649000
# Epoch 114, CIFAR-10 Batch 5:  loss is 0.387845, validation accuracy is 0.646600
# Epoch 115, CIFAR-10 Batch 1:  loss is 0.404318, validation accuracy is 0.652200
# Epoch 115, CIFAR-10 Batch 2:  loss is 0.392641, validation accuracy is 0.652000
# Epoch 115, CIFAR-10 Batch 3:  loss is 0.409184, validation accuracy is 0.646200
# Epoch 115, CIFAR-10 Batch 4:  loss is 0.392035, validation accuracy is 0.650800
# Epoch 115, CIFAR-10 Batch 5:  loss is 0.395489, validation accuracy is 0.647000
# Epoch 116, CIFAR-10 Batch 1:  loss is 0.408253, validation accuracy is 0.654400
# Epoch 116, CIFAR-10 Batch 2:  loss is 0.387910, validation accuracy is 0.647800
# Epoch 116, CIFAR-10 Batch 3:  loss is 0.400946, validation accuracy is 0.650400
# Epoch 116, CIFAR-10 Batch 4:  loss is 0.389541, validation accuracy is 0.647800
# Epoch 116, CIFAR-10 Batch 5:  loss is 0.388013, validation accuracy is 0.649200
# Epoch 117, CIFAR-10 Batch 1:  loss is 0.405206, validation accuracy is 0.652200
# Epoch 117, CIFAR-10 Batch 2:  loss is 0.379362, validation accuracy is 0.650600
# Epoch 117, CIFAR-10 Batch 3:  loss is 0.396371, validation accuracy is 0.648600
# Epoch 117, CIFAR-10 Batch 4:  loss is 0.390079, validation accuracy is 0.647400
# Epoch 117, CIFAR-10 Batch 5:  loss is 0.396207, validation accuracy is 0.644600
# Epoch 118, CIFAR-10 Batch 1:  loss is 0.396801, validation accuracy is 0.650200
# Epoch 118, CIFAR-10 Batch 2:  loss is 0.385661, validation accuracy is 0.649000
# Epoch 118, CIFAR-10 Batch 3:  loss is 0.392605, validation accuracy is 0.646400
# Epoch 118, CIFAR-10 Batch 4:  loss is 0.382940, validation accuracy is 0.643800
# Epoch 118, CIFAR-10 Batch 5:  loss is 0.378933, validation accuracy is 0.650200
# Epoch 119, CIFAR-10 Batch 1:  loss is 0.411024, validation accuracy is 0.650600
# Epoch 119, CIFAR-10 Batch 2:  loss is 0.384700, validation accuracy is 0.651800
# Epoch 119, CIFAR-10 Batch 3:  loss is 0.390929, validation accuracy is 0.646000
# Epoch 119, CIFAR-10 Batch 4:  loss is 0.371489, validation accuracy is 0.648000
# Epoch 119, CIFAR-10 Batch 5:  loss is 0.375696, validation accuracy is 0.647800
# Epoch 120, CIFAR-10 Batch 1:  loss is 0.397474, validation accuracy is 0.653000
# Epoch 120, CIFAR-10 Batch 2:  loss is 0.381738, validation accuracy is 0.644800
# Epoch 120, CIFAR-10 Batch 3:  loss is 0.384333, validation accuracy is 0.646600
# Epoch 120, CIFAR-10 Batch 4:  loss is 0.385301, validation accuracy is 0.642200
# Epoch 120, CIFAR-10 Batch 5:  loss is 0.377214, validation accuracy is 0.649800
# Epoch 121, CIFAR-10 Batch 1:  loss is 0.405586, validation accuracy is 0.645000
# Epoch 121, CIFAR-10 Batch 2:  loss is 0.374842, validation accuracy is 0.645600
# Epoch 121, CIFAR-10 Batch 3:  loss is 0.377018, validation accuracy is 0.650800
# Epoch 121, CIFAR-10 Batch 4:  loss is 0.367989, validation accuracy is 0.648800
# Epoch 121, CIFAR-10 Batch 5:  loss is 0.371907, validation accuracy is 0.647000
# Epoch 122, CIFAR-10 Batch 1:  loss is 0.391944, validation accuracy is 0.652000
# ...
# Epoch 161, CIFAR-10 Batch 1:  loss is 0.290154, validation accuracy is 0.647800
# Epoch 161, CIFAR-10 Batch 2:  loss is 0.275879, validation accuracy is 0.656000
# Epoch 161, CIFAR-10 Batch 3:  loss is 0.292958, validation accuracy is 0.646000
# Epoch 161, CIFAR-10 Batch 4:  loss is 0.263629, validation accuracy is 0.652400
# Epoch 161, CIFAR-10 Batch 5:  loss is 0.283745, validation accuracy is 0.651800
# Epoch 162, CIFAR-10 Batch 1:  loss is 0.301924, validation accuracy is 0.654200
# Epoch 162, CIFAR-10 Batch 2:  loss is 0.302018, validation accuracy is 0.646200
# Epoch 162, CIFAR-10 Batch 3:  loss is 0.292963, validation accuracy is 0.648000
# Epoch 162, CIFAR-10 Batch 4:  loss is 0.269994, validation accuracy is 0.655400
# Epoch 162, CIFAR-10 Batch 5:  loss is 0.263347, validation accuracy is 0.656600
# Epoch 163, CIFAR-10 Batch 1:  loss is 0.301096, validation accuracy is 0.652600
# Epoch 163, CIFAR-10 Batch 2:  loss is 0.291278, validation accuracy is 0.649800
# Epoch 163, CIFAR-10 Batch 3:  loss is 0.289943, validation accuracy is 0.651400
# Epoch 163, CIFAR-10 Batch 4:  loss is 0.254267, validation accuracy is 0.655200
# Epoch 163, CIFAR-10 Batch 5:  loss is 0.267859, validation accuracy is 0.654800
# Epoch 164, CIFAR-10 Batch 1:  loss is 0.284715, validation accuracy is 0.658000
# Epoch 164, CIFAR-10 Batch 2:  loss is 0.283059, validation accuracy is 0.656000
# Epoch 164, CIFAR-10 Batch 3:  loss is 0.275144, validation accuracy is 0.649800
# Epoch 164, CIFAR-10 Batch 4:  loss is 0.259945, validation accuracy is 0.656200
# Epoch 164, CIFAR-10 Batch 5:  loss is 0.267374, validation accuracy is 0.649800
# Epoch 165, CIFAR-10 Batch 1:  loss is 0.292981, validation accuracy is 0.651800
# Epoch 165, CIFAR-10 Batch 2:  loss is 0.293037, validation accuracy is 0.650200
# Epoch 165, CIFAR-10 Batch 3:  loss is 0.291854, validation accuracy is 0.643400
# Epoch 165, CIFAR-10 Batch 4:  loss is 0.260995, validation accuracy is 0.652600
# Epoch 165, CIFAR-10 Batch 5:  loss is 0.268293, validation accuracy is 0.652600
# Epoch 166, CIFAR-10 Batch 1:  loss is 0.292615, validation accuracy is 0.657200
# Epoch 166, CIFAR-10 Batch 2:  loss is 0.279687, validation accuracy is 0.654800
# Epoch 166, CIFAR-10 Batch 3:  loss is 0.282244, validation accuracy is 0.656200
# Epoch 166, CIFAR-10 Batch 4:  loss is 0.256693, validation accuracy is 0.654200
# Epoch 166, CIFAR-10 Batch 5:  loss is 0.250799, validation accuracy is 0.655200
# Epoch 167, CIFAR-10 Batch 1:  loss is 0.285938, validation accuracy is 0.653000
# Epoch 167, CIFAR-10 Batch 2:  loss is 0.272298, validation accuracy is 0.657000
# Epoch 167, CIFAR-10 Batch 3:  loss is 0.287668, validation accuracy is 0.654200
# Epoch 167, CIFAR-10 Batch 4:  loss is 0.251646, validation accuracy is 0.659200
# Epoch 167, CIFAR-10 Batch 5:  loss is 0.237540, validation accuracy is 0.657200
# Epoch 168, CIFAR-10 Batch 1:  loss is 0.274408, validation accuracy is 0.654400
# Epoch 168, CIFAR-10 Batch 2:  loss is 0.286466, validation accuracy is 0.657600
# Epoch 168, CIFAR-10 Batch 3:  loss is 0.291169, validation accuracy is 0.650200
# Epoch 168, CIFAR-10 Batch 4:  loss is 0.270478, validation accuracy is 0.646800
# Epoch 168, CIFAR-10 Batch 5:  loss is 0.263774, validation accuracy is 0.649800
# Epoch 169, CIFAR-10 Batch 1:  loss is 0.270922, validation accuracy is 0.657400
# Epoch 169, CIFAR-10 Batch 2:  loss is 0.285954, validation accuracy is 0.646200
# Epoch 169, CIFAR-10 Batch 3:  loss is 0.273934, validation accuracy is 0.648200
# Epoch 169, CIFAR-10 Batch 4:  loss is 0.264501, validation accuracy is 0.647800
# Epoch 169, CIFAR-10 Batch 5:  loss is 0.251615, validation accuracy is 0.654600
# Epoch 170, CIFAR-10 Batch 1:  loss is 0.272535, validation accuracy is 0.659800
# Epoch 170, CIFAR-10 Batch 2:  loss is 0.258957, validation accuracy is 0.656800
# Epoch 170, CIFAR-10 Batch 3:  loss is 0.269459, validation accuracy is 0.649400
# Epoch 170, CIFAR-10 Batch 4:  loss is 0.255206, validation accuracy is 0.650000
# Epoch 170, CIFAR-10 Batch 5:  loss is 0.260367, validation accuracy is 0.649800
# Epoch 171, CIFAR-10 Batch 1:  loss is 0.287621, validation accuracy is 0.647000
# Epoch 171, CIFAR-10 Batch 2:  loss is 0.277458, validation accuracy is 0.649800
# Epoch 171, CIFAR-10 Batch 3:  loss is 0.278501, validation accuracy is 0.645600
# Epoch 171, CIFAR-10 Batch 4:  loss is 0.255057, validation accuracy is 0.654000
# Epoch 171, CIFAR-10 Batch 5:  loss is 0.251219, validation accuracy is 0.653800
# Epoch 172, CIFAR-10 Batch 1:  loss is 0.270511, validation accuracy is 0.657000
# Epoch 172, CIFAR-10 Batch 2:  loss is 0.261587, validation accuracy is 0.654200
# Epoch 172, CIFAR-10 Batch 3:  loss is 0.265592, validation accuracy is 0.650200
# Epoch 172, CIFAR-10 Batch 4:  loss is 0.251069, validation accuracy is 0.653400
# Epoch 172, CIFAR-10 Batch 5:  loss is 0.240751, validation accuracy is 0.650600
# Epoch 173, CIFAR-10 Batch 1:  loss is 0.268709, validation accuracy is 0.645600
# Epoch 173, CIFAR-10 Batch 2:  loss is 0.259947, validation accuracy is 0.649200
# Epoch 173, CIFAR-10 Batch 3:  loss is 0.280636, validation accuracy is 0.648400
# Epoch 173, CIFAR-10 Batch 4:  loss is 0.252490, validation accuracy is 0.657400
# Epoch 173, CIFAR-10 Batch 5:  loss is 0.241393, validation accuracy is 0.651600
# Epoch 174, CIFAR-10 Batch 1:  loss is 0.265197, validation accuracy is 0.656600
# Epoch 174, CIFAR-10 Batch 2:  loss is 0.271547, validation accuracy is 0.650600
# Epoch 174, CIFAR-10 Batch 3:  loss is 0.272959, validation accuracy is 0.647800
# Epoch 174, CIFAR-10 Batch 4:  loss is 0.254075, validation accuracy is 0.652200
# Epoch 174, CIFAR-10 Batch 5:  loss is 0.244275, validation accuracy is 0.652200
# Epoch 175, CIFAR-10 Batch 1:  loss is 0.280267, validation accuracy is 0.652200
# Epoch 175, CIFAR-10 Batch 2:  loss is 0.266851, validation accuracy is 0.649600
# Epoch 175, CIFAR-10 Batch 3:  loss is 0.279094, validation accuracy is 0.642800
# Epoch 175, CIFAR-10 Batch 4:  loss is 0.253690, validation accuracy is 0.648200
# Epoch 175, CIFAR-10 Batch 5:  loss is 0.243513, validation accuracy is 0.652800
# Epoch 176, CIFAR-10 Batch 1:  loss is 0.264478, validation accuracy is 0.657600
# Epoch 176, CIFAR-10 Batch 2:  loss is 0.275621, validation accuracy is 0.652800
# Epoch 176, CIFAR-10 Batch 3:  loss is 0.260433, validation accuracy is 0.654400
# Epoch 176, CIFAR-10 Batch 4:  loss is 0.241304, validation accuracy is 0.653000
# Epoch 176, CIFAR-10 Batch 5:  loss is 0.236480, validation accuracy is 0.655800
# Epoch 177, CIFAR-10 Batch 1:  loss is 0.263459, validation accuracy is 0.652000
# Epoch 177, CIFAR-10 Batch 2:  loss is 0.257087, validation accuracy is 0.655200
# Epoch 177, CIFAR-10 Batch 3:  loss is 0.269994, validation accuracy is 0.652600
# Epoch 177, CIFAR-10 Batch 4:  loss is 0.246449, validation accuracy is 0.654800
# Epoch 177, CIFAR-10 Batch 5:  loss is 0.234218, validation accuracy is 0.657600
# Epoch 178, CIFAR-10 Batch 1:  loss is 0.259013, validation accuracy is 0.652400
# Epoch 178, CIFAR-10 Batch 2:  loss is 0.250700, validation accuracy is 0.653200
# Epoch 178, CIFAR-10 Batch 3:  loss is 0.266097, validation accuracy is 0.643200
# Epoch 178, CIFAR-10 Batch 4:  loss is 0.241616, validation accuracy is 0.660000
# Epoch 178, CIFAR-10 Batch 5:  loss is 0.238580, validation accuracy is 0.658200
# Epoch 179, CIFAR-10 Batch 1:  loss is 0.269794, validation accuracy is 0.649400
# Epoch 179, CIFAR-10 Batch 2:  loss is 0.258291, validation accuracy is 0.654600
# Epoch 179, CIFAR-10 Batch 3:  loss is 0.272220, validation accuracy is 0.643400
# Epoch 179, CIFAR-10 Batch 4:  loss is 0.244224, validation accuracy is 0.656600
# Epoch 179, CIFAR-10 Batch 5:  loss is 0.248212, validation accuracy is 0.658400
# Epoch 180, CIFAR-10 Batch 1:  loss is 0.263400, validation accuracy is 0.658600
# Epoch 180, CIFAR-10 Batch 2:  loss is 0.247805, validation accuracy is 0.652600
# Epoch 180, CIFAR-10 Batch 3:  loss is 0.249222, validation accuracy is 0.654600
# Epoch 180, CIFAR-10 Batch 4:  loss is 0.231916, validation accuracy is 0.656600
# Epoch 180, CIFAR-10 Batch 5:  loss is 0.230322, validation accuracy is 0.655000
# Epoch 181, CIFAR-10 Batch 1:  loss is 0.271808, validation accuracy is 0.650800
# Epoch 181, CIFAR-10 Batch 2:  loss is 0.249461, validation accuracy is 0.653200
# Epoch 181, CIFAR-10 Batch 3:  loss is 0.256721, validation accuracy is 0.651600
# Epoch 181, CIFAR-10 Batch 4:  loss is 0.246815, validation accuracy is 0.655800
# Epoch 181, CIFAR-10 Batch 5:  loss is 0.229996, validation accuracy is 0.651600
# Epoch 182, CIFAR-10 Batch 1:  loss is 0.267205, validation accuracy is 0.649600
# Epoch 182, CIFAR-10 Batch 2:  loss is 0.257949, validation accuracy is 0.649400
# Epoch 182, CIFAR-10 Batch 3:  loss is 0.262077, validation accuracy is 0.645400
# Epoch 182, CIFAR-10 Batch 4:  loss is 0.255181, validation accuracy is 0.649800
# Epoch 182, CIFAR-10 Batch 5:  loss is 0.238988, validation accuracy is 0.644000
# Epoch 183, CIFAR-10 Batch 1:  loss is 0.267348, validation accuracy is 0.654000
# Epoch 183, CIFAR-10 Batch 2:  loss is 0.250461, validation accuracy is 0.654800
# Epoch 183, CIFAR-10 Batch 3:  loss is 0.257033, validation accuracy is 0.655000
# Epoch 183, CIFAR-10 Batch 4:  loss is 0.255559, validation accuracy is 0.649600
# Epoch 183, CIFAR-10 Batch 5:  loss is 0.238262, validation accuracy is 0.644000
# Epoch 184, CIFAR-10 Batch 1:  loss is 0.278033, validation accuracy is 0.649000
# Epoch 184, CIFAR-10 Batch 2:  loss is 0.266981, validation accuracy is 0.652800
# Epoch 184, CIFAR-10 Batch 3:  loss is 0.263896, validation accuracy is 0.644200
# Epoch 184, CIFAR-10 Batch 4:  loss is 0.248113, validation accuracy is 0.656800
# Epoch 184, CIFAR-10 Batch 5:  loss is 0.240670, validation accuracy is 0.646600
# Epoch 185, CIFAR-10 Batch 1:  loss is 0.262071, validation accuracy is 0.651400
# Epoch 185, CIFAR-10 Batch 2:  loss is 0.266515, validation accuracy is 0.655000
# Epoch 185, CIFAR-10 Batch 3:  loss is 0.254216, validation accuracy is 0.649400
# Epoch 185, CIFAR-10 Batch 4:  loss is 0.241317, validation accuracy is 0.655800
# Epoch 185, CIFAR-10 Batch 5:  loss is 0.228586, validation accuracy is 0.652200
# Epoch 186, CIFAR-10 Batch 1:  loss is 0.261614, validation accuracy is 0.656800
# Epoch 186, CIFAR-10 Batch 2:  loss is 0.249402, validation accuracy is 0.655600
# Epoch 186, CIFAR-10 Batch 3:  loss is 0.247845, validation accuracy is 0.650000
# Epoch 186, CIFAR-10 Batch 4:  loss is 0.238424, validation accuracy is 0.657000
# Epoch 186, CIFAR-10 Batch 5:  loss is 0.223902, validation accuracy is 0.654600
# Epoch 187, CIFAR-10 Batch 1:  loss is 0.259715, validation accuracy is 0.651200
# Epoch 187, CIFAR-10 Batch 2:  loss is 0.243037, validation accuracy is 0.658000
# Epoch 187, CIFAR-10 Batch 3:  loss is 0.241338, validation accuracy is 0.652800
# Epoch 187, CIFAR-10 Batch 4:  loss is 0.229108, validation accuracy is 0.653000
# Epoch 187, CIFAR-10 Batch 5:  loss is 0.220783, validation accuracy is 0.656000
# Epoch 188, CIFAR-10 Batch 1:  loss is 0.251615, validation accuracy is 0.652400
# Epoch 188, CIFAR-10 Batch 2:  loss is 0.239734, validation accuracy is 0.659200
# Epoch 188, CIFAR-10 Batch 3:  loss is 0.236638, validation accuracy is 0.655000
# Epoch 188, CIFAR-10 Batch 4:  loss is 0.230344, validation accuracy is 0.653600
# Epoch 188, CIFAR-10 Batch 5:  loss is 0.215927, validation accuracy is 0.655400
# Epoch 189, CIFAR-10 Batch 1:  loss is 0.243081, validation accuracy is 0.657400
# Epoch 189, CIFAR-10 Batch 2:  loss is 0.238594, validation accuracy is 0.659000
# Epoch 189, CIFAR-10 Batch 3:  loss is 0.244081, validation accuracy is 0.650200
# Epoch 189, CIFAR-10 Batch 4:  loss is 0.230942, validation accuracy is 0.653200
# Epoch 189, CIFAR-10 Batch 5:  loss is 0.218160, validation accuracy is 0.655400
# Epoch 190, CIFAR-10 Batch 1:  loss is 0.246233, validation accuracy is 0.652000
# Epoch 190, CIFAR-10 Batch 2:  loss is 0.233512, validation accuracy is 0.660400
# Epoch 190, CIFAR-10 Batch 3:  loss is 0.255223, validation accuracy is 0.642600
# Epoch 190, CIFAR-10 Batch 4:  loss is 0.225054, validation accuracy is 0.654400
# Epoch 190, CIFAR-10 Batch 5:  loss is 0.214248, validation accuracy is 0.652400
# Epoch 191, CIFAR-10 Batch 1:  loss is 0.239153, validation accuracy is 0.659400
# Epoch 191, CIFAR-10 Batch 2:  loss is 0.238022, validation accuracy is 0.653200
# Epoch 191, CIFAR-10 Batch 3:  loss is 0.232372, validation accuracy is 0.656600
# Epoch 191, CIFAR-10 Batch 4:  loss is 0.226569, validation accuracy is 0.653200
# Epoch 191, CIFAR-10 Batch 5:  loss is 0.212664, validation accuracy is 0.653400
# Epoch 192, CIFAR-10 Batch 1:  loss is 0.243875, validation accuracy is 0.653800
# Epoch 192, CIFAR-10 Batch 2:  loss is 0.248814, validation accuracy is 0.649800
# Epoch 192, CIFAR-10 Batch 3:  loss is 0.244472, validation accuracy is 0.648600
# Epoch 192, CIFAR-10 Batch 4:  loss is 0.232537, validation accuracy is 0.652400
# Epoch 192, CIFAR-10 Batch 5:  loss is 0.218564, validation accuracy is 0.653000
# Epoch 193, CIFAR-10 Batch 1:  loss is 0.241636, validation accuracy is 0.652800
# Epoch 193, CIFAR-10 Batch 2:  loss is 0.233122, validation accuracy is 0.659000
# Epoch 193, CIFAR-10 Batch 3:  loss is 0.241051, validation accuracy is 0.648000
# Epoch 193, CIFAR-10 Batch 4:  loss is 0.224137, validation accuracy is 0.655600
# Epoch 193, CIFAR-10 Batch 5:  loss is 0.224519, validation accuracy is 0.654800
# Epoch 194, CIFAR-10 Batch 1:  loss is 0.254138, validation accuracy is 0.649400
# Epoch 194, CIFAR-10 Batch 2:  loss is 0.240331, validation accuracy is 0.649600
# Epoch 194, CIFAR-10 Batch 3:  loss is 0.245224, validation accuracy is 0.647000
# Epoch 194, CIFAR-10 Batch 4:  loss is 0.228675, validation accuracy is 0.655400
# Epoch 194, CIFAR-10 Batch 5:  loss is 0.212279, validation accuracy is 0.652000
# Epoch 195, CIFAR-10 Batch 1:  loss is 0.238842, validation accuracy is 0.646600
# Epoch 195, CIFAR-10 Batch 2:  loss is 0.240834, validation accuracy is 0.651800
# Epoch 195, CIFAR-10 Batch 3:  loss is 0.240033, validation accuracy is 0.648000
# Epoch 195, CIFAR-10 Batch 4:  loss is 0.219173, validation accuracy is 0.653400
# Epoch 195, CIFAR-10 Batch 5:  loss is 0.208199, validation accuracy is 0.654800
# Epoch 196, CIFAR-10 Batch 1:  loss is 0.241313, validation accuracy is 0.649400
# Epoch 196, CIFAR-10 Batch 2:  loss is 0.227255, validation accuracy is 0.654600
# Epoch 196, CIFAR-10 Batch 3:  loss is 0.237613, validation accuracy is 0.647400
# Epoch 196, CIFAR-10 Batch 4:  loss is 0.222796, validation accuracy is 0.654400
# Epoch 196, CIFAR-10 Batch 5:  loss is 0.211915, validation accuracy is 0.655000
# Epoch 197, CIFAR-10 Batch 1:  loss is 0.240491, validation accuracy is 0.651200
# Epoch 197, CIFAR-10 Batch 2:  loss is 0.231013, validation accuracy is 0.656200
# Epoch 197, CIFAR-10 Batch 3:  loss is 0.228665, validation accuracy is 0.651600
# Epoch 197, CIFAR-10 Batch 4:  loss is 0.228187, validation accuracy is 0.649800
# Epoch 197, CIFAR-10 Batch 5:  loss is 0.216750, validation accuracy is 0.657800
# Epoch 198, CIFAR-10 Batch 1:  loss is 0.236044, validation accuracy is 0.654400
# Epoch 198, CIFAR-10 Batch 2:  loss is 0.235157, validation accuracy is 0.651400
# Epoch 198, CIFAR-10 Batch 3:  loss is 0.229592, validation accuracy is 0.650000
# Epoch 198, CIFAR-10 Batch 4:  loss is 0.222681, validation accuracy is 0.652200
# Epoch 198, CIFAR-10 Batch 5:  loss is 0.209354, validation accuracy is 0.648800
# Epoch 199, CIFAR-10 Batch 1:  loss is 0.257394, validation accuracy is 0.643400
# Epoch 199, CIFAR-10 Batch 2:  loss is 0.237073, validation accuracy is 0.651200
# Epoch 199, CIFAR-10 Batch 3:  loss is 0.234322, validation accuracy is 0.649400
# Epoch 199, CIFAR-10 Batch 4:  loss is 0.219695, validation accuracy is 0.653600
# Epoch 199, CIFAR-10 Batch 5:  loss is 0.216278, validation accuracy is 0.652200
# Epoch 200, CIFAR-10 Batch 1:  loss is 0.254571, validation accuracy is 0.647600
# Epoch 200, CIFAR-10 Batch 2:  loss is 0.229157, validation accuracy is 0.654600
# Epoch 200, CIFAR-10 Batch 3:  loss is 0.219845, validation accuracy is 0.657600
# Epoch 200, CIFAR-10 Batch 4:  loss is 0.221472, validation accuracy is 0.648400
# Epoch 200, CIFAR-10 Batch 5:  loss is 0.213894, validation accuracy is 0.655400

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6509458820025126

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
