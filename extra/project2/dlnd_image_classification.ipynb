# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    lower_bound = 0
    higher_bound = 1
    max_val = np.max(x)
    min_val = np.min(x)
    return min_val + (higher_bound - lower_bound) * (x - min_val) / (max_val - min_val)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
label_map = {i : i for i in range(0, 10)}
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    one_hot = np.zeros((len(x), len(label_map)))
    for i in range(len(x)):
        one_hot[i, label_map[x[i]]] = 1
    return one_hot


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, [None, *image_shape], name = "x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, [None, n_classes], name = "y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name = "keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    depth = x_tensor.get_shape().as_list()[-1]
    weight = tf.Variable(tf.truncated_normal([*conv_ksize, depth, conv_num_outputs], stddev = 0.1), name = "conv_weights")
    bias = tf.Variable(tf.truncated_normal([conv_num_outputs], stddev = 0.1), name = "conv_bias")
    layer = tf.nn.conv2d(x_tensor, weight, strides = [1, *conv_strides, 1], padding = "SAME")
    layer = tf.nn.bias_add(layer, bias)
    layer = tf.nn.elu(layer) # that's not a typo, I've intended to use Exponential Linear Unit :)
    layer = tf.nn.max_pool(layer, [1, *pool_ksize, 1], [1, *pool_strides, 1], padding = "SAME")
    return layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# tests.test_con_pool(conv2d_maxpool)
# Out:
# "\nDON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE\n"

# %%
def inception(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides, first_inception_ksize = [3, 3], second_inception_ksize = [5, 5]):
    """
    Apply inception layer as described in GoogLeNeT paper
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    :param first_inception_ksize: kernel size 2-D Tuple for the first convolutional layer after 1x1 conv
    :param second_inception_ksize: kernel size 2-D Tuple for the second convolutional layer after 1x1 conv
    : return: A tensor that represents inception of x_tensor
    """
    depth = x_tensor.get_shape().as_list()[-1]
    sizes = [conv_num_outputs // 4, conv_num_outputs // 4, conv_num_outputs // 4, conv_num_outputs - 3 * conv_num_outputs // 4]
    
    # pooling and 1x1 convolution
    layer1_weight = tf.Variable(tf.truncated_normal([1, 1, depth, sizes[0]], stddev = 0.1))
    layer1 = tf.nn.max_pool(x_tensor, [1, *pool_ksize, 1], [1, *pool_strides, 1], padding = "SAME")
    layer1 = tf.nn.conv2d(layer1, layer1_weight, strides = [1, *conv_strides, 1], padding = "SAME")
    
    # 1x1 convolution
    layer2_weight = tf.Variable(tf.truncated_normal([1, 1, depth, sizes[1]], stddev = 0.1))
    layer2 = tf.nn.conv2d(x_tensor, layer2_weight, strides = [1, *conv_strides, 1], padding = "SAME")

    # 1x1 convolution -> 3x3 convolution (default)
    layer3_weight = tf.Variable(tf.truncated_normal([1, 1, depth, sizes[2]], stddev = 0.1))
    layer3 = tf.nn.conv2d(x_tensor, layer3_weight, strides = [1, *conv_strides, 1], padding = "SAME")
    layer3_1_weight = tf.Variable(tf.truncated_normal([*first_inception_ksize, sizes[2], sizes[2]], stddev = 0.1))
    layer3_1 = tf.nn.conv2d(layer3, layer3_1_weight, strides = [1, *conv_strides, 1], padding = "SAME")
    
    # 1x1 convolutuion -> 5x5 convolution (default)
    layer4_weight = tf.Variable(tf.truncated_normal([1, 1, depth, sizes[3]], stddev = 0.1))
    layer4 = tf.nn.conv2d(x_tensor, layer4_weight, strides = [1, *conv_strides, 1], padding = "SAME")
    layer4_1_weight = tf.Variable(tf.truncated_normal([*second_inception_ksize, sizes[3], sizes[3]], stddev = 0.1))
    layer4_1 = tf.nn.conv2d(layer4, layer4_1_weight, strides = [1, *conv_strides, 1], padding = "SAME")
    
    layer = tf.concat([layer2, layer3, layer4, layer1], 3)

    bias = tf.Variable(tf.truncated_normal([conv_num_outputs], stddev = 0.1), name = "conv_bias")
    layer = tf.nn.bias_add(layer, bias)
    layer = tf.nn.elu(layer)
    return layer

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    b, h, w, d = x_tensor.get_shape().as_list()
    return tf.reshape(x_tensor, [-1, h * w * d])

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weight = tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[1], num_outputs], stddev = 0.1), name = "conn_weight")
    bias = tf.Variable(tf.truncated_normal([num_outputs], stddev = 0.1), name = "conn_bias")
    layer = tf.add(tf.matmul(x_tensor, weight), bias)
    layer = tf.nn.elu(layer)
    return layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weight = tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[1], num_outputs], stddev = 0.1), name = "output_weight")
    bias = tf.Variable(tf.truncated_normal([num_outputs], stddev = 0.1), name = "output_bias")
    return tf.add(tf.matmul(x_tensor, weight), bias)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    layer = conv2d_maxpool(x, 16, [8, 8], [1, 1], [2, 2], [2, 2])
    layer = inception(layer, 32, [5, 5], [1, 1], [8, 8], [1, 1])
    layer = inception(layer, 64, [3, 3], [1, 1], [5, 5], [1, 1])

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    layer = flatten(layer)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    layer = fully_conn(layer, 32)
    layer = tf.nn.dropout(layer, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    layer = output(layer, 10)
    
    # TODO: return output
    return layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict = {x: feature_batch, y: label_batch, keep_prob: keep_probability})
    

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict = {x: feature_batch, y: label_batch, keep_prob: 1.0})
    acc = session.run(accuracy, feed_dict = {x: valid_features, y: valid_labels, keep_prob: 1.0})
    print("loss is {:.6f}, validation accuracy is {:.6f}".format(loss, acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 200
batch_size = 4096
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  loss is 2.334073, validation accuracy is 0.097600
# Epoch  2, CIFAR-10 Batch 1:  loss is 2.317511, validation accuracy is 0.102000
# Epoch  3, CIFAR-10 Batch 1:  loss is 2.280329, validation accuracy is 0.129200
# Epoch  4, CIFAR-10 Batch 1:  loss is 2.236770, validation accuracy is 0.206400
# Epoch  5, CIFAR-10 Batch 1:  loss is 2.207205, validation accuracy is 0.231000
# Epoch  6, CIFAR-10 Batch 1:  loss is 2.172628, validation accuracy is 0.255200
# Epoch  7, CIFAR-10 Batch 1:  loss is 2.116173, validation accuracy is 0.280800
# Epoch  8, CIFAR-10 Batch 1:  loss is 2.057739, validation accuracy is 0.279400
# Epoch  9, CIFAR-10 Batch 1:  loss is 2.009946, validation accuracy is 0.298600
# Epoch 10, CIFAR-10 Batch 1:  loss is 1.970108, validation accuracy is 0.322600
# Epoch 11, CIFAR-10 Batch 1:  loss is 1.939413, validation accuracy is 0.316800
# Epoch 12, CIFAR-10 Batch 1:  loss is 1.900319, validation accuracy is 0.332000
# Epoch 13, CIFAR-10 Batch 1:  loss is 1.862836, validation accuracy is 0.352600
# Epoch 14, CIFAR-10 Batch 1:  loss is 1.835574, validation accuracy is 0.341200
# Epoch 15, CIFAR-10 Batch 1:  loss is 1.795458, validation accuracy is 0.357200
# Epoch 16, CIFAR-10 Batch 1:  loss is 1.772681, validation accuracy is 0.372000
# Epoch 17, CIFAR-10 Batch 1:  loss is 1.748631, validation accuracy is 0.376000
# Epoch 18, CIFAR-10 Batch 1:  loss is 1.711584, validation accuracy is 0.393600
# Epoch 19, CIFAR-10 Batch 1:  loss is 1.695038, validation accuracy is 0.404800
# Epoch 20, CIFAR-10 Batch 1:  loss is 1.675045, validation accuracy is 0.389000
# Epoch 21, CIFAR-10 Batch 1:  loss is 1.633529, validation accuracy is 0.416000
# Epoch 22, CIFAR-10 Batch 1:  loss is 1.608440, validation accuracy is 0.422800
# Epoch 23, CIFAR-10 Batch 1:  loss is 1.595571, validation accuracy is 0.420400
# Epoch 24, CIFAR-10 Batch 1:  loss is 1.584356, validation accuracy is 0.422000
# Epoch 25, CIFAR-10 Batch 1:  loss is 1.540117, validation accuracy is 0.429800
# Epoch 26, CIFAR-10 Batch 1:  loss is 1.521222, validation accuracy is 0.443200
# Epoch 27, CIFAR-10 Batch 1:  loss is 1.500953, validation accuracy is 0.442400
# Epoch 28, CIFAR-10 Batch 1:  loss is 1.484243, validation accuracy is 0.444200
# Epoch 29, CIFAR-10 Batch 1:  loss is 1.470111, validation accuracy is 0.448400
# Epoch 30, CIFAR-10 Batch 1:  loss is 1.445915, validation accuracy is 0.450800
# Epoch 31, CIFAR-10 Batch 1:  loss is 1.427748, validation accuracy is 0.455000
# Epoch 32, CIFAR-10 Batch 1:  loss is 1.400170, validation accuracy is 0.462000
# Epoch 33, CIFAR-10 Batch 1:  loss is 1.390566, validation accuracy is 0.464800
# Epoch 34, CIFAR-10 Batch 1:  loss is 1.379600, validation accuracy is 0.461200
# Epoch 35, CIFAR-10 Batch 1:  loss is 1.363634, validation accuracy is 0.469800
# Epoch 36, CIFAR-10 Batch 1:  loss is 1.342830, validation accuracy is 0.469000
# Epoch 37, CIFAR-10 Batch 1:  loss is 1.325909, validation accuracy is 0.468400
# Epoch 38, CIFAR-10 Batch 1:  loss is 1.314085, validation accuracy is 0.473800
# Epoch 39, CIFAR-10 Batch 1:  loss is 1.308776, validation accuracy is 0.472800
# Epoch 40, CIFAR-10 Batch 1:  loss is 1.291185, validation accuracy is 0.475600
# Epoch 41, CIFAR-10 Batch 1:  loss is 1.285945, validation accuracy is 0.474800
# Epoch 42, CIFAR-10 Batch 1:  loss is 1.270146, validation accuracy is 0.479400
# Epoch 43, CIFAR-10 Batch 1:  loss is 1.254609, validation accuracy is 0.483600
# Epoch 44, CIFAR-10 Batch 1:  loss is 1.240300, validation accuracy is 0.482000
# Epoch 45, CIFAR-10 Batch 1:  loss is 1.224583, validation accuracy is 0.483800
# Epoch 46, CIFAR-10 Batch 1:  loss is 1.217191, validation accuracy is 0.485200
# Epoch 47, CIFAR-10 Batch 1:  loss is 1.218713, validation accuracy is 0.483400
# Epoch 48, CIFAR-10 Batch 1:  loss is 1.191520, validation accuracy is 0.486200
# Epoch 49, CIFAR-10 Batch 1:  loss is 1.184691, validation accuracy is 0.489600
# Epoch 50, CIFAR-10 Batch 1:  loss is 1.151568, validation accuracy is 0.490000
# Epoch 51, CIFAR-10 Batch 1:  loss is 1.148445, validation accuracy is 0.490200
# Epoch 52, CIFAR-10 Batch 1:  loss is 1.146132, validation accuracy is 0.494200
# Epoch 53, CIFAR-10 Batch 1:  loss is 1.130682, validation accuracy is 0.498000
# Epoch 54, CIFAR-10 Batch 1:  loss is 1.120097, validation accuracy is 0.496200
# Epoch 55, CIFAR-10 Batch 1:  loss is 1.098412, validation accuracy is 0.498200
# Epoch 56, CIFAR-10 Batch 1:  loss is 1.085686, validation accuracy is 0.498200
# Epoch 57, CIFAR-10 Batch 1:  loss is 1.074890, validation accuracy is 0.503200
# Epoch 58, CIFAR-10 Batch 1:  loss is 1.062133, validation accuracy is 0.502800
# Epoch 59, CIFAR-10 Batch 1:  loss is 1.046655, validation accuracy is 0.505200
# Epoch 60, CIFAR-10 Batch 1:  loss is 1.061746, validation accuracy is 0.492800
# Epoch 61, CIFAR-10 Batch 1:  loss is 1.032915, validation accuracy is 0.507600
# Epoch 62, CIFAR-10 Batch 1:  loss is 1.016158, validation accuracy is 0.505600
# Epoch 63, CIFAR-10 Batch 1:  loss is 1.007892, validation accuracy is 0.505600
# Epoch 64, CIFAR-10 Batch 1:  loss is 1.007667, validation accuracy is 0.505400
# Epoch 65, CIFAR-10 Batch 1:  loss is 0.987667, validation accuracy is 0.510000
# Epoch 66, CIFAR-10 Batch 1:  loss is 0.986524, validation accuracy is 0.509600
# Epoch 67, CIFAR-10 Batch 1:  loss is 0.976183, validation accuracy is 0.506000
# Epoch 68, CIFAR-10 Batch 1:  loss is 0.959270, validation accuracy is 0.505600
# Epoch 69, CIFAR-10 Batch 1:  loss is 0.942922, validation accuracy is 0.516200
# Epoch 70, CIFAR-10 Batch 1:  loss is 0.944371, validation accuracy is 0.514400
# Epoch 71, CIFAR-10 Batch 1:  loss is 0.914717, validation accuracy is 0.520000
# Epoch 72, CIFAR-10 Batch 1:  loss is 0.919991, validation accuracy is 0.505800
# Epoch 73, CIFAR-10 Batch 1:  loss is 0.908844, validation accuracy is 0.521400
# Epoch 74, CIFAR-10 Batch 1:  loss is 0.908365, validation accuracy is 0.516800
# Epoch 75, CIFAR-10 Batch 1:  loss is 0.877949, validation accuracy is 0.517200
# Epoch 76, CIFAR-10 Batch 1:  loss is 0.876388, validation accuracy is 0.515400
# Epoch 77, CIFAR-10 Batch 1:  loss is 0.859671, validation accuracy is 0.523600
# Epoch 78, CIFAR-10 Batch 1:  loss is 0.859602, validation accuracy is 0.525800
# Epoch 79, CIFAR-10 Batch 1:  loss is 0.841879, validation accuracy is 0.523400
# Epoch 80, CIFAR-10 Batch 1:  loss is 0.831364, validation accuracy is 0.526600
# Epoch 81, CIFAR-10 Batch 1:  loss is 0.825300, validation accuracy is 0.527600
# Epoch 82, CIFAR-10 Batch 1:  loss is 0.818312, validation accuracy is 0.525600
# Epoch 83, CIFAR-10 Batch 1:  loss is 0.811628, validation accuracy is 0.535800
# Epoch 84, CIFAR-10 Batch 1:  loss is 0.794180, validation accuracy is 0.530000
# Epoch 85, CIFAR-10 Batch 1:  loss is 0.794884, validation accuracy is 0.534000
# Epoch 86, CIFAR-10 Batch 1:  loss is 0.783839, validation accuracy is 0.533600
# Epoch 87, CIFAR-10 Batch 1:  loss is 0.767974, validation accuracy is 0.529200
# Epoch 88, CIFAR-10 Batch 1:  loss is 0.766617, validation accuracy is 0.532800
# Epoch 89, CIFAR-10 Batch 1:  loss is 0.752434, validation accuracy is 0.537600
# Epoch 90, CIFAR-10 Batch 1:  loss is 0.746558, validation accuracy is 0.536000
# Epoch 91, CIFAR-10 Batch 1:  loss is 0.742600, validation accuracy is 0.531200
# Epoch 92, CIFAR-10 Batch 1:  loss is 0.748494, validation accuracy is 0.524600
# Epoch 93, CIFAR-10 Batch 1:  loss is 0.726726, validation accuracy is 0.531200
# Epoch 94, CIFAR-10 Batch 1:  loss is 0.711282, validation accuracy is 0.536800
# Epoch 95, CIFAR-10 Batch 1:  loss is 0.706205, validation accuracy is 0.539800
# Epoch 96, CIFAR-10 Batch 1:  loss is 0.704225, validation accuracy is 0.535400
# Epoch 97, CIFAR-10 Batch 1:  loss is 0.696423, validation accuracy is 0.533800
# Epoch 98, CIFAR-10 Batch 1:  loss is 0.679154, validation accuracy is 0.539600
# Epoch 99, CIFAR-10 Batch 1:  loss is 0.684183, validation accuracy is 0.542400
# Epoch 100, CIFAR-10 Batch 1:  loss is 0.662305, validation accuracy is 0.537200
# Epoch 101, CIFAR-10 Batch 1:  loss is 0.649966, validation accuracy is 0.544600
# Epoch 102, CIFAR-10 Batch 1:  loss is 0.639876, validation accuracy is 0.543800
# Epoch 103, CIFAR-10 Batch 1:  loss is 0.637962, validation accuracy is 0.543200
# Epoch 104, CIFAR-10 Batch 1:  loss is 0.623559, validation accuracy is 0.539600
# Epoch 105, CIFAR-10 Batch 1:  loss is 0.623704, validation accuracy is 0.544800
# Epoch 106, CIFAR-10 Batch 1:  loss is 0.616192, validation accuracy is 0.541400
# Epoch 107, CIFAR-10 Batch 1:  loss is 0.598027, validation accuracy is 0.551600
# Epoch 108, CIFAR-10 Batch 1:  loss is 0.586643, validation accuracy is 0.545200
# Epoch 109, CIFAR-10 Batch 1:  loss is 0.588066, validation accuracy is 0.549200
# Epoch 110, CIFAR-10 Batch 1:  loss is 0.587222, validation accuracy is 0.547000
# Epoch 111, CIFAR-10 Batch 1:  loss is 0.568680, validation accuracy is 0.552600
# Epoch 112, CIFAR-10 Batch 1:  loss is 0.570890, validation accuracy is 0.546000
# Epoch 113, CIFAR-10 Batch 1:  loss is 0.557300, validation accuracy is 0.553000
# Epoch 114, CIFAR-10 Batch 1:  loss is 0.548049, validation accuracy is 0.551000
# Epoch 115, CIFAR-10 Batch 1:  loss is 0.548761, validation accuracy is 0.547400
# Epoch 116, CIFAR-10 Batch 1:  loss is 0.540830, validation accuracy is 0.548600
# Epoch 117, CIFAR-10 Batch 1:  loss is 0.531044, validation accuracy is 0.547400
# Epoch 118, CIFAR-10 Batch 1:  loss is 0.547044, validation accuracy is 0.540600
# Epoch 119, CIFAR-10 Batch 1:  loss is 0.536121, validation accuracy is 0.546000
# Epoch 120, CIFAR-10 Batch 1:  loss is 0.516894, validation accuracy is 0.557000
# Epoch 121, CIFAR-10 Batch 1:  loss is 0.504041, validation accuracy is 0.560200
# Epoch 122, CIFAR-10 Batch 1:  loss is 0.495497, validation accuracy is 0.554800
# Epoch 123, CIFAR-10 Batch 1:  loss is 0.494734, validation accuracy is 0.553200
# Epoch 124, CIFAR-10 Batch 1:  loss is 0.488180, validation accuracy is 0.552400
# Epoch 125, CIFAR-10 Batch 1:  loss is 0.489343, validation accuracy is 0.555200
# Epoch 126, CIFAR-10 Batch 1:  loss is 0.477436, validation accuracy is 0.553000
# Epoch 127, CIFAR-10 Batch 1:  loss is 0.470278, validation accuracy is 0.555000
# Epoch 128, CIFAR-10 Batch 1:  loss is 0.484247, validation accuracy is 0.548600
# Epoch 129, CIFAR-10 Batch 1:  loss is 0.491236, validation accuracy is 0.538200
# Epoch 130, CIFAR-10 Batch 1:  loss is 0.460011, validation accuracy is 0.551600
# Epoch 131, CIFAR-10 Batch 1:  loss is 0.473872, validation accuracy is 0.550600
# Epoch 132, CIFAR-10 Batch 1:  loss is 0.461668, validation accuracy is 0.556600
# Epoch 133, CIFAR-10 Batch 1:  loss is 0.452098, validation accuracy is 0.546800
# Epoch 134, CIFAR-10 Batch 1:  loss is 0.440311, validation accuracy is 0.561000
# Epoch 135, CIFAR-10 Batch 1:  loss is 0.438327, validation accuracy is 0.549800
# Epoch 136, CIFAR-10 Batch 1:  loss is 0.436913, validation accuracy is 0.549600
# Epoch 137, CIFAR-10 Batch 1:  loss is 0.431644, validation accuracy is 0.554000
# Epoch 138, CIFAR-10 Batch 1:  loss is 0.419813, validation accuracy is 0.557600
# Epoch 139, CIFAR-10 Batch 1:  loss is 0.410552, validation accuracy is 0.557400
# Epoch 140, CIFAR-10 Batch 1:  loss is 0.404657, validation accuracy is 0.564600
# Epoch 141, CIFAR-10 Batch 1:  loss is 0.398699, validation accuracy is 0.562600
# Epoch 142, CIFAR-10 Batch 1:  loss is 0.390235, validation accuracy is 0.558000
# Epoch 143, CIFAR-10 Batch 1:  loss is 0.387421, validation accuracy is 0.561600
# Epoch 144, CIFAR-10 Batch 1:  loss is 0.388131, validation accuracy is 0.560000
# Epoch 145, CIFAR-10 Batch 1:  loss is 0.390301, validation accuracy is 0.558000
# Epoch 146, CIFAR-10 Batch 1:  loss is 0.382020, validation accuracy is 0.562000
# Epoch 147, CIFAR-10 Batch 1:  loss is 0.370660, validation accuracy is 0.559000
# Epoch 148, CIFAR-10 Batch 1:  loss is 0.356923, validation accuracy is 0.563400
# Epoch 149, CIFAR-10 Batch 1:  loss is 0.363921, validation accuracy is 0.565800
# Epoch 150, CIFAR-10 Batch 1:  loss is 0.371087, validation accuracy is 0.557000
# Epoch 151, CIFAR-10 Batch 1:  loss is 0.351661, validation accuracy is 0.561600
# Epoch 152, CIFAR-10 Batch 1:  loss is 0.352272, validation accuracy is 0.560000
# Epoch 153, CIFAR-10 Batch 1:  loss is 0.348866, validation accuracy is 0.559800
# Epoch 154, CIFAR-10 Batch 1:  loss is 0.343872, validation accuracy is 0.568400
# Epoch 155, CIFAR-10 Batch 1:  loss is 0.336637, validation accuracy is 0.564600
# Epoch 156, CIFAR-10 Batch 1:  loss is 0.330625, validation accuracy is 0.566000
# Epoch 157, CIFAR-10 Batch 1:  loss is 0.333062, validation accuracy is 0.566200
# Epoch 158, CIFAR-10 Batch 1:  loss is 0.332969, validation accuracy is 0.559200
# Epoch 159, CIFAR-10 Batch 1:  loss is 0.338916, validation accuracy is 0.559600
# Epoch 160, CIFAR-10 Batch 1:  loss is 0.321602, validation accuracy is 0.564600
# Epoch 161, CIFAR-10 Batch 1:  loss is 0.308312, validation accuracy is 0.570000
# Epoch 162, CIFAR-10 Batch 1:  loss is 0.304694, validation accuracy is 0.568400
# Epoch 163, CIFAR-10 Batch 1:  loss is 0.305499, validation accuracy is 0.559600
# Epoch 164, CIFAR-10 Batch 1:  loss is 0.304032, validation accuracy is 0.567600
# Epoch 165, CIFAR-10 Batch 1:  loss is 0.294433, validation accuracy is 0.565800
# Epoch 166, CIFAR-10 Batch 1:  loss is 0.295720, validation accuracy is 0.567000
# Epoch 167, CIFAR-10 Batch 1:  loss is 0.287467, validation accuracy is 0.571400
# Epoch 168, CIFAR-10 Batch 1:  loss is 0.293861, validation accuracy is 0.564800
# Epoch 169, CIFAR-10 Batch 1:  loss is 0.286575, validation accuracy is 0.570200
# Epoch 170, CIFAR-10 Batch 1:  loss is 0.278706, validation accuracy is 0.569200
# Epoch 171, CIFAR-10 Batch 1:  loss is 0.274276, validation accuracy is 0.568400
# Epoch 172, CIFAR-10 Batch 1:  loss is 0.284876, validation accuracy is 0.568800
# Epoch 173, CIFAR-10 Batch 1:  loss is 0.273907, validation accuracy is 0.569200
# Epoch 174, CIFAR-10 Batch 1:  loss is 0.270443, validation accuracy is 0.571400
# Epoch 175, CIFAR-10 Batch 1:  loss is 0.261115, validation accuracy is 0.568600
# Epoch 176, CIFAR-10 Batch 1:  loss is 0.268083, validation accuracy is 0.566800
# Epoch 177, CIFAR-10 Batch 1:  loss is 0.261399, validation accuracy is 0.567600
# Epoch 178, CIFAR-10 Batch 1:  loss is 0.268645, validation accuracy is 0.560800
# Epoch 179, CIFAR-10 Batch 1:  loss is 0.253341, validation accuracy is 0.568400
# Epoch 180, CIFAR-10 Batch 1:  loss is 0.252576, validation accuracy is 0.571000
# Epoch 181, CIFAR-10 Batch 1:  loss is 0.261423, validation accuracy is 0.562200
# Epoch 182, CIFAR-10 Batch 1:  loss is 0.246541, validation accuracy is 0.569800
# Epoch 183, CIFAR-10 Batch 1:  loss is 0.235396, validation accuracy is 0.570200
# Epoch 184, CIFAR-10 Batch 1:  loss is 0.235996, validation accuracy is 0.571800
# Epoch 185, CIFAR-10 Batch 1:  loss is 0.232995, validation accuracy is 0.573400
# Epoch 186, CIFAR-10 Batch 1:  loss is 0.232226, validation accuracy is 0.568800
# Epoch 187, CIFAR-10 Batch 1:  loss is 0.229694, validation accuracy is 0.573600
# Epoch 188, CIFAR-10 Batch 1:  loss is 0.224511, validation accuracy is 0.570200
# Epoch 189, CIFAR-10 Batch 1:  loss is 0.216871, validation accuracy is 0.570200
# Epoch 190, CIFAR-10 Batch 1:  loss is 0.215404, validation accuracy is 0.573600
# Epoch 191, CIFAR-10 Batch 1:  loss is 0.213856, validation accuracy is 0.573200
# Epoch 192, CIFAR-10 Batch 1:  loss is 0.222565, validation accuracy is 0.564800
# Epoch 193, CIFAR-10 Batch 1:  loss is 0.235067, validation accuracy is 0.559200
# Epoch 194, CIFAR-10 Batch 1:  loss is 0.205208, validation accuracy is 0.574200
# Epoch 195, CIFAR-10 Batch 1:  loss is 0.227198, validation accuracy is 0.562800
# Epoch 196, CIFAR-10 Batch 1:  loss is 0.203976, validation accuracy is 0.571000
# Epoch 197, CIFAR-10 Batch 1:  loss is 0.213566, validation accuracy is 0.564400
# Epoch 198, CIFAR-10 Batch 1:  loss is 0.203101, validation accuracy is 0.572800
# Epoch 199, CIFAR-10 Batch 1:  loss is 0.214692, validation accuracy is 0.562600
# Epoch 200, CIFAR-10 Batch 1:  loss is 0.214264, validation accuracy is 0.557400

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  loss is 2.332885, validation accuracy is 0.087800
# Epoch  1, CIFAR-10 Batch 2:  loss is 2.294014, validation accuracy is 0.106800
# Epoch  1, CIFAR-10 Batch 3:  loss is 2.282365, validation accuracy is 0.160600
# Epoch  1, CIFAR-10 Batch 4:  loss is 2.251482, validation accuracy is 0.194000
# Epoch  1, CIFAR-10 Batch 5:  loss is 2.218208, validation accuracy is 0.197800
# Epoch  2, CIFAR-10 Batch 1:  loss is 2.184315, validation accuracy is 0.241600
# Epoch  2, CIFAR-10 Batch 2:  loss is 2.148141, validation accuracy is 0.268800
# Epoch  2, CIFAR-10 Batch 3:  loss is 2.101785, validation accuracy is 0.250400
# Epoch  2, CIFAR-10 Batch 4:  loss is 2.088374, validation accuracy is 0.252400
# Epoch  2, CIFAR-10 Batch 5:  loss is 2.048283, validation accuracy is 0.272000
# Epoch  3, CIFAR-10 Batch 1:  loss is 2.013714, validation accuracy is 0.312600
# Epoch  3, CIFAR-10 Batch 2:  loss is 1.979199, validation accuracy is 0.301600
# Epoch  3, CIFAR-10 Batch 3:  loss is 1.904350, validation accuracy is 0.319600
# Epoch  3, CIFAR-10 Batch 4:  loss is 1.888663, validation accuracy is 0.342800
# Epoch  3, CIFAR-10 Batch 5:  loss is 1.893634, validation accuracy is 0.353400
# Epoch  4, CIFAR-10 Batch 1:  loss is 1.851508, validation accuracy is 0.356200
# Epoch  4, CIFAR-10 Batch 2:  loss is 1.809687, validation accuracy is 0.357600
# Epoch  4, CIFAR-10 Batch 3:  loss is 1.802275, validation accuracy is 0.369000
# Epoch  4, CIFAR-10 Batch 4:  loss is 1.774385, validation accuracy is 0.362000
# Epoch  4, CIFAR-10 Batch 5:  loss is 1.778453, validation accuracy is 0.392600
# Epoch  5, CIFAR-10 Batch 1:  loss is 1.760082, validation accuracy is 0.390400
# Epoch  5, CIFAR-10 Batch 2:  loss is 1.725473, validation accuracy is 0.393800
# Epoch  5, CIFAR-10 Batch 3:  loss is 1.692124, validation accuracy is 0.389200
# Epoch  5, CIFAR-10 Batch 4:  loss is 1.692037, validation accuracy is 0.395400
# Epoch  5, CIFAR-10 Batch 5:  loss is 1.704458, validation accuracy is 0.417000
# Epoch  6, CIFAR-10 Batch 1:  loss is 1.691943, validation accuracy is 0.406400
# Epoch  6, CIFAR-10 Batch 2:  loss is 1.657183, validation accuracy is 0.419600
# Epoch  6, CIFAR-10 Batch 3:  loss is 1.629978, validation accuracy is 0.415800
# Epoch  6, CIFAR-10 Batch 4:  loss is 1.627608, validation accuracy is 0.417600
# Epoch  6, CIFAR-10 Batch 5:  loss is 1.647869, validation accuracy is 0.434800
# Epoch  7, CIFAR-10 Batch 1:  loss is 1.636783, validation accuracy is 0.434200
# Epoch  7, CIFAR-10 Batch 2:  loss is 1.595102, validation accuracy is 0.429800
# Epoch  7, CIFAR-10 Batch 3:  loss is 1.580319, validation accuracy is 0.435200
# Epoch  7, CIFAR-10 Batch 4:  loss is 1.583546, validation accuracy is 0.424000
# Epoch  7, CIFAR-10 Batch 5:  loss is 1.595969, validation accuracy is 0.455400
# Epoch  8, CIFAR-10 Batch 1:  loss is 1.583819, validation accuracy is 0.445800
# Epoch  8, CIFAR-10 Batch 2:  loss is 1.543480, validation accuracy is 0.454600
# Epoch  8, CIFAR-10 Batch 3:  loss is 1.528903, validation accuracy is 0.451800
# Epoch  8, CIFAR-10 Batch 4:  loss is 1.523087, validation accuracy is 0.446000
# Epoch  8, CIFAR-10 Batch 5:  loss is 1.550282, validation accuracy is 0.456200
# Epoch  9, CIFAR-10 Batch 1:  loss is 1.530482, validation accuracy is 0.458200
# Epoch  9, CIFAR-10 Batch 2:  loss is 1.502244, validation accuracy is 0.462600
# Epoch  9, CIFAR-10 Batch 3:  loss is 1.501227, validation accuracy is 0.467800
# Epoch  9, CIFAR-10 Batch 4:  loss is 1.480256, validation accuracy is 0.467200
# Epoch  9, CIFAR-10 Batch 5:  loss is 1.513502, validation accuracy is 0.467000
# Epoch 10, CIFAR-10 Batch 1:  loss is 1.493681, validation accuracy is 0.468200
# Epoch 10, CIFAR-10 Batch 2:  loss is 1.464127, validation accuracy is 0.469400
# Epoch 10, CIFAR-10 Batch 3:  loss is 1.470790, validation accuracy is 0.467600
# Epoch 10, CIFAR-10 Batch 4:  loss is 1.455919, validation accuracy is 0.469000
# Epoch 10, CIFAR-10 Batch 5:  loss is 1.479574, validation accuracy is 0.473200
# Epoch 11, CIFAR-10 Batch 1:  loss is 1.457268, validation accuracy is 0.481000
# Epoch 11, CIFAR-10 Batch 2:  loss is 1.448969, validation accuracy is 0.474800
# Epoch 11, CIFAR-10 Batch 3:  loss is 1.432886, validation accuracy is 0.476400
# Epoch 11, CIFAR-10 Batch 4:  loss is 1.430241, validation accuracy is 0.479600
# Epoch 11, CIFAR-10 Batch 5:  loss is 1.448663, validation accuracy is 0.490400
# Epoch 12, CIFAR-10 Batch 1:  loss is 1.422533, validation accuracy is 0.488200
# Epoch 12, CIFAR-10 Batch 2:  loss is 1.405624, validation accuracy is 0.488800
# Epoch 12, CIFAR-10 Batch 3:  loss is 1.399488, validation accuracy is 0.493200
# Epoch 12, CIFAR-10 Batch 4:  loss is 1.389953, validation accuracy is 0.487800
# Epoch 12, CIFAR-10 Batch 5:  loss is 1.425055, validation accuracy is 0.492800
# Epoch 13, CIFAR-10 Batch 1:  loss is 1.399703, validation accuracy is 0.491200
# Epoch 13, CIFAR-10 Batch 2:  loss is 1.379596, validation accuracy is 0.502200
# Epoch 13, CIFAR-10 Batch 3:  loss is 1.367024, validation accuracy is 0.495000
# Epoch 13, CIFAR-10 Batch 4:  loss is 1.363947, validation accuracy is 0.500600
# Epoch 13, CIFAR-10 Batch 5:  loss is 1.404875, validation accuracy is 0.501600
# Epoch 14, CIFAR-10 Batch 1:  loss is 1.360039, validation accuracy is 0.503400
# Epoch 14, CIFAR-10 Batch 2:  loss is 1.357946, validation accuracy is 0.505400
# Epoch 14, CIFAR-10 Batch 3:  loss is 1.350799, validation accuracy is 0.498000
# Epoch 14, CIFAR-10 Batch 4:  loss is 1.335860, validation accuracy is 0.500200
# Epoch 14, CIFAR-10 Batch 5:  loss is 1.377216, validation accuracy is 0.510000
# Epoch 15, CIFAR-10 Batch 1:  loss is 1.346064, validation accuracy is 0.517600
# Epoch 15, CIFAR-10 Batch 2:  loss is 1.334088, validation accuracy is 0.507200
# Epoch 15, CIFAR-10 Batch 3:  loss is 1.338517, validation accuracy is 0.502600
# Epoch 15, CIFAR-10 Batch 4:  loss is 1.311173, validation accuracy is 0.509600
# Epoch 15, CIFAR-10 Batch 5:  loss is 1.351675, validation accuracy is 0.512000
# Epoch 16, CIFAR-10 Batch 1:  loss is 1.308452, validation accuracy is 0.511400
# Epoch 16, CIFAR-10 Batch 2:  loss is 1.316646, validation accuracy is 0.517000
# Epoch 16, CIFAR-10 Batch 3:  loss is 1.303958, validation accuracy is 0.512800
# Epoch 16, CIFAR-10 Batch 4:  loss is 1.286839, validation accuracy is 0.519400
# Epoch 16, CIFAR-10 Batch 5:  loss is 1.327440, validation accuracy is 0.516400
# Epoch 17, CIFAR-10 Batch 1:  loss is 1.293435, validation accuracy is 0.520800
# Epoch 17, CIFAR-10 Batch 2:  loss is 1.290639, validation accuracy is 0.516600
# Epoch 17, CIFAR-10 Batch 3:  loss is 1.286119, validation accuracy is 0.523600
# Epoch 17, CIFAR-10 Batch 4:  loss is 1.276463, validation accuracy is 0.518600
# Epoch 17, CIFAR-10 Batch 5:  loss is 1.312417, validation accuracy is 0.516800
# Epoch 18, CIFAR-10 Batch 1:  loss is 1.276909, validation accuracy is 0.520000
# Epoch 18, CIFAR-10 Batch 2:  loss is 1.272451, validation accuracy is 0.528800
# Epoch 18, CIFAR-10 Batch 3:  loss is 1.268805, validation accuracy is 0.519800
# Epoch 18, CIFAR-10 Batch 4:  loss is 1.247266, validation accuracy is 0.524600
# Epoch 18, CIFAR-10 Batch 5:  loss is 1.299097, validation accuracy is 0.522400
# Epoch 19, CIFAR-10 Batch 1:  loss is 1.253109, validation accuracy is 0.529400
# Epoch 19, CIFAR-10 Batch 2:  loss is 1.260233, validation accuracy is 0.523000
# Epoch 19, CIFAR-10 Batch 3:  loss is 1.245991, validation accuracy is 0.528600
# Epoch 19, CIFAR-10 Batch 4:  loss is 1.226106, validation accuracy is 0.530000
# Epoch 19, CIFAR-10 Batch 5:  loss is 1.284683, validation accuracy is 0.526200
# Epoch 20, CIFAR-10 Batch 1:  loss is 1.227917, validation accuracy is 0.537800
# Epoch 20, CIFAR-10 Batch 2:  loss is 1.233748, validation accuracy is 0.538400
# Epoch 20, CIFAR-10 Batch 3:  loss is 1.231172, validation accuracy is 0.537600
# Epoch 20, CIFAR-10 Batch 4:  loss is 1.207678, validation accuracy is 0.533600
# Epoch 20, CIFAR-10 Batch 5:  loss is 1.263846, validation accuracy is 0.529800
# Epoch 21, CIFAR-10 Batch 1:  loss is 1.218894, validation accuracy is 0.535000
# Epoch 21, CIFAR-10 Batch 2:  loss is 1.212513, validation accuracy is 0.538800
# Epoch 21, CIFAR-10 Batch 3:  loss is 1.205548, validation accuracy is 0.534200
# Epoch 21, CIFAR-10 Batch 4:  loss is 1.196530, validation accuracy is 0.543000
# Epoch 21, CIFAR-10 Batch 5:  loss is 1.237683, validation accuracy is 0.539600
# Epoch 22, CIFAR-10 Batch 1:  loss is 1.199471, validation accuracy is 0.543000
# Epoch 22, CIFAR-10 Batch 2:  loss is 1.196514, validation accuracy is 0.536600
# Epoch 22, CIFAR-10 Batch 3:  loss is 1.193309, validation accuracy is 0.542200
# Epoch 22, CIFAR-10 Batch 4:  loss is 1.172580, validation accuracy is 0.549200
# Epoch 22, CIFAR-10 Batch 5:  loss is 1.223762, validation accuracy is 0.537800
# Epoch 23, CIFAR-10 Batch 1:  loss is 1.183789, validation accuracy is 0.547400
# Epoch 23, CIFAR-10 Batch 2:  loss is 1.188603, validation accuracy is 0.534600
# Epoch 23, CIFAR-10 Batch 3:  loss is 1.174557, validation accuracy is 0.551000
# Epoch 23, CIFAR-10 Batch 4:  loss is 1.156654, validation accuracy is 0.548200
# Epoch 23, CIFAR-10 Batch 5:  loss is 1.203821, validation accuracy is 0.544200
# Epoch 24, CIFAR-10 Batch 1:  loss is 1.178381, validation accuracy is 0.542000
# Epoch 24, CIFAR-10 Batch 2:  loss is 1.170561, validation accuracy is 0.546200
# Epoch 24, CIFAR-10 Batch 3:  loss is 1.152799, validation accuracy is 0.552800
# Epoch 24, CIFAR-10 Batch 4:  loss is 1.138024, validation accuracy is 0.551200
# Epoch 24, CIFAR-10 Batch 5:  loss is 1.175580, validation accuracy is 0.546000
# Epoch 25, CIFAR-10 Batch 1:  loss is 1.150602, validation accuracy is 0.549800
# Epoch 25, CIFAR-10 Batch 2:  loss is 1.154150, validation accuracy is 0.555600
# Epoch 25, CIFAR-10 Batch 3:  loss is 1.137094, validation accuracy is 0.552000
# Epoch 25, CIFAR-10 Batch 4:  loss is 1.130681, validation accuracy is 0.548400
# Epoch 25, CIFAR-10 Batch 5:  loss is 1.165961, validation accuracy is 0.548600
# Epoch 26, CIFAR-10 Batch 1:  loss is 1.141360, validation accuracy is 0.551600
# Epoch 26, CIFAR-10 Batch 2:  loss is 1.166847, validation accuracy is 0.545800
# Epoch 26, CIFAR-10 Batch 3:  loss is 1.121748, validation accuracy is 0.557000
# Epoch 26, CIFAR-10 Batch 4:  loss is 1.096906, validation accuracy is 0.556800
# Epoch 26, CIFAR-10 Batch 5:  loss is 1.139454, validation accuracy is 0.555000
# Epoch 27, CIFAR-10 Batch 1:  loss is 1.114988, validation accuracy is 0.562400
# Epoch 27, CIFAR-10 Batch 2:  loss is 1.149985, validation accuracy is 0.546800
# Epoch 27, CIFAR-10 Batch 3:  loss is 1.109433, validation accuracy is 0.560000
# Epoch 27, CIFAR-10 Batch 4:  loss is 1.092676, validation accuracy is 0.557400
# Epoch 27, CIFAR-10 Batch 5:  loss is 1.128257, validation accuracy is 0.556600
# Epoch 28, CIFAR-10 Batch 1:  loss is 1.114850, validation accuracy is 0.560600
# Epoch 28, CIFAR-10 Batch 2:  loss is 1.104996, validation accuracy is 0.563600
# Epoch 28, CIFAR-10 Batch 3:  loss is 1.095383, validation accuracy is 0.561800
# Epoch 28, CIFAR-10 Batch 4:  loss is 1.077179, validation accuracy is 0.560200
# Epoch 28, CIFAR-10 Batch 5:  loss is 1.113729, validation accuracy is 0.561600
# Epoch 29, CIFAR-10 Batch 1:  loss is 1.097384, validation accuracy is 0.560000
# Epoch 29, CIFAR-10 Batch 2:  loss is 1.099177, validation accuracy is 0.565000
# Epoch 29, CIFAR-10 Batch 3:  loss is 1.091620, validation accuracy is 0.556200
# Epoch 29, CIFAR-10 Batch 4:  loss is 1.062048, validation accuracy is 0.568400
# Epoch 29, CIFAR-10 Batch 5:  loss is 1.102705, validation accuracy is 0.561800
# Epoch 30, CIFAR-10 Batch 1:  loss is 1.083135, validation accuracy is 0.563800
# Epoch 30, CIFAR-10 Batch 2:  loss is 1.080345, validation accuracy is 0.563400
# Epoch 30, CIFAR-10 Batch 3:  loss is 1.056267, validation accuracy is 0.565800
# Epoch 30, CIFAR-10 Batch 4:  loss is 1.047323, validation accuracy is 0.573400
# Epoch 30, CIFAR-10 Batch 5:  loss is 1.080936, validation accuracy is 0.568000
# Epoch 31, CIFAR-10 Batch 1:  loss is 1.068357, validation accuracy is 0.569000
# Epoch 31, CIFAR-10 Batch 2:  loss is 1.058913, validation accuracy is 0.566200
# Epoch 31, CIFAR-10 Batch 3:  loss is 1.046537, validation accuracy is 0.571600
# Epoch 31, CIFAR-10 Batch 4:  loss is 1.032721, validation accuracy is 0.574800
# Epoch 31, CIFAR-10 Batch 5:  loss is 1.059720, validation accuracy is 0.567800
# Epoch 32, CIFAR-10 Batch 1:  loss is 1.063078, validation accuracy is 0.567400
# Epoch 32, CIFAR-10 Batch 2:  loss is 1.054087, validation accuracy is 0.567200
# Epoch 32, CIFAR-10 Batch 3:  loss is 1.049687, validation accuracy is 0.565600
# Epoch 32, CIFAR-10 Batch 4:  loss is 1.033345, validation accuracy is 0.572600
# Epoch 32, CIFAR-10 Batch 5:  loss is 1.062301, validation accuracy is 0.564000
# Epoch 33, CIFAR-10 Batch 1:  loss is 1.057639, validation accuracy is 0.565400
# Epoch 33, CIFAR-10 Batch 2:  loss is 1.046056, validation accuracy is 0.573400
# Epoch 33, CIFAR-10 Batch 3:  loss is 1.048631, validation accuracy is 0.563400
# Epoch 33, CIFAR-10 Batch 4:  loss is 1.020131, validation accuracy is 0.570400
# Epoch 33, CIFAR-10 Batch 5:  loss is 1.048136, validation accuracy is 0.569800
# Epoch 34, CIFAR-10 Batch 1:  loss is 1.038081, validation accuracy is 0.572200
# Epoch 34, CIFAR-10 Batch 2:  loss is 1.033950, validation accuracy is 0.576800
# Epoch 34, CIFAR-10 Batch 3:  loss is 1.005032, validation accuracy is 0.576800
# Epoch 34, CIFAR-10 Batch 4:  loss is 0.993232, validation accuracy is 0.578200
# Epoch 34, CIFAR-10 Batch 5:  loss is 1.021757, validation accuracy is 0.573600
# Epoch 35, CIFAR-10 Batch 1:  loss is 1.016116, validation accuracy is 0.582000
# Epoch 35, CIFAR-10 Batch 2:  loss is 1.017313, validation accuracy is 0.580600
# Epoch 35, CIFAR-10 Batch 3:  loss is 0.984079, validation accuracy is 0.585000
# Epoch 35, CIFAR-10 Batch 4:  loss is 0.973431, validation accuracy is 0.581400
# Epoch 35, CIFAR-10 Batch 5:  loss is 1.006400, validation accuracy is 0.582800
# Epoch 36, CIFAR-10 Batch 1:  loss is 1.000337, validation accuracy is 0.584800
# Epoch 36, CIFAR-10 Batch 2:  loss is 0.997103, validation accuracy is 0.591800
# Epoch 36, CIFAR-10 Batch 3:  loss is 0.968753, validation accuracy is 0.585800
# Epoch 36, CIFAR-10 Batch 4:  loss is 0.952479, validation accuracy is 0.590800
# Epoch 36, CIFAR-10 Batch 5:  loss is 0.983852, validation accuracy is 0.585200
# Epoch 37, CIFAR-10 Batch 1:  loss is 0.990083, validation accuracy is 0.586200
# Epoch 37, CIFAR-10 Batch 2:  loss is 0.995903, validation accuracy is 0.586000
# Epoch 37, CIFAR-10 Batch 3:  loss is 0.959157, validation accuracy is 0.588400
# Epoch 37, CIFAR-10 Batch 4:  loss is 0.949599, validation accuracy is 0.589800
# Epoch 37, CIFAR-10 Batch 5:  loss is 0.969609, validation accuracy is 0.587400
# Epoch 38, CIFAR-10 Batch 1:  loss is 0.975991, validation accuracy is 0.588200
# Epoch 38, CIFAR-10 Batch 2:  loss is 0.979583, validation accuracy is 0.590400
# Epoch 38, CIFAR-10 Batch 3:  loss is 0.953416, validation accuracy is 0.581800
# Epoch 38, CIFAR-10 Batch 4:  loss is 0.935507, validation accuracy is 0.586400
# Epoch 38, CIFAR-10 Batch 5:  loss is 0.958306, validation accuracy is 0.586000
# Epoch 39, CIFAR-10 Batch 1:  loss is 0.960399, validation accuracy is 0.589400
# Epoch 39, CIFAR-10 Batch 2:  loss is 0.956521, validation accuracy is 0.591800
# Epoch 39, CIFAR-10 Batch 3:  loss is 0.928965, validation accuracy is 0.589600
# Epoch 39, CIFAR-10 Batch 4:  loss is 0.918340, validation accuracy is 0.596800
# Epoch 39, CIFAR-10 Batch 5:  loss is 0.959379, validation accuracy is 0.589600
# Epoch 40, CIFAR-10 Batch 1:  loss is 0.961072, validation accuracy is 0.592400
# Epoch 40, CIFAR-10 Batch 2:  loss is 0.960029, validation accuracy is 0.583000
# Epoch 40, CIFAR-10 Batch 3:  loss is 0.925907, validation accuracy is 0.594000
# Epoch 40, CIFAR-10 Batch 4:  loss is 0.908797, validation accuracy is 0.593800
# Epoch 40, CIFAR-10 Batch 5:  loss is 0.920739, validation accuracy is 0.599200
# Epoch 41, CIFAR-10 Batch 1:  loss is 0.928123, validation accuracy is 0.596000
# Epoch 41, CIFAR-10 Batch 2:  loss is 0.933610, validation accuracy is 0.594800
# Epoch 41, CIFAR-10 Batch 3:  loss is 0.903449, validation accuracy is 0.598000
# Epoch 41, CIFAR-10 Batch 4:  loss is 0.887080, validation accuracy is 0.599000
# Epoch 41, CIFAR-10 Batch 5:  loss is 0.915132, validation accuracy is 0.597400
# Epoch 42, CIFAR-10 Batch 1:  loss is 0.926569, validation accuracy is 0.595200
# Epoch 42, CIFAR-10 Batch 2:  loss is 0.938851, validation accuracy is 0.591000
# Epoch 42, CIFAR-10 Batch 3:  loss is 0.935446, validation accuracy is 0.586200
# Epoch 42, CIFAR-10 Batch 4:  loss is 0.890773, validation accuracy is 0.598800
# Epoch 42, CIFAR-10 Batch 5:  loss is 0.896522, validation accuracy is 0.601400
# Epoch 43, CIFAR-10 Batch 1:  loss is 0.912678, validation accuracy is 0.598000
# Epoch 43, CIFAR-10 Batch 2:  loss is 0.906187, validation accuracy is 0.602600
# Epoch 43, CIFAR-10 Batch 3:  loss is 0.894678, validation accuracy is 0.600000
# Epoch 43, CIFAR-10 Batch 4:  loss is 0.869170, validation accuracy is 0.600600
# Epoch 43, CIFAR-10 Batch 5:  loss is 0.891616, validation accuracy is 0.602000
# Epoch 44, CIFAR-10 Batch 1:  loss is 0.918118, validation accuracy is 0.592600
# Epoch 44, CIFAR-10 Batch 2:  loss is 0.900592, validation accuracy is 0.600800
# Epoch 44, CIFAR-10 Batch 3:  loss is 0.889044, validation accuracy is 0.598200
# Epoch 44, CIFAR-10 Batch 4:  loss is 0.869901, validation accuracy is 0.598200
# Epoch 44, CIFAR-10 Batch 5:  loss is 0.885722, validation accuracy is 0.600400
# Epoch 45, CIFAR-10 Batch 1:  loss is 0.903076, validation accuracy is 0.603600
# Epoch 45, CIFAR-10 Batch 2:  loss is 0.886108, validation accuracy is 0.606400
# Epoch 45, CIFAR-10 Batch 3:  loss is 0.875112, validation accuracy is 0.603200
# Epoch 45, CIFAR-10 Batch 4:  loss is 0.844351, validation accuracy is 0.608200
# Epoch 45, CIFAR-10 Batch 5:  loss is 0.871556, validation accuracy is 0.602400
# Epoch 46, CIFAR-10 Batch 1:  loss is 0.882094, validation accuracy is 0.606000
# Epoch 46, CIFAR-10 Batch 2:  loss is 0.888796, validation accuracy is 0.604200
# Epoch 46, CIFAR-10 Batch 3:  loss is 0.857564, validation accuracy is 0.602600
# Epoch 46, CIFAR-10 Batch 4:  loss is 0.854900, validation accuracy is 0.603000
# Epoch 46, CIFAR-10 Batch 5:  loss is 0.874781, validation accuracy is 0.600800
# Epoch 47, CIFAR-10 Batch 1:  loss is 0.889459, validation accuracy is 0.594400
# Epoch 47, CIFAR-10 Batch 2:  loss is 0.861642, validation accuracy is 0.614000
# Epoch 47, CIFAR-10 Batch 3:  loss is 0.845053, validation accuracy is 0.607200
# Epoch 47, CIFAR-10 Batch 4:  loss is 0.820914, validation accuracy is 0.610600
# Epoch 47, CIFAR-10 Batch 5:  loss is 0.856030, validation accuracy is 0.599800
# Epoch 48, CIFAR-10 Batch 1:  loss is 0.881944, validation accuracy is 0.605200
# Epoch 48, CIFAR-10 Batch 2:  loss is 0.860837, validation accuracy is 0.609600
# Epoch 48, CIFAR-10 Batch 3:  loss is 0.827293, validation accuracy is 0.612800
# Epoch 48, CIFAR-10 Batch 4:  loss is 0.815943, validation accuracy is 0.609800
# Epoch 48, CIFAR-10 Batch 5:  loss is 0.834214, validation accuracy is 0.611400
# Epoch 49, CIFAR-10 Batch 1:  loss is 0.855893, validation accuracy is 0.608600
# Epoch 49, CIFAR-10 Batch 2:  loss is 0.837888, validation accuracy is 0.612800
# Epoch 49, CIFAR-10 Batch 3:  loss is 0.811264, validation accuracy is 0.614600
# Epoch 49, CIFAR-10 Batch 4:  loss is 0.806329, validation accuracy is 0.614400
# Epoch 49, CIFAR-10 Batch 5:  loss is 0.814048, validation accuracy is 0.618000
# Epoch 50, CIFAR-10 Batch 1:  loss is 0.838371, validation accuracy is 0.612200
# Epoch 50, CIFAR-10 Batch 2:  loss is 0.822588, validation accuracy is 0.615200
# Epoch 50, CIFAR-10 Batch 3:  loss is 0.803710, validation accuracy is 0.612600
# Epoch 50, CIFAR-10 Batch 4:  loss is 0.788642, validation accuracy is 0.617000
# Epoch 50, CIFAR-10 Batch 5:  loss is 0.795692, validation accuracy is 0.614800
# Epoch 51, CIFAR-10 Batch 1:  loss is 0.835581, validation accuracy is 0.616400
# Epoch 51, CIFAR-10 Batch 2:  loss is 0.817049, validation accuracy is 0.618800
# Epoch 51, CIFAR-10 Batch 3:  loss is 0.798844, validation accuracy is 0.618400
# Epoch 51, CIFAR-10 Batch 4:  loss is 0.782766, validation accuracy is 0.611000
# Epoch 51, CIFAR-10 Batch 5:  loss is 0.798885, validation accuracy is 0.613200
# Epoch 52, CIFAR-10 Batch 1:  loss is 0.820971, validation accuracy is 0.613200
# Epoch 52, CIFAR-10 Batch 2:  loss is 0.802847, validation accuracy is 0.614800
# Epoch 52, CIFAR-10 Batch 3:  loss is 0.781490, validation accuracy is 0.616200
# Epoch 52, CIFAR-10 Batch 4:  loss is 0.763765, validation accuracy is 0.617200
# Epoch 52, CIFAR-10 Batch 5:  loss is 0.794996, validation accuracy is 0.611400
# Epoch 53, CIFAR-10 Batch 1:  loss is 0.830324, validation accuracy is 0.612200
# Epoch 53, CIFAR-10 Batch 2:  loss is 0.823302, validation accuracy is 0.604400
# Epoch 53, CIFAR-10 Batch 3:  loss is 0.793558, validation accuracy is 0.612200
# Epoch 53, CIFAR-10 Batch 4:  loss is 0.769566, validation accuracy is 0.608400
# Epoch 53, CIFAR-10 Batch 5:  loss is 0.766466, validation accuracy is 0.616000
# Epoch 54, CIFAR-10 Batch 1:  loss is 0.797446, validation accuracy is 0.616600
# Epoch 54, CIFAR-10 Batch 2:  loss is 0.797701, validation accuracy is 0.617800
# Epoch 54, CIFAR-10 Batch 3:  loss is 0.772619, validation accuracy is 0.613400
# Epoch 54, CIFAR-10 Batch 4:  loss is 0.754700, validation accuracy is 0.614000
# Epoch 54, CIFAR-10 Batch 5:  loss is 0.755350, validation accuracy is 0.617600
# Epoch 55, CIFAR-10 Batch 1:  loss is 0.794494, validation accuracy is 0.616200
# Epoch 55, CIFAR-10 Batch 2:  loss is 0.778266, validation accuracy is 0.623800
# Epoch 55, CIFAR-10 Batch 3:  loss is 0.773818, validation accuracy is 0.610800
# Epoch 55, CIFAR-10 Batch 4:  loss is 0.737069, validation accuracy is 0.619000
# Epoch 55, CIFAR-10 Batch 5:  loss is 0.755326, validation accuracy is 0.620200
# Epoch 56, CIFAR-10 Batch 1:  loss is 0.777810, validation accuracy is 0.622600
# Epoch 56, CIFAR-10 Batch 2:  loss is 0.764817, validation accuracy is 0.620600
# Epoch 56, CIFAR-10 Batch 3:  loss is 0.753751, validation accuracy is 0.623600
# Epoch 56, CIFAR-10 Batch 4:  loss is 0.736497, validation accuracy is 0.614400
# Epoch 56, CIFAR-10 Batch 5:  loss is 0.743790, validation accuracy is 0.615800
# Epoch 57, CIFAR-10 Batch 1:  loss is 0.775286, validation accuracy is 0.621000
# Epoch 57, CIFAR-10 Batch 2:  loss is 0.757541, validation accuracy is 0.622000
# Epoch 57, CIFAR-10 Batch 3:  loss is 0.755425, validation accuracy is 0.620000
# Epoch 57, CIFAR-10 Batch 4:  loss is 0.728438, validation accuracy is 0.614200
# Epoch 57, CIFAR-10 Batch 5:  loss is 0.743887, validation accuracy is 0.615200
# Epoch 58, CIFAR-10 Batch 1:  loss is 0.769286, validation accuracy is 0.621000
# Epoch 58, CIFAR-10 Batch 2:  loss is 0.752652, validation accuracy is 0.629000
# Epoch 58, CIFAR-10 Batch 3:  loss is 0.734463, validation accuracy is 0.622000
# Epoch 58, CIFAR-10 Batch 4:  loss is 0.712427, validation accuracy is 0.620400
# Epoch 58, CIFAR-10 Batch 5:  loss is 0.729355, validation accuracy is 0.617800
# Epoch 59, CIFAR-10 Batch 1:  loss is 0.751868, validation accuracy is 0.623800
# Epoch 59, CIFAR-10 Batch 2:  loss is 0.756590, validation accuracy is 0.617600
# Epoch 59, CIFAR-10 Batch 3:  loss is 0.741110, validation accuracy is 0.613800
# Epoch 59, CIFAR-10 Batch 4:  loss is 0.727050, validation accuracy is 0.617600
# Epoch 59, CIFAR-10 Batch 5:  loss is 0.723092, validation accuracy is 0.622200
# Epoch 60, CIFAR-10 Batch 1:  loss is 0.758628, validation accuracy is 0.617000
# Epoch 60, CIFAR-10 Batch 2:  loss is 0.738891, validation accuracy is 0.633200
# Epoch 60, CIFAR-10 Batch 3:  loss is 0.716304, validation accuracy is 0.622800
# Epoch 60, CIFAR-10 Batch 4:  loss is 0.683377, validation accuracy is 0.626400
# Epoch 60, CIFAR-10 Batch 5:  loss is 0.696928, validation accuracy is 0.623400
# Epoch 61, CIFAR-10 Batch 1:  loss is 0.743320, validation accuracy is 0.624400
# Epoch 61, CIFAR-10 Batch 2:  loss is 0.723749, validation accuracy is 0.628200
# Epoch 61, CIFAR-10 Batch 3:  loss is 0.697860, validation accuracy is 0.629000
# Epoch 61, CIFAR-10 Batch 4:  loss is 0.676772, validation accuracy is 0.629200
# Epoch 61, CIFAR-10 Batch 5:  loss is 0.692933, validation accuracy is 0.623600
# Epoch 62, CIFAR-10 Batch 1:  loss is 0.720352, validation accuracy is 0.634600
# Epoch 62, CIFAR-10 Batch 2:  loss is 0.717867, validation accuracy is 0.632200
# Epoch 62, CIFAR-10 Batch 3:  loss is 0.691907, validation accuracy is 0.631600
# Epoch 62, CIFAR-10 Batch 4:  loss is 0.669939, validation accuracy is 0.628400
# Epoch 62, CIFAR-10 Batch 5:  loss is 0.686449, validation accuracy is 0.628200
# Epoch 63, CIFAR-10 Batch 1:  loss is 0.718639, validation accuracy is 0.630800
# Epoch 63, CIFAR-10 Batch 2:  loss is 0.698249, validation accuracy is 0.629000
# Epoch 63, CIFAR-10 Batch 3:  loss is 0.679014, validation accuracy is 0.628200
# Epoch 63, CIFAR-10 Batch 4:  loss is 0.662163, validation accuracy is 0.629400
# Epoch 63, CIFAR-10 Batch 5:  loss is 0.676627, validation accuracy is 0.626000
# Epoch 64, CIFAR-10 Batch 1:  loss is 0.713665, validation accuracy is 0.632000
# Epoch 64, CIFAR-10 Batch 2:  loss is 0.707224, validation accuracy is 0.634000
# Epoch 64, CIFAR-10 Batch 3:  loss is 0.673494, validation accuracy is 0.632400
# Epoch 64, CIFAR-10 Batch 4:  loss is 0.649340, validation accuracy is 0.633600
# Epoch 64, CIFAR-10 Batch 5:  loss is 0.668365, validation accuracy is 0.631600
# Epoch 65, CIFAR-10 Batch 1:  loss is 0.714367, validation accuracy is 0.624200
# Epoch 65, CIFAR-10 Batch 2:  loss is 0.696417, validation accuracy is 0.623800
# Epoch 65, CIFAR-10 Batch 3:  loss is 0.671207, validation accuracy is 0.627400
# Epoch 65, CIFAR-10 Batch 4:  loss is 0.648882, validation accuracy is 0.635800
# Epoch 65, CIFAR-10 Batch 5:  loss is 0.657706, validation accuracy is 0.626400
# Epoch 66, CIFAR-10 Batch 1:  loss is 0.702786, validation accuracy is 0.631200
# Epoch 66, CIFAR-10 Batch 2:  loss is 0.684141, validation accuracy is 0.634400
# Epoch 66, CIFAR-10 Batch 3:  loss is 0.666122, validation accuracy is 0.631000
# Epoch 66, CIFAR-10 Batch 4:  loss is 0.628052, validation accuracy is 0.633400
# Epoch 66, CIFAR-10 Batch 5:  loss is 0.648512, validation accuracy is 0.630200
# Epoch 67, CIFAR-10 Batch 1:  loss is 0.690660, validation accuracy is 0.630000
# Epoch 67, CIFAR-10 Batch 2:  loss is 0.683821, validation accuracy is 0.624200
# Epoch 67, CIFAR-10 Batch 3:  loss is 0.668819, validation accuracy is 0.624000
# Epoch 67, CIFAR-10 Batch 4:  loss is 0.630265, validation accuracy is 0.630400
# Epoch 67, CIFAR-10 Batch 5:  loss is 0.631386, validation accuracy is 0.633200
# Epoch 68, CIFAR-10 Batch 1:  loss is 0.676123, validation accuracy is 0.633400
# Epoch 68, CIFAR-10 Batch 2:  loss is 0.670271, validation accuracy is 0.631800
# Epoch 68, CIFAR-10 Batch 3:  loss is 0.635631, validation accuracy is 0.630000
# Epoch 68, CIFAR-10 Batch 4:  loss is 0.622269, validation accuracy is 0.631400
# Epoch 68, CIFAR-10 Batch 5:  loss is 0.631359, validation accuracy is 0.630800
# Epoch 69, CIFAR-10 Batch 1:  loss is 0.669306, validation accuracy is 0.635200
# Epoch 69, CIFAR-10 Batch 2:  loss is 0.660115, validation accuracy is 0.636800
# Epoch 69, CIFAR-10 Batch 3:  loss is 0.636290, validation accuracy is 0.634400
# Epoch 69, CIFAR-10 Batch 4:  loss is 0.605344, validation accuracy is 0.634200
# Epoch 69, CIFAR-10 Batch 5:  loss is 0.626924, validation accuracy is 0.630400
# Epoch 70, CIFAR-10 Batch 1:  loss is 0.667754, validation accuracy is 0.634200
# Epoch 70, CIFAR-10 Batch 2:  loss is 0.658858, validation accuracy is 0.631600
# Epoch 70, CIFAR-10 Batch 3:  loss is 0.623644, validation accuracy is 0.635800
# Epoch 70, CIFAR-10 Batch 4:  loss is 0.597932, validation accuracy is 0.630200
# Epoch 70, CIFAR-10 Batch 5:  loss is 0.610906, validation accuracy is 0.630200
# Epoch 71, CIFAR-10 Batch 1:  loss is 0.664476, validation accuracy is 0.626400
# Epoch 71, CIFAR-10 Batch 2:  loss is 0.668228, validation accuracy is 0.621000
# Epoch 71, CIFAR-10 Batch 3:  loss is 0.641963, validation accuracy is 0.627800
# Epoch 71, CIFAR-10 Batch 4:  loss is 0.600011, validation accuracy is 0.631000
# Epoch 71, CIFAR-10 Batch 5:  loss is 0.593261, validation accuracy is 0.636200
# Epoch 72, CIFAR-10 Batch 1:  loss is 0.655462, validation accuracy is 0.629800
# Epoch 72, CIFAR-10 Batch 2:  loss is 0.637867, validation accuracy is 0.637200
# Epoch 72, CIFAR-10 Batch 3:  loss is 0.614501, validation accuracy is 0.631000
# Epoch 72, CIFAR-10 Batch 4:  loss is 0.589850, validation accuracy is 0.627200
# Epoch 72, CIFAR-10 Batch 5:  loss is 0.596270, validation accuracy is 0.635800
# Epoch 73, CIFAR-10 Batch 1:  loss is 0.653291, validation accuracy is 0.630200
# Epoch 73, CIFAR-10 Batch 2:  loss is 0.628007, validation accuracy is 0.635800
# Epoch 73, CIFAR-10 Batch 3:  loss is 0.605933, validation accuracy is 0.638200
# Epoch 73, CIFAR-10 Batch 4:  loss is 0.586094, validation accuracy is 0.628200
# Epoch 73, CIFAR-10 Batch 5:  loss is 0.584879, validation accuracy is 0.639600
# Epoch 74, CIFAR-10 Batch 1:  loss is 0.631766, validation accuracy is 0.633200
# Epoch 74, CIFAR-10 Batch 2:  loss is 0.630202, validation accuracy is 0.631400
# Epoch 74, CIFAR-10 Batch 3:  loss is 0.604238, validation accuracy is 0.640800
# Epoch 74, CIFAR-10 Batch 4:  loss is 0.564954, validation accuracy is 0.638000
# Epoch 74, CIFAR-10 Batch 5:  loss is 0.581724, validation accuracy is 0.633600
# Epoch 75, CIFAR-10 Batch 1:  loss is 0.629449, validation accuracy is 0.631200
# Epoch 75, CIFAR-10 Batch 2:  loss is 0.621639, validation accuracy is 0.633800
# Epoch 75, CIFAR-10 Batch 3:  loss is 0.593952, validation accuracy is 0.631000
# Epoch 75, CIFAR-10 Batch 4:  loss is 0.561623, validation accuracy is 0.638200
# Epoch 75, CIFAR-10 Batch 5:  loss is 0.577818, validation accuracy is 0.632800
# Epoch 76, CIFAR-10 Batch 1:  loss is 0.616358, validation accuracy is 0.636400
# Epoch 76, CIFAR-10 Batch 2:  loss is 0.606221, validation accuracy is 0.635000
# Epoch 76, CIFAR-10 Batch 3:  loss is 0.582031, validation accuracy is 0.635400
# Epoch 76, CIFAR-10 Batch 4:  loss is 0.548940, validation accuracy is 0.632400
# Epoch 76, CIFAR-10 Batch 5:  loss is 0.575821, validation accuracy is 0.631200
# Epoch 77, CIFAR-10 Batch 1:  loss is 0.635855, validation accuracy is 0.627200
# Epoch 77, CIFAR-10 Batch 2:  loss is 0.621159, validation accuracy is 0.630200
# Epoch 77, CIFAR-10 Batch 3:  loss is 0.573846, validation accuracy is 0.636800
# Epoch 77, CIFAR-10 Batch 4:  loss is 0.553915, validation accuracy is 0.634000
# Epoch 77, CIFAR-10 Batch 5:  loss is 0.569146, validation accuracy is 0.635200
# Epoch 78, CIFAR-10 Batch 1:  loss is 0.610755, validation accuracy is 0.641600
# Epoch 78, CIFAR-10 Batch 2:  loss is 0.596914, validation accuracy is 0.636200
# Epoch 78, CIFAR-10 Batch 3:  loss is 0.570750, validation accuracy is 0.636200
# Epoch 78, CIFAR-10 Batch 4:  loss is 0.552109, validation accuracy is 0.632000
# Epoch 78, CIFAR-10 Batch 5:  loss is 0.572649, validation accuracy is 0.626600
# Epoch 79, CIFAR-10 Batch 1:  loss is 0.608155, validation accuracy is 0.630000
# Epoch 79, CIFAR-10 Batch 2:  loss is 0.583541, validation accuracy is 0.633400
# Epoch 79, CIFAR-10 Batch 3:  loss is 0.569075, validation accuracy is 0.634600
# Epoch 79, CIFAR-10 Batch 4:  loss is 0.542650, validation accuracy is 0.636600
# Epoch 79, CIFAR-10 Batch 5:  loss is 0.555732, validation accuracy is 0.633000
# Epoch 80, CIFAR-10 Batch 1:  loss is 0.588032, validation accuracy is 0.638000
# Epoch 80, CIFAR-10 Batch 2:  loss is 0.583886, validation accuracy is 0.638400
# Epoch 80, CIFAR-10 Batch 3:  loss is 0.557933, validation accuracy is 0.637600
# Epoch 80, CIFAR-10 Batch 4:  loss is 0.543434, validation accuracy is 0.635400
# Epoch 80, CIFAR-10 Batch 5:  loss is 0.548578, validation accuracy is 0.631200
# Epoch 81, CIFAR-10 Batch 1:  loss is 0.579210, validation accuracy is 0.632600
# Epoch 81, CIFAR-10 Batch 2:  loss is 0.584764, validation accuracy is 0.632400
# Epoch 81, CIFAR-10 Batch 3:  loss is 0.554321, validation accuracy is 0.634200
# Epoch 81, CIFAR-10 Batch 4:  loss is 0.531349, validation accuracy is 0.633800
# Epoch 81, CIFAR-10 Batch 5:  loss is 0.545526, validation accuracy is 0.636400
# Epoch 82, CIFAR-10 Batch 1:  loss is 0.581901, validation accuracy is 0.629600
# Epoch 82, CIFAR-10 Batch 2:  loss is 0.559767, validation accuracy is 0.640000
# Epoch 82, CIFAR-10 Batch 3:  loss is 0.543247, validation accuracy is 0.634000
# Epoch 82, CIFAR-10 Batch 4:  loss is 0.531676, validation accuracy is 0.632200
# Epoch 82, CIFAR-10 Batch 5:  loss is 0.544835, validation accuracy is 0.637400
# Epoch 83, CIFAR-10 Batch 1:  loss is 0.575783, validation accuracy is 0.632800
# Epoch 83, CIFAR-10 Batch 2:  loss is 0.567636, validation accuracy is 0.635200
# Epoch 83, CIFAR-10 Batch 3:  loss is 0.534794, validation accuracy is 0.640000
# Epoch 83, CIFAR-10 Batch 4:  loss is 0.512601, validation accuracy is 0.638000
# Epoch 83, CIFAR-10 Batch 5:  loss is 0.521196, validation accuracy is 0.642800
# Epoch 84, CIFAR-10 Batch 1:  loss is 0.568736, validation accuracy is 0.637800
# Epoch 84, CIFAR-10 Batch 2:  loss is 0.551676, validation accuracy is 0.637000
# Epoch 84, CIFAR-10 Batch 3:  loss is 0.540245, validation accuracy is 0.641000
# Epoch 84, CIFAR-10 Batch 4:  loss is 0.501876, validation accuracy is 0.639000
# Epoch 84, CIFAR-10 Batch 5:  loss is 0.518108, validation accuracy is 0.635800
# Epoch 85, CIFAR-10 Batch 1:  loss is 0.564835, validation accuracy is 0.638000
# Epoch 85, CIFAR-10 Batch 2:  loss is 0.551920, validation accuracy is 0.642600
# Epoch 85, CIFAR-10 Batch 3:  loss is 0.532884, validation accuracy is 0.639800
# Epoch 85, CIFAR-10 Batch 4:  loss is 0.493018, validation accuracy is 0.642000
# Epoch 85, CIFAR-10 Batch 5:  loss is 0.522746, validation accuracy is 0.644000
# Epoch 86, CIFAR-10 Batch 1:  loss is 0.546855, validation accuracy is 0.643000
# Epoch 86, CIFAR-10 Batch 2:  loss is 0.536284, validation accuracy is 0.639200
# Epoch 86, CIFAR-10 Batch 3:  loss is 0.509770, validation accuracy is 0.644200
# Epoch 86, CIFAR-10 Batch 4:  loss is 0.495677, validation accuracy is 0.641000
# Epoch 86, CIFAR-10 Batch 5:  loss is 0.510066, validation accuracy is 0.640800
# Epoch 87, CIFAR-10 Batch 1:  loss is 0.540775, validation accuracy is 0.640200
# Epoch 87, CIFAR-10 Batch 2:  loss is 0.534271, validation accuracy is 0.641600
# Epoch 87, CIFAR-10 Batch 3:  loss is 0.514252, validation accuracy is 0.637000
# Epoch 87, CIFAR-10 Batch 4:  loss is 0.491200, validation accuracy is 0.639200
# Epoch 87, CIFAR-10 Batch 5:  loss is 0.501149, validation accuracy is 0.643000
# Epoch 88, CIFAR-10 Batch 1:  loss is 0.544121, validation accuracy is 0.637400
# Epoch 88, CIFAR-10 Batch 2:  loss is 0.524909, validation accuracy is 0.641000
# Epoch 88, CIFAR-10 Batch 3:  loss is 0.515752, validation accuracy is 0.640200
# Epoch 88, CIFAR-10 Batch 4:  loss is 0.486139, validation accuracy is 0.641200
# Epoch 88, CIFAR-10 Batch 5:  loss is 0.486313, validation accuracy is 0.645400
# Epoch 89, CIFAR-10 Batch 1:  loss is 0.530164, validation accuracy is 0.643400
# Epoch 89, CIFAR-10 Batch 2:  loss is 0.539523, validation accuracy is 0.639000
# Epoch 89, CIFAR-10 Batch 3:  loss is 0.503791, validation accuracy is 0.641200
# Epoch 89, CIFAR-10 Batch 4:  loss is 0.464874, validation accuracy is 0.645000
# Epoch 89, CIFAR-10 Batch 5:  loss is 0.474003, validation accuracy is 0.646200
# Epoch 90, CIFAR-10 Batch 1:  loss is 0.524463, validation accuracy is 0.640800
# Epoch 90, CIFAR-10 Batch 2:  loss is 0.509942, validation accuracy is 0.640400
# Epoch 90, CIFAR-10 Batch 3:  loss is 0.500218, validation accuracy is 0.644000
# Epoch 90, CIFAR-10 Batch 4:  loss is 0.457101, validation accuracy is 0.643200
# Epoch 90, CIFAR-10 Batch 5:  loss is 0.474715, validation accuracy is 0.644200
# Epoch 91, CIFAR-10 Batch 1:  loss is 0.515012, validation accuracy is 0.645200
# Epoch 91, CIFAR-10 Batch 2:  loss is 0.505373, validation accuracy is 0.644800
# Epoch 91, CIFAR-10 Batch 3:  loss is 0.501453, validation accuracy is 0.641000
# Epoch 91, CIFAR-10 Batch 4:  loss is 0.462700, validation accuracy is 0.641000
# Epoch 91, CIFAR-10 Batch 5:  loss is 0.462953, validation accuracy is 0.646000
# Epoch 92, CIFAR-10 Batch 1:  loss is 0.523228, validation accuracy is 0.640200
# Epoch 92, CIFAR-10 Batch 2:  loss is 0.508751, validation accuracy is 0.642400
# Epoch 92, CIFAR-10 Batch 3:  loss is 0.488024, validation accuracy is 0.637600
# Epoch 92, CIFAR-10 Batch 4:  loss is 0.458040, validation accuracy is 0.643000
# Epoch 92, CIFAR-10 Batch 5:  loss is 0.481967, validation accuracy is 0.639200
# Epoch 93, CIFAR-10 Batch 1:  loss is 0.511785, validation accuracy is 0.642200
# Epoch 93, CIFAR-10 Batch 2:  loss is 0.494427, validation accuracy is 0.642400
# Epoch 93, CIFAR-10 Batch 3:  loss is 0.488395, validation accuracy is 0.639800
# Epoch 93, CIFAR-10 Batch 4:  loss is 0.445019, validation accuracy is 0.642800
# Epoch 93, CIFAR-10 Batch 5:  loss is 0.455467, validation accuracy is 0.646200
# Epoch 94, CIFAR-10 Batch 1:  loss is 0.502231, validation accuracy is 0.643600
# Epoch 94, CIFAR-10 Batch 2:  loss is 0.491478, validation accuracy is 0.641000
# Epoch 94, CIFAR-10 Batch 3:  loss is 0.473952, validation accuracy is 0.639600
# Epoch 94, CIFAR-10 Batch 4:  loss is 0.444290, validation accuracy is 0.640200
# Epoch 94, CIFAR-10 Batch 5:  loss is 0.458402, validation accuracy is 0.637800
# Epoch 95, CIFAR-10 Batch 1:  loss is 0.502088, validation accuracy is 0.642600
# Epoch 95, CIFAR-10 Batch 2:  loss is 0.493424, validation accuracy is 0.646800
# Epoch 95, CIFAR-10 Batch 3:  loss is 0.479774, validation accuracy is 0.634200
# Epoch 95, CIFAR-10 Batch 4:  loss is 0.432541, validation accuracy is 0.644400
# Epoch 95, CIFAR-10 Batch 5:  loss is 0.449761, validation accuracy is 0.645800
# Epoch 96, CIFAR-10 Batch 1:  loss is 0.500781, validation accuracy is 0.642800
# Epoch 96, CIFAR-10 Batch 2:  loss is 0.482139, validation accuracy is 0.639000
# Epoch 96, CIFAR-10 Batch 3:  loss is 0.462588, validation accuracy is 0.640000
# Epoch 96, CIFAR-10 Batch 4:  loss is 0.431036, validation accuracy is 0.645000
# Epoch 96, CIFAR-10 Batch 5:  loss is 0.445866, validation accuracy is 0.646600
# Epoch 97, CIFAR-10 Batch 1:  loss is 0.486457, validation accuracy is 0.646600
# Epoch 97, CIFAR-10 Batch 2:  loss is 0.470802, validation accuracy is 0.641600
# Epoch 97, CIFAR-10 Batch 3:  loss is 0.457758, validation accuracy is 0.639600
# Epoch 97, CIFAR-10 Batch 4:  loss is 0.425238, validation accuracy is 0.641400
# Epoch 97, CIFAR-10 Batch 5:  loss is 0.439969, validation accuracy is 0.641600
# Epoch 98, CIFAR-10 Batch 1:  loss is 0.483711, validation accuracy is 0.646800
# Epoch 98, CIFAR-10 Batch 2:  loss is 0.480087, validation accuracy is 0.641800
# Epoch 98, CIFAR-10 Batch 3:  loss is 0.455125, validation accuracy is 0.638400
# Epoch 98, CIFAR-10 Batch 4:  loss is 0.424979, validation accuracy is 0.645200
# Epoch 98, CIFAR-10 Batch 5:  loss is 0.426437, validation accuracy is 0.643400
# Epoch 99, CIFAR-10 Batch 1:  loss is 0.479702, validation accuracy is 0.645000
# Epoch 99, CIFAR-10 Batch 2:  loss is 0.457891, validation accuracy is 0.646600
# Epoch 99, CIFAR-10 Batch 3:  loss is 0.460406, validation accuracy is 0.644400
# Epoch 99, CIFAR-10 Batch 4:  loss is 0.425558, validation accuracy is 0.645400
# Epoch 99, CIFAR-10 Batch 5:  loss is 0.427836, validation accuracy is 0.640800
# Epoch 100, CIFAR-10 Batch 1:  loss is 0.474603, validation accuracy is 0.640800
# Epoch 100, CIFAR-10 Batch 2:  loss is 0.457126, validation accuracy is 0.648000
# Epoch 100, CIFAR-10 Batch 3:  loss is 0.444421, validation accuracy is 0.644000
# Epoch 100, CIFAR-10 Batch 4:  loss is 0.426548, validation accuracy is 0.643200
# Epoch 100, CIFAR-10 Batch 5:  loss is 0.448407, validation accuracy is 0.628400
# Epoch 101, CIFAR-10 Batch 1:  loss is 0.474277, validation accuracy is 0.644200
# Epoch 101, CIFAR-10 Batch 2:  loss is 0.450565, validation accuracy is 0.644600
# Epoch 101, CIFAR-10 Batch 3:  loss is 0.447307, validation accuracy is 0.644200
# Epoch 101, CIFAR-10 Batch 4:  loss is 0.416162, validation accuracy is 0.643600
# Epoch 101, CIFAR-10 Batch 5:  loss is 0.426659, validation accuracy is 0.643800
# Epoch 102, CIFAR-10 Batch 1:  loss is 0.456867, validation accuracy is 0.643600
# Epoch 102, CIFAR-10 Batch 2:  loss is 0.445694, validation accuracy is 0.646000
# Epoch 102, CIFAR-10 Batch 3:  loss is 0.433960, validation accuracy is 0.641600
# Epoch 102, CIFAR-10 Batch 4:  loss is 0.395614, validation accuracy is 0.647000
# Epoch 102, CIFAR-10 Batch 5:  loss is 0.413076, validation accuracy is 0.642600
# Epoch 103, CIFAR-10 Batch 1:  loss is 0.464977, validation accuracy is 0.644400
# Epoch 103, CIFAR-10 Batch 2:  loss is 0.440219, validation accuracy is 0.645400
# Epoch 103, CIFAR-10 Batch 3:  loss is 0.443013, validation accuracy is 0.636400
# Epoch 103, CIFAR-10 Batch 4:  loss is 0.400573, validation accuracy is 0.647400
# Epoch 103, CIFAR-10 Batch 5:  loss is 0.397456, validation accuracy is 0.649000
# Epoch 104, CIFAR-10 Batch 1:  loss is 0.461263, validation accuracy is 0.647200
# Epoch 104, CIFAR-10 Batch 2:  loss is 0.440752, validation accuracy is 0.642200
# Epoch 104, CIFAR-10 Batch 3:  loss is 0.422482, validation accuracy is 0.645200
# Epoch 104, CIFAR-10 Batch 4:  loss is 0.389762, validation accuracy is 0.648400
# Epoch 104, CIFAR-10 Batch 5:  loss is 0.410424, validation accuracy is 0.642600
# Epoch 105, CIFAR-10 Batch 1:  loss is 0.450818, validation accuracy is 0.649600
# Epoch 105, CIFAR-10 Batch 2:  loss is 0.428306, validation accuracy is 0.647800
# Epoch 105, CIFAR-10 Batch 3:  loss is 0.425888, validation accuracy is 0.642400
# Epoch 105, CIFAR-10 Batch 4:  loss is 0.399650, validation accuracy is 0.645000
# Epoch 105, CIFAR-10 Batch 5:  loss is 0.391314, validation accuracy is 0.645200
# Epoch 106, CIFAR-10 Batch 1:  loss is 0.434276, validation accuracy is 0.646800
# Epoch 106, CIFAR-10 Batch 2:  loss is 0.430996, validation accuracy is 0.644800
# Epoch 106, CIFAR-10 Batch 3:  loss is 0.414330, validation accuracy is 0.642600
# Epoch 106, CIFAR-10 Batch 4:  loss is 0.379819, validation accuracy is 0.649200
# Epoch 106, CIFAR-10 Batch 5:  loss is 0.391427, validation accuracy is 0.650000
# Epoch 107, CIFAR-10 Batch 1:  loss is 0.426360, validation accuracy is 0.649200
# Epoch 107, CIFAR-10 Batch 2:  loss is 0.417256, validation accuracy is 0.649800
# Epoch 107, CIFAR-10 Batch 3:  loss is 0.416020, validation accuracy is 0.641400
# Epoch 107, CIFAR-10 Batch 4:  loss is 0.369874, validation accuracy is 0.648400
# Epoch 107, CIFAR-10 Batch 5:  loss is 0.379723, validation accuracy is 0.650800
# Epoch 108, CIFAR-10 Batch 1:  loss is 0.426043, validation accuracy is 0.649800
# Epoch 108, CIFAR-10 Batch 2:  loss is 0.415351, validation accuracy is 0.648000
# Epoch 108, CIFAR-10 Batch 3:  loss is 0.407838, validation accuracy is 0.640600
# Epoch 108, CIFAR-10 Batch 4:  loss is 0.372064, validation accuracy is 0.647600
# Epoch 108, CIFAR-10 Batch 5:  loss is 0.381594, validation accuracy is 0.647000
# Epoch 109, CIFAR-10 Batch 1:  loss is 0.427959, validation accuracy is 0.646600
# Epoch 109, CIFAR-10 Batch 2:  loss is 0.433087, validation accuracy is 0.640600
# Epoch 109, CIFAR-10 Batch 3:  loss is 0.408716, validation accuracy is 0.640400
# Epoch 109, CIFAR-10 Batch 4:  loss is 0.381458, validation accuracy is 0.642400
# Epoch 109, CIFAR-10 Batch 5:  loss is 0.383677, validation accuracy is 0.645200
# Epoch 110, CIFAR-10 Batch 1:  loss is 0.419342, validation accuracy is 0.646400
# Epoch 110, CIFAR-10 Batch 2:  loss is 0.418015, validation accuracy is 0.649800
# Epoch 110, CIFAR-10 Batch 3:  loss is 0.392592, validation accuracy is 0.643600
# Epoch 110, CIFAR-10 Batch 4:  loss is 0.367571, validation accuracy is 0.643000
# Epoch 110, CIFAR-10 Batch 5:  loss is 0.387937, validation accuracy is 0.636600
# Epoch 111, CIFAR-10 Batch 1:  loss is 0.413991, validation accuracy is 0.649200
# Epoch 111, CIFAR-10 Batch 2:  loss is 0.409203, validation accuracy is 0.648800
# Epoch 111, CIFAR-10 Batch 3:  loss is 0.410188, validation accuracy is 0.646600
# Epoch 111, CIFAR-10 Batch 4:  loss is 0.368259, validation accuracy is 0.641600
# Epoch 111, CIFAR-10 Batch 5:  loss is 0.399289, validation accuracy is 0.637400
# Epoch 112, CIFAR-10 Batch 1:  loss is 0.426976, validation accuracy is 0.644000
# Epoch 112, CIFAR-10 Batch 2:  loss is 0.404944, validation accuracy is 0.647800
# Epoch 112, CIFAR-10 Batch 3:  loss is 0.408232, validation accuracy is 0.642400
# Epoch 112, CIFAR-10 Batch 4:  loss is 0.370504, validation accuracy is 0.646400
# Epoch 112, CIFAR-10 Batch 5:  loss is 0.379445, validation accuracy is 0.641400
# Epoch 113, CIFAR-10 Batch 1:  loss is 0.427144, validation accuracy is 0.649400
# Epoch 113, CIFAR-10 Batch 2:  loss is 0.411182, validation accuracy is 0.644000
# Epoch 113, CIFAR-10 Batch 3:  loss is 0.399609, validation accuracy is 0.645800
# Epoch 113, CIFAR-10 Batch 4:  loss is 0.369762, validation accuracy is 0.636800
# Epoch 113, CIFAR-10 Batch 5:  loss is 0.373200, validation accuracy is 0.643800
# Epoch 114, CIFAR-10 Batch 1:  loss is 0.398729, validation accuracy is 0.646000
# Epoch 114, CIFAR-10 Batch 2:  loss is 0.392716, validation accuracy is 0.643800
# Epoch 114, CIFAR-10 Batch 3:  loss is 0.390660, validation accuracy is 0.647400
# Epoch 114, CIFAR-10 Batch 4:  loss is 0.353802, validation accuracy is 0.648200
# Epoch 114, CIFAR-10 Batch 5:  loss is 0.365092, validation accuracy is 0.650000
# Epoch 115, CIFAR-10 Batch 1:  loss is 0.406831, validation accuracy is 0.648200
# Epoch 115, CIFAR-10 Batch 2:  loss is 0.385349, validation accuracy is 0.648000
# Epoch 115, CIFAR-10 Batch 3:  loss is 0.372003, validation accuracy is 0.649200
# Epoch 115, CIFAR-10 Batch 4:  loss is 0.350204, validation accuracy is 0.647800
# Epoch 115, CIFAR-10 Batch 5:  loss is 0.360103, validation accuracy is 0.645800
# Epoch 116, CIFAR-10 Batch 1:  loss is 0.386696, validation accuracy is 0.650000
# Epoch 116, CIFAR-10 Batch 2:  loss is 0.381163, validation accuracy is 0.646600
# Epoch 116, CIFAR-10 Batch 3:  loss is 0.385549, validation accuracy is 0.646800
# Epoch 116, CIFAR-10 Batch 4:  loss is 0.355963, validation accuracy is 0.643200
# Epoch 116, CIFAR-10 Batch 5:  loss is 0.352104, validation accuracy is 0.647600
# Epoch 117, CIFAR-10 Batch 1:  loss is 0.388857, validation accuracy is 0.648400
# Epoch 117, CIFAR-10 Batch 2:  loss is 0.378263, validation accuracy is 0.650000
# Epoch 117, CIFAR-10 Batch 3:  loss is 0.374734, validation accuracy is 0.644400
# Epoch 117, CIFAR-10 Batch 4:  loss is 0.355079, validation accuracy is 0.642800
# Epoch 117, CIFAR-10 Batch 5:  loss is 0.355739, validation accuracy is 0.644600
# Epoch 118, CIFAR-10 Batch 1:  loss is 0.398938, validation accuracy is 0.642000
# Epoch 118, CIFAR-10 Batch 2:  loss is 0.370967, validation accuracy is 0.647800
# Epoch 118, CIFAR-10 Batch 3:  loss is 0.394421, validation accuracy is 0.640800
# Epoch 118, CIFAR-10 Batch 4:  loss is 0.340628, validation accuracy is 0.644600
# Epoch 118, CIFAR-10 Batch 5:  loss is 0.344249, validation accuracy is 0.649400
# Epoch 119, CIFAR-10 Batch 1:  loss is 0.381116, validation accuracy is 0.650400
# Epoch 119, CIFAR-10 Batch 2:  loss is 0.375608, validation accuracy is 0.643200
# Epoch 119, CIFAR-10 Batch 3:  loss is 0.365309, validation accuracy is 0.646600
# Epoch 119, CIFAR-10 Batch 4:  loss is 0.340095, validation accuracy is 0.643400
# Epoch 119, CIFAR-10 Batch 5:  loss is 0.345229, validation accuracy is 0.649400
# Epoch 120, CIFAR-10 Batch 1:  loss is 0.366982, validation accuracy is 0.649800
# Epoch 120, CIFAR-10 Batch 2:  loss is 0.358511, validation accuracy is 0.649800
# Epoch 120, CIFAR-10 Batch 3:  loss is 0.366784, validation accuracy is 0.651200
# Epoch 120, CIFAR-10 Batch 4:  loss is 0.323998, validation accuracy is 0.648000
# Epoch 120, CIFAR-10 Batch 5:  loss is 0.338312, validation accuracy is 0.648400
# Epoch 121, CIFAR-10 Batch 1:  loss is 0.364814, validation accuracy is 0.649000
# Epoch 121, CIFAR-10 Batch 2:  loss is 0.357618, validation accuracy is 0.648600
# Epoch 121, CIFAR-10 Batch 3:  loss is 0.356241, validation accuracy is 0.651000
# Epoch 121, CIFAR-10 Batch 4:  loss is 0.335639, validation accuracy is 0.643200
# Epoch 121, CIFAR-10 Batch 5:  loss is 0.331728, validation accuracy is 0.649400
# Epoch 122, CIFAR-10 Batch 1:  loss is 0.369638, validation accuracy is 0.649200
# ...
# Epoch 161, CIFAR-10 Batch 1:  loss is 0.246579, validation accuracy is 0.650600
# Epoch 161, CIFAR-10 Batch 2:  loss is 0.233365, validation accuracy is 0.645800
# Epoch 161, CIFAR-10 Batch 3:  loss is 0.240405, validation accuracy is 0.654400
# Epoch 161, CIFAR-10 Batch 4:  loss is 0.202551, validation accuracy is 0.649800
# Epoch 161, CIFAR-10 Batch 5:  loss is 0.210708, validation accuracy is 0.655800
# Epoch 162, CIFAR-10 Batch 1:  loss is 0.241355, validation accuracy is 0.648200
# Epoch 162, CIFAR-10 Batch 2:  loss is 0.235605, validation accuracy is 0.646000
# Epoch 162, CIFAR-10 Batch 3:  loss is 0.238772, validation accuracy is 0.648000
# Epoch 162, CIFAR-10 Batch 4:  loss is 0.208535, validation accuracy is 0.653600
# Epoch 162, CIFAR-10 Batch 5:  loss is 0.206112, validation accuracy is 0.653800
# Epoch 163, CIFAR-10 Batch 1:  loss is 0.243598, validation accuracy is 0.647200
# Epoch 163, CIFAR-10 Batch 2:  loss is 0.236287, validation accuracy is 0.643800
# Epoch 163, CIFAR-10 Batch 3:  loss is 0.230627, validation accuracy is 0.646200
# Epoch 163, CIFAR-10 Batch 4:  loss is 0.214506, validation accuracy is 0.652800
# Epoch 163, CIFAR-10 Batch 5:  loss is 0.211761, validation accuracy is 0.652800
# Epoch 164, CIFAR-10 Batch 1:  loss is 0.236028, validation accuracy is 0.653000
# Epoch 164, CIFAR-10 Batch 2:  loss is 0.220310, validation accuracy is 0.647000
# Epoch 164, CIFAR-10 Batch 3:  loss is 0.228902, validation accuracy is 0.657200
# Epoch 164, CIFAR-10 Batch 4:  loss is 0.203091, validation accuracy is 0.650800
# Epoch 164, CIFAR-10 Batch 5:  loss is 0.202783, validation accuracy is 0.655000
# Epoch 165, CIFAR-10 Batch 1:  loss is 0.232401, validation accuracy is 0.652000
# Epoch 165, CIFAR-10 Batch 2:  loss is 0.222505, validation accuracy is 0.647200
# Epoch 165, CIFAR-10 Batch 3:  loss is 0.231268, validation accuracy is 0.652800
# Epoch 165, CIFAR-10 Batch 4:  loss is 0.206151, validation accuracy is 0.649400
# Epoch 165, CIFAR-10 Batch 5:  loss is 0.225261, validation accuracy is 0.651000
# Epoch 166, CIFAR-10 Batch 1:  loss is 0.236063, validation accuracy is 0.650800
# Epoch 166, CIFAR-10 Batch 2:  loss is 0.210608, validation accuracy is 0.654200
# Epoch 166, CIFAR-10 Batch 3:  loss is 0.227750, validation accuracy is 0.654600
# Epoch 166, CIFAR-10 Batch 4:  loss is 0.199590, validation accuracy is 0.651800
# Epoch 166, CIFAR-10 Batch 5:  loss is 0.197696, validation accuracy is 0.656000
# Epoch 167, CIFAR-10 Batch 1:  loss is 0.221541, validation accuracy is 0.653600
# Epoch 167, CIFAR-10 Batch 2:  loss is 0.215368, validation accuracy is 0.653200
# Epoch 167, CIFAR-10 Batch 3:  loss is 0.223023, validation accuracy is 0.653000
# Epoch 167, CIFAR-10 Batch 4:  loss is 0.192576, validation accuracy is 0.659800
# Epoch 167, CIFAR-10 Batch 5:  loss is 0.195694, validation accuracy is 0.660800
# Epoch 168, CIFAR-10 Batch 1:  loss is 0.217181, validation accuracy is 0.659400
# Epoch 168, CIFAR-10 Batch 2:  loss is 0.210997, validation accuracy is 0.651400
# Epoch 168, CIFAR-10 Batch 3:  loss is 0.221862, validation accuracy is 0.655600
# Epoch 168, CIFAR-10 Batch 4:  loss is 0.193070, validation accuracy is 0.654400
# Epoch 168, CIFAR-10 Batch 5:  loss is 0.208582, validation accuracy is 0.650000
# Epoch 169, CIFAR-10 Batch 1:  loss is 0.225435, validation accuracy is 0.655000
# Epoch 169, CIFAR-10 Batch 2:  loss is 0.209935, validation accuracy is 0.655800
# Epoch 169, CIFAR-10 Batch 3:  loss is 0.214140, validation accuracy is 0.655800
# Epoch 169, CIFAR-10 Batch 4:  loss is 0.196897, validation accuracy is 0.647400
# Epoch 169, CIFAR-10 Batch 5:  loss is 0.198174, validation accuracy is 0.651000
# Epoch 170, CIFAR-10 Batch 1:  loss is 0.226198, validation accuracy is 0.644600
# Epoch 170, CIFAR-10 Batch 2:  loss is 0.211695, validation accuracy is 0.643600
# Epoch 170, CIFAR-10 Batch 3:  loss is 0.214886, validation accuracy is 0.657800
# Epoch 170, CIFAR-10 Batch 4:  loss is 0.194349, validation accuracy is 0.655400
# Epoch 170, CIFAR-10 Batch 5:  loss is 0.191944, validation accuracy is 0.658200
# Epoch 171, CIFAR-10 Batch 1:  loss is 0.214678, validation accuracy is 0.650800
# Epoch 171, CIFAR-10 Batch 2:  loss is 0.207231, validation accuracy is 0.652000
# Epoch 171, CIFAR-10 Batch 3:  loss is 0.212900, validation accuracy is 0.658400
# Epoch 171, CIFAR-10 Batch 4:  loss is 0.187956, validation accuracy is 0.653000
# Epoch 171, CIFAR-10 Batch 5:  loss is 0.193330, validation accuracy is 0.659200
# Epoch 172, CIFAR-10 Batch 1:  loss is 0.216437, validation accuracy is 0.656800
# Epoch 172, CIFAR-10 Batch 2:  loss is 0.199272, validation accuracy is 0.652400
# Epoch 172, CIFAR-10 Batch 3:  loss is 0.213833, validation accuracy is 0.651400
# Epoch 172, CIFAR-10 Batch 4:  loss is 0.192335, validation accuracy is 0.650200
# Epoch 172, CIFAR-10 Batch 5:  loss is 0.199483, validation accuracy is 0.652200
# Epoch 173, CIFAR-10 Batch 1:  loss is 0.220096, validation accuracy is 0.647600
# Epoch 173, CIFAR-10 Batch 2:  loss is 0.204312, validation accuracy is 0.646400
# Epoch 173, CIFAR-10 Batch 3:  loss is 0.210340, validation accuracy is 0.654400
# Epoch 173, CIFAR-10 Batch 4:  loss is 0.198254, validation accuracy is 0.647400
# Epoch 173, CIFAR-10 Batch 5:  loss is 0.194795, validation accuracy is 0.652800
# Epoch 174, CIFAR-10 Batch 1:  loss is 0.209334, validation accuracy is 0.654400
# Epoch 174, CIFAR-10 Batch 2:  loss is 0.199288, validation accuracy is 0.656800
# Epoch 174, CIFAR-10 Batch 3:  loss is 0.203997, validation accuracy is 0.655200
# Epoch 174, CIFAR-10 Batch 4:  loss is 0.184604, validation accuracy is 0.648600
# Epoch 174, CIFAR-10 Batch 5:  loss is 0.189702, validation accuracy is 0.657000
# Epoch 175, CIFAR-10 Batch 1:  loss is 0.208885, validation accuracy is 0.657400
# Epoch 175, CIFAR-10 Batch 2:  loss is 0.201328, validation accuracy is 0.660400
# Epoch 175, CIFAR-10 Batch 3:  loss is 0.200679, validation accuracy is 0.655800
# Epoch 175, CIFAR-10 Batch 4:  loss is 0.171836, validation accuracy is 0.653800
# Epoch 175, CIFAR-10 Batch 5:  loss is 0.186018, validation accuracy is 0.658400
# Epoch 176, CIFAR-10 Batch 1:  loss is 0.213437, validation accuracy is 0.646000
# Epoch 176, CIFAR-10 Batch 2:  loss is 0.215416, validation accuracy is 0.647800
# Epoch 176, CIFAR-10 Batch 3:  loss is 0.208015, validation accuracy is 0.647000
# Epoch 176, CIFAR-10 Batch 4:  loss is 0.180674, validation accuracy is 0.651400
# Epoch 176, CIFAR-10 Batch 5:  loss is 0.191720, validation accuracy is 0.659200
# Epoch 177, CIFAR-10 Batch 1:  loss is 0.210613, validation accuracy is 0.654800
# Epoch 177, CIFAR-10 Batch 2:  loss is 0.201537, validation accuracy is 0.646200
# Epoch 177, CIFAR-10 Batch 3:  loss is 0.200074, validation accuracy is 0.651400
# Epoch 177, CIFAR-10 Batch 4:  loss is 0.172242, validation accuracy is 0.653200
# Epoch 177, CIFAR-10 Batch 5:  loss is 0.185580, validation accuracy is 0.657200
# Epoch 178, CIFAR-10 Batch 1:  loss is 0.209808, validation accuracy is 0.652200
# Epoch 178, CIFAR-10 Batch 2:  loss is 0.205288, validation accuracy is 0.645000
# Epoch 178, CIFAR-10 Batch 3:  loss is 0.210625, validation accuracy is 0.653000
# Epoch 178, CIFAR-10 Batch 4:  loss is 0.172636, validation accuracy is 0.650600
# Epoch 178, CIFAR-10 Batch 5:  loss is 0.189115, validation accuracy is 0.653400
# Epoch 179, CIFAR-10 Batch 1:  loss is 0.203378, validation accuracy is 0.654200
# Epoch 179, CIFAR-10 Batch 2:  loss is 0.195236, validation accuracy is 0.657400
# Epoch 179, CIFAR-10 Batch 3:  loss is 0.193331, validation accuracy is 0.657600
# Epoch 179, CIFAR-10 Batch 4:  loss is 0.171650, validation accuracy is 0.651600
# Epoch 179, CIFAR-10 Batch 5:  loss is 0.174438, validation accuracy is 0.661400
# Epoch 180, CIFAR-10 Batch 1:  loss is 0.211338, validation accuracy is 0.646600
# Epoch 180, CIFAR-10 Batch 2:  loss is 0.195285, validation accuracy is 0.648400
# Epoch 180, CIFAR-10 Batch 3:  loss is 0.192200, validation accuracy is 0.660600
# Epoch 180, CIFAR-10 Batch 4:  loss is 0.173050, validation accuracy is 0.651800
# Epoch 180, CIFAR-10 Batch 5:  loss is 0.179842, validation accuracy is 0.654400
# Epoch 181, CIFAR-10 Batch 1:  loss is 0.211690, validation accuracy is 0.646000
# Epoch 181, CIFAR-10 Batch 2:  loss is 0.194971, validation accuracy is 0.651000
# Epoch 181, CIFAR-10 Batch 3:  loss is 0.194648, validation accuracy is 0.655800
# Epoch 181, CIFAR-10 Batch 4:  loss is 0.166014, validation accuracy is 0.657400
# Epoch 181, CIFAR-10 Batch 5:  loss is 0.165870, validation accuracy is 0.660400
# Epoch 182, CIFAR-10 Batch 1:  loss is 0.187858, validation accuracy is 0.656200
# Epoch 182, CIFAR-10 Batch 2:  loss is 0.183683, validation accuracy is 0.654400
# Epoch 182, CIFAR-10 Batch 3:  loss is 0.190392, validation accuracy is 0.658400
# Epoch 182, CIFAR-10 Batch 4:  loss is 0.165828, validation accuracy is 0.652800
# Epoch 182, CIFAR-10 Batch 5:  loss is 0.177608, validation accuracy is 0.647200
# Epoch 183, CIFAR-10 Batch 1:  loss is 0.202479, validation accuracy is 0.650400
# Epoch 183, CIFAR-10 Batch 2:  loss is 0.182357, validation accuracy is 0.657600
# Epoch 183, CIFAR-10 Batch 3:  loss is 0.192250, validation accuracy is 0.653600
# Epoch 183, CIFAR-10 Batch 4:  loss is 0.164580, validation accuracy is 0.655000
# Epoch 183, CIFAR-10 Batch 5:  loss is 0.166593, validation accuracy is 0.655000
# Epoch 184, CIFAR-10 Batch 1:  loss is 0.192180, validation accuracy is 0.654400
# Epoch 184, CIFAR-10 Batch 2:  loss is 0.184056, validation accuracy is 0.655000
# Epoch 184, CIFAR-10 Batch 3:  loss is 0.192166, validation accuracy is 0.653200
# Epoch 184, CIFAR-10 Batch 4:  loss is 0.160831, validation accuracy is 0.650800
# Epoch 184, CIFAR-10 Batch 5:  loss is 0.169024, validation accuracy is 0.661200
# Epoch 185, CIFAR-10 Batch 1:  loss is 0.191605, validation accuracy is 0.656800
# Epoch 185, CIFAR-10 Batch 2:  loss is 0.184709, validation accuracy is 0.652800
# Epoch 185, CIFAR-10 Batch 3:  loss is 0.191520, validation accuracy is 0.653800
# Epoch 185, CIFAR-10 Batch 4:  loss is 0.168657, validation accuracy is 0.644800
# Epoch 185, CIFAR-10 Batch 5:  loss is 0.173703, validation accuracy is 0.652200
# Epoch 186, CIFAR-10 Batch 1:  loss is 0.195496, validation accuracy is 0.647800
# Epoch 186, CIFAR-10 Batch 2:  loss is 0.192544, validation accuracy is 0.647600
# Epoch 186, CIFAR-10 Batch 3:  loss is 0.198386, validation accuracy is 0.643000
# Epoch 186, CIFAR-10 Batch 4:  loss is 0.167157, validation accuracy is 0.650600
# Epoch 186, CIFAR-10 Batch 5:  loss is 0.173559, validation accuracy is 0.649800
# Epoch 187, CIFAR-10 Batch 1:  loss is 0.186293, validation accuracy is 0.651000
# Epoch 187, CIFAR-10 Batch 2:  loss is 0.183200, validation accuracy is 0.652000
# Epoch 187, CIFAR-10 Batch 3:  loss is 0.184690, validation accuracy is 0.654000
# Epoch 187, CIFAR-10 Batch 4:  loss is 0.164555, validation accuracy is 0.651600
# Epoch 187, CIFAR-10 Batch 5:  loss is 0.178887, validation accuracy is 0.647200
# Epoch 188, CIFAR-10 Batch 1:  loss is 0.199908, validation accuracy is 0.645400
# Epoch 188, CIFAR-10 Batch 2:  loss is 0.181026, validation accuracy is 0.653800
# Epoch 188, CIFAR-10 Batch 3:  loss is 0.181431, validation accuracy is 0.652200
# Epoch 188, CIFAR-10 Batch 4:  loss is 0.163059, validation accuracy is 0.646000
# Epoch 188, CIFAR-10 Batch 5:  loss is 0.166287, validation accuracy is 0.651600
# Epoch 189, CIFAR-10 Batch 1:  loss is 0.185176, validation accuracy is 0.650400
# Epoch 189, CIFAR-10 Batch 2:  loss is 0.171006, validation accuracy is 0.652200
# Epoch 189, CIFAR-10 Batch 3:  loss is 0.175535, validation accuracy is 0.654200
# Epoch 189, CIFAR-10 Batch 4:  loss is 0.159618, validation accuracy is 0.651200
# Epoch 189, CIFAR-10 Batch 5:  loss is 0.174388, validation accuracy is 0.650800
# Epoch 190, CIFAR-10 Batch 1:  loss is 0.197455, validation accuracy is 0.644600
# Epoch 190, CIFAR-10 Batch 2:  loss is 0.181388, validation accuracy is 0.651000
# Epoch 190, CIFAR-10 Batch 3:  loss is 0.178918, validation accuracy is 0.651400
# Epoch 190, CIFAR-10 Batch 4:  loss is 0.164223, validation accuracy is 0.644200
# Epoch 190, CIFAR-10 Batch 5:  loss is 0.194277, validation accuracy is 0.640600
# Epoch 191, CIFAR-10 Batch 1:  loss is 0.195607, validation accuracy is 0.647400
# Epoch 191, CIFAR-10 Batch 2:  loss is 0.174541, validation accuracy is 0.657000
# Epoch 191, CIFAR-10 Batch 3:  loss is 0.187184, validation accuracy is 0.651000
# Epoch 191, CIFAR-10 Batch 4:  loss is 0.160176, validation accuracy is 0.643000
# Epoch 191, CIFAR-10 Batch 5:  loss is 0.172907, validation accuracy is 0.650000
# Epoch 192, CIFAR-10 Batch 1:  loss is 0.176381, validation accuracy is 0.658000
# Epoch 192, CIFAR-10 Batch 2:  loss is 0.169420, validation accuracy is 0.654000
# Epoch 192, CIFAR-10 Batch 3:  loss is 0.179302, validation accuracy is 0.651800
# Epoch 192, CIFAR-10 Batch 4:  loss is 0.160182, validation accuracy is 0.657000
# Epoch 192, CIFAR-10 Batch 5:  loss is 0.157505, validation accuracy is 0.656400
# Epoch 193, CIFAR-10 Batch 1:  loss is 0.173688, validation accuracy is 0.658200
# Epoch 193, CIFAR-10 Batch 2:  loss is 0.162477, validation accuracy is 0.651000
# Epoch 193, CIFAR-10 Batch 3:  loss is 0.177067, validation accuracy is 0.659000
# Epoch 193, CIFAR-10 Batch 4:  loss is 0.151972, validation accuracy is 0.654800
# Epoch 193, CIFAR-10 Batch 5:  loss is 0.150846, validation accuracy is 0.650800
# Epoch 194, CIFAR-10 Batch 1:  loss is 0.178881, validation accuracy is 0.651400
# Epoch 194, CIFAR-10 Batch 2:  loss is 0.160099, validation accuracy is 0.652600
# Epoch 194, CIFAR-10 Batch 3:  loss is 0.170375, validation accuracy is 0.654800
# Epoch 194, CIFAR-10 Batch 4:  loss is 0.148531, validation accuracy is 0.651800
# Epoch 194, CIFAR-10 Batch 5:  loss is 0.158003, validation accuracy is 0.657000
# Epoch 195, CIFAR-10 Batch 1:  loss is 0.176353, validation accuracy is 0.655800
# Epoch 195, CIFAR-10 Batch 2:  loss is 0.177143, validation accuracy is 0.654000
# Epoch 195, CIFAR-10 Batch 3:  loss is 0.176990, validation accuracy is 0.656800
# Epoch 195, CIFAR-10 Batch 4:  loss is 0.148622, validation accuracy is 0.660400
# Epoch 195, CIFAR-10 Batch 5:  loss is 0.151513, validation accuracy is 0.656000
# Epoch 196, CIFAR-10 Batch 1:  loss is 0.175494, validation accuracy is 0.650600
# Epoch 196, CIFAR-10 Batch 2:  loss is 0.164380, validation accuracy is 0.649400
# Epoch 196, CIFAR-10 Batch 3:  loss is 0.169561, validation accuracy is 0.654400
# Epoch 196, CIFAR-10 Batch 4:  loss is 0.147615, validation accuracy is 0.654400
# Epoch 196, CIFAR-10 Batch 5:  loss is 0.157955, validation accuracy is 0.656200
# Epoch 197, CIFAR-10 Batch 1:  loss is 0.178651, validation accuracy is 0.647800
# Epoch 197, CIFAR-10 Batch 2:  loss is 0.175087, validation accuracy is 0.651000
# Epoch 197, CIFAR-10 Batch 3:  loss is 0.172123, validation accuracy is 0.657800
# Epoch 197, CIFAR-10 Batch 4:  loss is 0.156745, validation accuracy is 0.648200
# Epoch 197, CIFAR-10 Batch 5:  loss is 0.166953, validation accuracy is 0.649200
# Epoch 198, CIFAR-10 Batch 1:  loss is 0.162344, validation accuracy is 0.652800
# Epoch 198, CIFAR-10 Batch 2:  loss is 0.163357, validation accuracy is 0.652400
# Epoch 198, CIFAR-10 Batch 3:  loss is 0.183230, validation accuracy is 0.653200
# Epoch 198, CIFAR-10 Batch 4:  loss is 0.153734, validation accuracy is 0.640600
# Epoch 198, CIFAR-10 Batch 5:  loss is 0.164685, validation accuracy is 0.655200
# Epoch 199, CIFAR-10 Batch 1:  loss is 0.168421, validation accuracy is 0.648000
# Epoch 199, CIFAR-10 Batch 2:  loss is 0.166994, validation accuracy is 0.652200
# Epoch 199, CIFAR-10 Batch 3:  loss is 0.173796, validation accuracy is 0.656600
# Epoch 199, CIFAR-10 Batch 4:  loss is 0.144555, validation accuracy is 0.649200
# Epoch 199, CIFAR-10 Batch 5:  loss is 0.150469, validation accuracy is 0.662400
# Epoch 200, CIFAR-10 Batch 1:  loss is 0.169547, validation accuracy is 0.650800
# Epoch 200, CIFAR-10 Batch 2:  loss is 0.161991, validation accuracy is 0.654400
# Epoch 200, CIFAR-10 Batch 3:  loss is 0.161946, validation accuracy is 0.649200
# Epoch 200, CIFAR-10 Batch 4:  loss is 0.146553, validation accuracy is 0.651000
# Epoch 200, CIFAR-10 Batch 5:  loss is 0.152822, validation accuracy is 0.655400

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6501551270484924

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
