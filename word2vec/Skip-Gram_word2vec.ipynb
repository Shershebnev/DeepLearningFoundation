# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
import math
import random
from collections import Counter
c = Counter(int_words)
threshold = 0.00001
train_words = [item for item in int_words if random.random() > 1 - math.sqrt(threshold / (c[item] / len(int_words)))]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    r = random.randrange(1, window_size + 1)
    return words[max(idx - r, 0):idx] + words[idx + 1: idx + r + 1]

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name="inputs")
    labels = tf.placeholder(tf.int32, [None, None], name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform(shape=[n_vocab, n_embedding], minval=-1, maxval=1, name="embedding"))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, ids=inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=0.1), name="softmax_w")# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros([n_vocab]), name="softmax_b")# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(weights=softmax_w, biases=softmax_b, inputs=embed, labels=labels, num_sampled=n_sampled, num_classes=n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: checkpoints: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6092 0.2655 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6113 0.2691 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4607 0.2724 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5689 0.2784 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4343 0.2810 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.4908 0.2835 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.4943 0.2831 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.4945 0.2840 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4224 0.2819 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3884 0.2821 sec/batch
# Nearest to known: front, judah, ide, gutierrez, redford, posting, paget, shorebirds,
# Nearest to see: domestication, greeks, valued, californians, mvp, alcibiades, collectively, assembling,
# Nearest to three: fits, willughby, romanized, scriptwriter, trainspotting, myopia, dianetics, falange,
# Nearest to when: cabled, zinn, bahini, nanos, tek, dressing, enforcer, medici,
# Nearest to such: etter, delores, pouches, whorehouse, iadb, nizam, office, divest,
# Nearest to time: plastics, thrashing, cronenberg, universals, wrestling, absurdities, genevi, statistically,
# Nearest to first: devising, worthies, orb, grimes, kms, formosa, quarreling, kenner,
# Nearest to at: popularized, detroit, neither, clot, swordsmen, monaro, astronomy, masculism,
# Nearest to versions: winifred, ngg, announcement, loaf, ahidjo, apprentices, troupe, mythical,
# Nearest to shown: reactant, potential, nigger, chessboard, confers, brushing, lego, generically,
# Nearest to nobel: codasyl, tongan, cancelled, pion, edmund, enron, codex, follett,
# Nearest to recorded: tigran, cops, gautama, nag, literati, yamaguchi, defects, intersected,
# Nearest to square: gropius, quadruple, rennie, kolhapur, montoya, connery, venetians, kroq,
# Nearest to ocean: suppose, carbide, orrin, posthuman, fetched, ihs, hopewell, descent,
# Nearest to rise: hedonistic, hydrology, mstings, frankish, character, verilog, tekoa, creighton,
# Nearest to channel: ket, intersexual, evolutionist, ventriloquist, raum, biot, reportage, doosra,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4431 0.2859 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3483 0.2801 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3247 0.2940 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2439 0.2846 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1236 0.2942 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1848 0.3057 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0754 0.2968 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0443 0.2860 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0140 0.2872 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0115 0.3045 sec/batch
# Nearest to known: front, judah, posting, break, realized, ide, gutierrez, did,
# Nearest to see: valued, domestication, greeks, mvp, engines, output, absolutely, manifesto,
# Nearest to three: fits, microcomputer, romanized, willughby, multiplayer, trainspotting, scriptwriter, myopia,
# Nearest to when: been, higher, cabled, present, bahini, nanos, failed, zinn,
# Nearest to such: etter, office, theory, program, whorehouse, perpetrator, divest, there,
# Nearest to time: plastics, cronenberg, wrestling, latter, universals, runs, drowned, patterns,
# Nearest to first: distinct, devising, worthies, pacino, freshman, thoughts, sort, trumpeter,
# Nearest to at: detroit, neither, popularized, astronomy, checked, reykjav, cat, believe,
# Nearest to versions: winifred, ngg, announcement, apprentices, done, mythical, troupe, tefnut,
# Nearest to shown: potential, reactant, electromagnetism, nigger, confers, links, imams, involving,
# Nearest to nobel: codasyl, cancelled, tongan, codex, edmund, enron, pion, follett,
# Nearest to recorded: gautama, cops, amateur, stairway, tigran, nag, defects, literati,
# Nearest to square: gropius, montoya, quadruple, sacred, kicked, rennie, connery, venetians,
# Nearest to ocean: suppose, posthuman, carbide, descent, orrin, ihs, mahilyow, hopewell,
# Nearest to rise: character, hydrology, mstings, frankish, hedonistic, undergoes, alekhine, statue,
# Nearest to channel: ket, ventriloquist, raum, topological, evolutionist, reportage, proud, amend,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9626 0.3050 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9011 0.3022 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8658 0.2885 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8836 0.2845 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8169 0.2907 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8333 0.3112 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8080 0.2835 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7991 0.2780 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8085 0.2778 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7754 0.2810 sec/batch
# Nearest to known: front, judah, break, gutierrez, permit, realized, overnight, posting,
# Nearest to see: domestication, greeks, valued, mvp, manifesto, collectively, absolutely, output,
# Nearest to three: microcomputer, utilised, myopia, fits, scriptwriter, nik, willughby, romanized,
# Nearest to when: zinn, been, cabled, bahini, higher, drowning, failed, pretended,
# Nearest to such: calculate, etter, experiments, positively, theory, office, whorehouse, likely,
# Nearest to time: plastics, wrestling, cronenberg, latter, universals, thrashing, drowned, runs,
# Nearest to first: orb, flames, distinct, parallels, freshman, devising, worthies, pacino,
# Nearest to at: detroit, popularized, neither, kinship, applause, spread, swordsmen, abraham,
# Nearest to versions: winifred, announcement, ngg, apprentices, mythical, done, ahidjo, troupe,
# Nearest to shown: potential, reactant, electromagnetism, nigger, generically, confers, poetically, requires,
# Nearest to nobel: codasyl, edmund, enron, codex, cancelled, tongan, rebellion, follett,
# Nearest to recorded: gautama, cops, nag, amateur, stairway, defects, literati, tigran,
# Nearest to square: gropius, montoya, quadruple, sacred, venetians, kicked, rennie, kroq,
# Nearest to ocean: suppose, posthuman, descent, carbide, mahilyow, pharmacology, orrin, turns,
# Nearest to rise: character, frankish, hydrology, mstings, hedonistic, undergoes, statue, collective,
# Nearest to channel: amend, ket, brings, ventriloquist, topological, reportage, evolutionist, slide,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7962 0.3083 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7484 0.3350 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7329 0.3024 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7142 0.2870 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7477 0.2829 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7125 0.2820 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6930 0.2815 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7140 0.2808 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7091 0.2792 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6368 0.2864 sec/batch
# Nearest to known: judah, front, break, gutierrez, overnight, realized, posting, expansions,
# Nearest to see: domestication, greeks, valued, mvp, collectively, californians, output, krupp,
# Nearest to three: seven, zero, one, myopia, joseph, nik, microcomputer, willughby,
# Nearest to when: cabled, bahini, zinn, drowning, been, compromised, combating, failed,
# Nearest to such: calculate, etter, whorehouse, theory, program, experiments, positively, pouches,
# Nearest to time: plastics, cronenberg, wrestling, universals, absurdities, statistically, champagne, aridity,
# Nearest to first: worthies, orb, freshman, flames, electorates, distinct, kms, grimes,
# Nearest to at: detroit, abraham, applause, kinship, popularized, adjusted, swordsmen, spread,
# Nearest to versions: winifred, ngg, announcement, apprentices, done, mythical, ahidjo, coca,
# Nearest to shown: potential, reactant, nigger, electromagnetism, confers, generically, brushing, poetically,
# Nearest to nobel: edmund, enron, gale, codex, leicestershire, follett, codasyl, prussian,
# Nearest to recorded: gautama, cops, literati, stairway, intersected, tigran, nag, amateur,
# Nearest to square: gropius, montoya, quadruple, sacred, rennie, venetians, kroq, tacitus,
# Nearest to ocean: suppose, carbide, posthuman, lake, descent, hopewell, orrin, mahilyow,
# Nearest to rise: frankish, hydrology, character, mstings, creighton, undergoes, motifs, verilog,
# Nearest to channel: ket, amend, brings, reportage, topological, ventriloquist, evolutionist, raum,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6697 0.2836 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6496 0.2861 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6237 0.3132 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6274 0.2860 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6289 0.2835 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6454 0.2845 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5887 0.2099 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5422 0.3022 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5293 0.2821 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5386 0.2825 sec/batch
# Nearest to known: judah, front, break, gutierrez, overnight, nut, realized, fringes,
# Nearest to see: greeks, domestication, valued, californians, parabola, output, manifesto, mvp,
# Nearest to three: zero, one, seven, nik, joseph, myopia, microcomputer, scriptwriter,
# Nearest to when: cabled, bahini, compromised, zinn, drowning, been, combating, failed,
# Nearest to such: calculate, etter, delores, theory, experiments, program, boosting, positively,
# Nearest to time: plastics, cronenberg, wrestling, absurdities, universals, unexploited, runs, statistically,
# Nearest to first: worthies, orb, freshman, grimes, formosa, pacino, waited, electorates,
# Nearest to at: swordsmen, detroit, applause, kinship, abraham, kirkwood, lighted, masculism,
# Nearest to versions: winifred, ngg, announcement, done, apprentices, mythical, ahidjo, coca,
# Nearest to shown: potential, reactant, nigger, electromagnetism, confers, lego, brushing, requires,
# Nearest to nobel: edmund, enron, follett, gale, leicestershire, prize, prussian, writers,
# Nearest to recorded: literati, gautama, cops, intersected, stairway, tigran, nag, amateur,
# Nearest to square: gropius, montoya, quadruple, kroq, rennie, venetians, sacred, caruana,
# Nearest to ocean: suppose, lake, descent, posthuman, carbide, icebergs, hopewell, km,
# Nearest to rise: frankish, hydrology, mstings, character, arithmetical, undergoes, creighton, verilog,
# Nearest to channel: ket, amend, brings, reportage, evolutionist, intersexual, deficient, ventriloquist,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4825 0.2863 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4990 0.2842 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4773 0.2830 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5298 0.2816 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4794 0.2833 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4520 0.2839 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4747 0.2839 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3798 0.2837 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4142 0.2840 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4077 0.2820 sec/batch
# Nearest to known: front, judah, gutierrez, realized, stately, expansions, fringes, nut,
# Nearest to see: greeks, californians, domestication, valued, parabola, manifesto, output, spectroscopic,
# Nearest to three: zero, seven, one, infrastructures, tissot, microcomputer, capita, myopia,
# Nearest to when: cabled, zinn, drowning, bahini, compromised, combating, been, failed,
# Nearest to such: calculate, etter, theory, delores, experiments, likely, pouches, whorehouse,
# Nearest to time: plastics, wrestling, absurdities, cronenberg, runs, statistically, unexploited, thrashing,
# Nearest to first: worthies, orb, glories, flames, formosa, venereal, grimes, freshman,
# Nearest to at: applause, kinship, swordsmen, detroit, lighted, biasing, kirkwood, clot,
# Nearest to versions: winifred, ngg, announcement, done, ahidjo, apprentices, somali, fairchild,
# Nearest to shown: potential, reactant, nigger, confers, electromagnetism, lego, requires, armorica,
# Nearest to nobel: edmund, follett, enron, gale, leicestershire, prize, writers, prussian,
# Nearest to recorded: literati, intersected, cops, tigran, readership, stairway, redford, gautama,
# Nearest to square: gropius, montoya, quadruple, kroq, sq, venetians, fathoms, rennie,
# Nearest to ocean: lake, km, coastal, extremes, shortwave, railways, airliners, sea,
# Nearest to rise: frankish, hydrology, mstings, arithmetical, undergoes, stunningly, airstrip, character,
# Nearest to channel: ket, brings, intersexual, ventriloquist, hopper, reportage, deficient, amend,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4294 0.2877 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3888 0.2849 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4362 0.2847 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3908 0.2824 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4232 0.2859 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4390 0.2847 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3498 0.2856 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3806 0.2852 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3895 0.2840 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3824 0.2833 sec/batch
# Nearest to known: judah, front, gutierrez, realized, fringes, break, solders, unhappiness,
# Nearest to see: greeks, californians, manifesto, spectroscopic, parabola, domestication, softpanorama, valued,
# Nearest to three: zero, seven, one, tissot, infrastructures, myopia, four, capita,
# Nearest to when: drowning, cabled, zinn, failed, compromised, bahini, been, woollen,
# Nearest to such: delores, calculate, likely, etter, program, theory, pouches, boosting,
# Nearest to time: plastics, wrestling, absurdities, cronenberg, thrashing, fast, unexploited, statistically,
# Nearest to first: orb, worthies, rusty, glories, flames, grimes, formosa, talents,
# Nearest to at: swordsmen, clot, detroit, lesbianism, applause, biasing, kirkwood, quarks,
# Nearest to versions: announcement, done, sony, winifred, ahidjo, ngg, apprentices, graphics,
# Nearest to shown: potential, reactant, nigger, confers, electromagnetism, requires, brushing, poetically,
# Nearest to nobel: edmund, prize, writers, follett, gale, enron, leicestershire, codex,
# Nearest to recorded: intersected, literati, cops, singers, redford, stairway, readership, intermingled,
# Nearest to square: gropius, montoya, quadruple, fathoms, kroq, sq, caruana, rennie,
# Nearest to ocean: km, lake, coastal, extremes, railways, shortwave, sea, situated,
# Nearest to rise: frankish, hydrology, mstings, stunningly, arithmetical, character, airstrip, undergoes,
# Nearest to channel: ket, intersexual, slide, glise, capital, ventriloquist, hopper, brings,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3710 0.2841 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3662 0.2835 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3415 0.2806 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3536 0.2792 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4000 0.2788 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3572 0.2771 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3994 0.2756 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3718 0.2748 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3059 0.2721 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3313 0.2716 sec/batch
# Nearest to known: judah, front, gutierrez, fringes, break, cno, unhappiness, expansions,
# Nearest to see: parabola, manifesto, californians, softpanorama, greeks, spectroscopic, domestication, revolutionaries,
# Nearest to three: zero, one, seven, four, eight, tissot, myopia, infrastructures,
# Nearest to when: drowning, zinn, failed, bahini, compromised, cabled, been, then,
# Nearest to such: etter, delores, calculate, likely, hamsun, boosting, program, pouches,
# Nearest to time: plastics, thrashing, absurdities, wrestling, statistically, fast, ices, universals,
# Nearest to first: worthies, orb, glories, rusty, kms, pacino, bellevue, resuscitation,
# Nearest to at: swordsmen, detroit, adjusted, clot, biasing, applause, outlying, lesbianism,
# Nearest to versions: announcement, winifred, sony, done, unix, apprentices, graphics, ahidjo,
# Nearest to shown: potential, reactant, nigger, confers, poetically, armorica, lego, brushing,
# Nearest to nobel: edmund, writers, prize, follett, enron, codex, leicestershire, gale,
# Nearest to recorded: redford, literati, cops, singers, intersected, tigran, readership, intermingled,
# Nearest to square: gropius, montoya, quadruple, sq, fathoms, caruana, kroq, rennie,
# Nearest to ocean: lake, extremes, coastal, km, railways, shortwave, situated, sea,
# Nearest to rise: frankish, mstings, stunningly, hydrology, arithmetical, airstrip, creighton, mackey,
# Nearest to channel: ket, intersexual, subfield, slide, glise, capital, ventriloquist, evolutionist,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3296 0.2746 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3116 0.2736 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3549 0.2721 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3730 0.2702 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3709 0.2716 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2891 0.2734 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2662 0.2725 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3246 0.2754 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2127 0.2740 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2614 0.2729 sec/batch
# Nearest to known: judah, front, gutierrez, fringes, unhappiness, cno, algae, solders,
# Nearest to see: softpanorama, parabola, spectroscopic, valued, manifesto, californians, basaltic, languages,
# Nearest to three: zero, one, seven, eight, four, tissot, five, nik,
# Nearest to when: drowning, failed, then, bahini, cabled, zinn, compromised, been,
# Nearest to such: delores, etter, hamsun, calculate, likely, quality, simplified, subfield,
# Nearest to time: plastics, wrestling, thrashing, absurdities, universals, fast, runs, forerunners,
# Nearest to first: worthies, rusty, grimes, resuscitation, orb, bellevue, formosa, waited,
# Nearest to at: swordsmen, detroit, adjusted, clot, applause, biasing, lesbianism, unrecognised,
# Nearest to versions: announcement, winifred, sony, unix, fairchild, graphics, apprentices, ahidjo,
# Nearest to shown: potential, reactant, nigger, confers, poetically, lego, provisioning, armorica,
# Nearest to nobel: edmund, prize, writers, follett, codex, adler, gale, snooker,
# Nearest to recorded: singers, literati, redford, intersected, stairway, readership, cops, tigran,
# Nearest to square: gropius, quadruple, montoya, caruana, fathoms, expressway, sq, kroq,
# Nearest to ocean: lake, coastal, shortwave, railways, extremes, situated, km, hopewell,
# Nearest to rise: frankish, stunningly, arithmetical, mstings, hydrology, carmelite, mackey, airstrip,
# Nearest to channel: capital, ket, intersexual, slide, silk, ventriloquist, glise, evolutionist,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3129 0.2982 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2970 0.3191 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3212 0.1545 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2527 0.3325 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2481 0.3355 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2163 0.3411 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1839 0.3360 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1816 0.3371 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2097 0.3350 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1581 0.3375 sec/batch
# Nearest to known: judah, fringes, front, gutierrez, break, redford, micelle, nut,
# Nearest to see: basaltic, parabola, softpanorama, californians, krupp, greeks, manifesto, spectroscopic,
# Nearest to three: zero, one, seven, four, eight, five, unpaved, tissot,
# Nearest to when: drowning, failed, then, bahini, cabled, been, cdr, zinn,
# Nearest to such: delores, hamsun, etter, quality, calculate, likely, pouches, reacted,
# Nearest to time: plastics, thrashing, wrestling, absurdities, runs, fast, dissolute, ices,
# Nearest to first: worthies, rusty, grimes, xing, resuscitation, bellevue, orb, glories,
# Nearest to at: swordsmen, detroit, adjusted, meandering, outlying, clot, biasing, quarks,
# Nearest to versions: announcement, sony, fairchild, winifred, graphics, ahidjo, unix, apprentices,
# Nearest to shown: potential, reactant, nigger, poetically, confers, lego, provisioning, sidewise,
# Nearest to nobel: prize, edmund, writers, follett, codex, adler, cupboard, frankfurt,
# Nearest to recorded: singers, redford, literati, stairway, tigran, intersected, cops, readership,
# Nearest to square: montoya, fathoms, quadruple, gropius, sq, caruana, expressway, kroq,
# Nearest to ocean: lake, shortwave, situated, railways, extremes, carbide, hopewell, coastal,
# Nearest to rise: frankish, stunningly, mstings, arithmetical, hydrology, mackey, carmelite, airstrip,
# Nearest to channel: ket, intersexual, slide, capital, brings, cytokinesis, silk, glise,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2349 0.3351 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2246 0.3245 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2067 0.3222 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1077 0.3330 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1626 0.2820 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1654 0.2739 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1361 0.2738 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1844 0.2702 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1934 0.2698 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1869 0.2694 sec/batch
# Nearest to known: judah, algae, fringes, front, micelle, break, stately, amesbury,
# Nearest to see: spectroscopic, parabola, basaltic, softpanorama, collection, valued, californians, uncodified,
# Nearest to three: zero, one, seven, four, eight, five, six, two,
# Nearest to when: drowning, then, failed, bahini, cabled, ordered, compromised, been,
# Nearest to such: delores, hamsun, etter, of, likely, quality, calculate, boosting,
# Nearest to time: plastics, thrashing, absurdities, wrestling, runs, ices, fast, cip,
# Nearest to first: rusty, xing, worthies, successful, kms, sad, archetypical, krew,
# Nearest to at: adjusted, swordsmen, quarks, lesbianism, clot, detroit, applause, siro,
# Nearest to versions: announcement, sony, fairchild, winifred, unix, apprentices, graphics, ahidjo,
# Nearest to shown: potential, reactant, nigger, poetically, confers, explainable, lego, brushing,
# Nearest to nobel: prize, writers, edmund, follett, codex, adler, cupboard, frankfurt,
# Nearest to recorded: singers, literati, redford, intersected, readership, flicks, cops, intermingled,
# Nearest to square: montoya, fathoms, gropius, quadruple, expressway, caruana, sq, kroq,
# Nearest to ocean: shortwave, lake, hopewell, carbide, situated, savannas, extremes, oligocene,
# Nearest to rise: frankish, stunningly, arithmetical, hydrology, mstings, mackey, airstrip, undergoes,
# Nearest to channel: ket, intersexual, slide, hopper, gabrieli, glise, cytokinesis, reportage,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1610 0.2729 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2117 0.2701 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1597 0.2701 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1186 0.2705 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1539 0.2694 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1715 0.2685 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1648 0.2678 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1477 0.2720 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1363 0.2710 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1318 0.2701 sec/batch
# Nearest to known: judah, fringes, algae, gutierrez, front, micelle, stately, amesbury,
# Nearest to see: basaltic, nyasaland, list, spectroscopic, collection, softpanorama, geography, parabola,
# Nearest to three: zero, one, seven, eight, four, five, two, six,
# Nearest to when: drowning, then, failed, bahini, sung, cabled, compromised, ordered,
# Nearest to such: delores, hamsun, etter, quality, calculate, colored, likely, pouches,
# Nearest to time: absurdities, thrashing, plastics, wrestling, runs, cip, ices, actuality,
# Nearest to first: rusty, worthies, archetypical, successful, xing, resuscitation, bellevue, krew,
# Nearest to at: adjusted, swordsmen, quarks, lesbianism, siro, applause, detroit, meandering,
# Nearest to versions: announcement, sony, fairchild, winifred, unix, ahidjo, apprentices, graphics,
# Nearest to shown: potential, reactant, nigger, poetically, explainable, confers, lego, brushing,
# Nearest to nobel: prize, writers, follett, edmund, adler, codex, cupboard, frankfurt,
# Nearest to recorded: singers, literati, redford, intermingled, flicks, intersected, readership, tigran,
# Nearest to square: quadruple, gropius, caruana, expressway, fathoms, montoya, sacred, kroq,
# Nearest to ocean: shortwave, lake, situated, hopewell, oligocene, lush, savannas, railways,
# Nearest to rise: frankish, stunningly, mstings, arithmetical, hydrology, optimistic, mackey, undergoes,
# Nearest to channel: ket, hopper, cytokinesis, slide, gabrieli, equipment, capital, intersexual,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2067 0.2715 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1754 0.2709 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1436 0.2693 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1496 0.2702 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1129 0.2696 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1134 0.2707 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1160 0.2710 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1369 0.2705 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1988 0.2736 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1953 0.2711 sec/batch
# Nearest to known: judah, fringes, front, stately, kossuth, algae, gutierrez, amesbury,
# Nearest to see: nyasaland, list, geography, krupp, softpanorama, basaltic, spectroscopic, organisation,
# Nearest to three: one, zero, seven, eight, four, five, two, six,
# Nearest to when: drowning, then, failed, bahini, woollen, been, compromised, zinn,
# Nearest to such: delores, hamsun, etter, buber, mosques, reacted, penalized, shelved,
# Nearest to time: absurdities, thrashing, wrestling, plastics, cip, actuality, dissolute, champagne,
# Nearest to first: rusty, worthies, mengistu, successful, archetypical, xing, grimes, resuscitation,
# Nearest to at: swordsmen, applause, bachelor, adjusted, outlying, detroit, unrecognised, andrews,
# Nearest to versions: announcement, fairchild, winifred, sony, unix, ahidjo, qmail, apprentices,
# Nearest to shown: potential, poetically, nigger, reactant, confers, explainable, sidewise, brushing,
# Nearest to nobel: prize, writers, follett, edmund, adler, codex, cupboard, frankfurt,
# Nearest to recorded: singers, redford, literati, intermingled, tigran, flicks, intersected, readership,
# Nearest to square: expressway, caruana, quadruple, gropius, fathoms, sacred, montoya, kroq,
# Nearest to ocean: shortwave, hopewell, icebergs, oligocene, situated, lush, carbide, lake,
# Nearest to rise: frankish, stunningly, mstings, carmelite, hydrology, optimistic, mackey, airstrip,
# Nearest to channel: ket, cytokinesis, equipment, hopper, macro, capital, slide, encrypted,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.1808 0.2747 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.0913 0.2720 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1084 0.2702 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1091 0.2821 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0345 0.2740 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1164 0.2726 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1434 0.2746 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.0969 0.2721 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1434 0.0595 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0956 0.2753 sec/batch
# Nearest to known: judah, algae, fringes, front, stately, amesbury, break, redford,
# Nearest to see: list, basaltic, nyasaland, spectroscopic, collection, mvp, organisation, softpanorama,
# Nearest to three: one, zero, seven, four, eight, five, two, six,
# Nearest to when: drowning, then, failed, bahini, woollen, stationed, epimorphism, cdr,
# Nearest to such: delores, hamsun, etter, colored, quality, seen, buber, msg,
# Nearest to time: absurdities, thrashing, plastics, cip, ices, wrestling, runs, actuality,
# Nearest to first: rusty, worthies, xing, successful, archetypical, mengistu, glories, krew,
# Nearest to at: adjusted, meandering, bachelor, swordsmen, quarks, applause, unrecognised, siro,
# Nearest to versions: announcement, fairchild, unix, qmail, sony, graphics, cgi, winifred,
# Nearest to shown: potential, reactant, nigger, poetically, confers, explainable, wumpus, lilly,
# Nearest to nobel: prize, follett, writers, edmund, adler, cupboard, codex, pion,
# Nearest to recorded: redford, singers, literati, flicks, intermingled, tigran, intersected, cops,
# Nearest to square: expressway, gropius, quadruple, caruana, sacred, montoya, fathoms, circumference,
# Nearest to ocean: shortwave, hopewell, icebergs, carbide, oligocene, burrowing, lake, lush,
# Nearest to rise: frankish, mstings, stunningly, arithmetical, hydrology, optimistic, mackey, carmelite,
# Nearest to channel: ket, capital, cytokinesis, macro, encrypted, hopper, intersexual, silk,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0666 0.2762 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0380 0.2723 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0886 0.2733 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 3.9867 0.2722 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0448 0.2740 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0015 0.2728 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0418 0.2783 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0372 0.2721 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0963 0.2735 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.9826 0.2743 sec/batch
# Nearest to known: algae, judah, stately, front, these, fringes, basic, break,
# Nearest to see: list, nyasaland, basaltic, mvp, geography, californians, organisation, none,
# Nearest to three: one, zero, seven, four, five, eight, two, six,
# Nearest to when: drowning, then, failed, bahini, woollen, stationed, ordered, to,
# Nearest to such: delores, hamsun, colored, quality, penalized, seen, etter, npcs,
# Nearest to time: absurdities, thrashing, plastics, actuality, runs, sensed, cip, wrestling,
# Nearest to first: rusty, successful, worthies, all, the, xing, errand, krew,
# Nearest to at: meandering, adjusted, bachelor, quarks, siro, interceptor, swordsmen, outlying,
# Nearest to versions: announcement, fairchild, mk, sony, unix, qmail, winifred, xvii,
# Nearest to shown: potential, reactant, nigger, poetically, explainable, confers, sidewise, lilly,
# Nearest to nobel: prize, follett, writers, adler, cupboard, eccles, niacin, pion,
# Nearest to recorded: singers, redford, literati, flicks, intermingled, intersected, readership, betsy,
# Nearest to square: expressway, quadruple, sacred, caruana, inscription, fathoms, montoya, circumference,
# Nearest to ocean: shortwave, hopewell, icebergs, carbide, oligocene, situated, burrowing, lush,
# Nearest to rise: frankish, stunningly, mackey, carmelite, tailback, mstings, optimistic, hydrology,
# Nearest to channel: ket, cytokinesis, hopper, reportage, macro, intersexual, encrypted, timestamp,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9662 0.2782 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0057 0.2745 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9653 0.2763 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0107 0.3058 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0327 0.2929 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0257 0.2836 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0480 0.3163 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0988 0.3065 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0100 0.2849 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0041 0.2791 sec/batch
# Nearest to known: fringes, algae, stately, judah, basic, front, cygnus, solders,
# Nearest to see: list, basaltic, nyasaland, mvp, spectroscopic, none, arbiter, californians,
# Nearest to three: one, zero, seven, four, five, eight, two, six,
# Nearest to when: drowning, then, failed, woollen, to, bahini, been, cdr,
# Nearest to such: delores, hamsun, etter, buber, posteriori, colored, of, seen,
# Nearest to time: absurdities, plastics, ices, thrashing, sensed, cip, actuality, calculate,
# Nearest to first: rusty, worthies, all, successful, archetypical, the, krew, xing,
# Nearest to at: adjusted, meandering, bachelor, quarks, swordsmen, siro, acetaminophen, outlying,
# Nearest to versions: announcement, xvii, qmail, fairchild, mk, typographical, cgi, adsorbed,
# Nearest to shown: potential, reactant, poetically, nigger, explainable, confers, heterocyclic, sidewise,
# Nearest to nobel: prize, writers, follett, adler, niacin, eccles, edmund, frankfurt,
# Nearest to recorded: singers, redford, flicks, intermingled, intersected, literati, readership, betsy,
# Nearest to square: expressway, quadruple, circumference, sacred, inscription, fathoms, caruana, kroq,
# Nearest to ocean: shortwave, hopewell, icebergs, intelsat, carbide, oligocene, burrowing, railways,
# Nearest to rise: frankish, stunningly, hydrology, arithmetical, mstings, optimistic, tailback, mackey,
# Nearest to channel: ket, cytokinesis, hopper, hijjah, gabrieli, departures, capital, reportage,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0285 0.3153 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0495 0.3085 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0571 0.2751 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 3.9988 0.2754 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0430 0.2747 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0168 0.2748 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0306 0.2739 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0140 0.2741 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0274 0.2733 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0176 0.2740 sec/batch
# Nearest to known: fringes, judah, stately, front, algae, kossuth, basic, cygnus,
# Nearest to see: list, nyasaland, basaltic, mvp, none, geography, organisation, californians,
# Nearest to three: one, zero, seven, four, five, eight, two, six,
# Nearest to when: drowning, then, to, woollen, been, bahini, failed, was,
# Nearest to such: delores, hamsun, etter, buber, shelved, penalized, quality, colored,
# Nearest to time: absurdities, thrashing, calculate, plastics, actuality, ices, sensed, altogether,
# Nearest to first: rusty, worthies, all, archetypical, the, mengistu, successful, clc,
# Nearest to at: adjusted, bachelor, swordsmen, andrews, edict, outlying, meandering, scholastica,
# Nearest to versions: announcement, solaris, qmail, xvii, playstation, typographical, mk, cgi,
# Nearest to shown: potential, poetically, reactant, nigger, sidewise, explainable, confers, serre,
# Nearest to nobel: prize, writers, follett, adler, niacin, pion, eccles, tongan,
# Nearest to recorded: singers, intermingled, flicks, redford, intersected, literati, readership, defects,
# Nearest to square: expressway, sacred, quadruple, caruana, inscription, gropius, kroq, circumference,
# Nearest to ocean: shortwave, hopewell, icebergs, carbide, intelsat, oligocene, burrowing, railways,
# Nearest to rise: frankish, stunningly, optimistic, mackey, mstings, carmelite, tailback, arithmetical,
# Nearest to channel: ket, cytokinesis, hopper, encrypted, hijjah, departures, equipment, timestamp,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0000 0.2778 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9669 0.2772 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0094 0.2732 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0222 0.2750 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0391 0.2764 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.0864 0.2757 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0971 0.2761 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0198 0.2757 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9806 0.2744 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0172 0.2759 sec/batch
# Nearest to known: fringes, stately, cygnus, judah, basic, front, algae, kossuth,
# Nearest to see: list, nyasaland, organisation, external, none, geography, mvp, wiktionary,
# Nearest to three: one, zero, seven, four, five, eight, two, six,
# Nearest to when: drowning, to, then, woollen, failed, been, bahini, was,
# Nearest to such: delores, hamsun, etter, shelved, colored, imago, quality, buber,
# Nearest to time: absurdities, thrashing, calculate, ices, wrestling, actuality, sensed, plastics,
# Nearest to first: rusty, worthies, mengistu, archetypical, all, the, clc, iee,
# Nearest to at: adjusted, bachelor, interceptor, swordsmen, meandering, squaw, andrews, ancillon,
# Nearest to versions: announcement, xvii, qmail, mk, adsorbed, solaris, typographical, cnes,
# Nearest to shown: potential, poetically, reactant, nigger, explainable, sidewise, lilly, confers,
# Nearest to nobel: prize, follett, writers, adler, eccles, niacin, physicist, edmund,
# Nearest to recorded: redford, singers, flicks, intermingled, tigran, intersected, songwriter, skaldic,
# Nearest to square: sacred, expressway, quadruple, caruana, kroq, gropius, connery, montoya,
# Nearest to ocean: shortwave, hopewell, icebergs, carbide, intelsat, oligocene, burrowing, mahilyow,
# Nearest to rise: frankish, carmelite, stunningly, optimistic, mackey, tailback, mstings, hydrology,
# Nearest to channel: ket, cytokinesis, encrypted, hopper, macro, timestamp, reportage, departures,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.8967 0.2778 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9976 0.2746 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 3.9839 0.2746 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.9910 0.2757 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0427 0.2755 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0349 0.2632 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9938 0.2744 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9698 0.2755 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9883 0.2755 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9473 0.2756 sec/batch
# Nearest to known: stately, fringes, cygnus, algae, basic, judah, amesbury, joint,
# Nearest to see: list, nyasaland, none, external, mvp, organisation, ballantine, geography,
# Nearest to three: one, zero, seven, four, two, five, eight, six,
# Nearest to when: drowning, to, was, then, woollen, bahini, failed, been,
# Nearest to such: delores, hamsun, etter, seen, colored, imago, buber, those,
# Nearest to time: absurdities, sensed, thrashing, ices, calculate, actuality, wrestling, celebrated,
# Nearest to first: rusty, was, mengistu, worthies, the, thanksgiving, all, xing,
# Nearest to at: bachelor, adjusted, meandering, acetaminophen, outlying, interceptor, squaw, students,
# Nearest to versions: announcement, xvii, mk, solaris, qmail, cnes, apprentices, adsorbed,
# Nearest to shown: potential, reactant, poetically, nigger, explainable, heterocyclic, colonists, confers,
# Nearest to nobel: prize, follett, adler, writers, niacin, eccles, recipient, theodore,
# Nearest to recorded: redford, singers, intermingled, flicks, codifying, tigran, literati, songwriter,
# Nearest to square: sacred, expressway, kroq, quadruple, caruana, inscription, circumference, montoya,
# Nearest to ocean: shortwave, hopewell, icebergs, carbide, sea, intelsat, oligocene, burrowing,
# Nearest to rise: frankish, carmelite, optimistic, tailback, mstings, stunningly, hydrology, mackey,
# Nearest to channel: ket, cytokinesis, encrypted, hopper, macro, reportage, timestamp, departures,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9407 0.2795 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9477 0.2770 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9657 0.2742 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9878 0.2762 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9964 0.2745 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9731 0.2751 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8903 0.2769 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9358 0.2760 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.8824 0.2758 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9349 0.2721 sec/batch
# Nearest to known: basic, fringes, algae, usages, stately, joint, cygnus, break,
# Nearest to see: list, mvp, geography, none, basaltic, nyasaland, external, biochemistry,
# Nearest to three: one, zero, seven, five, four, two, eight, six,
# Nearest to when: drowning, to, then, woollen, been, failed, was, bahini,
# Nearest to such: delores, of, colored, shelved, hamsun, etter, seen, those,
# Nearest to time: absurdities, sensed, ices, thrashing, calculate, actuality, wrestling, runs,
# Nearest to first: rusty, the, was, successful, opener, all, reconstructions, thanksgiving,
# Nearest to at: bachelor, adjusted, meandering, in, acetaminophen, dq, students, squaw,
# Nearest to versions: announcement, xvii, mk, qmail, cnes, ahidjo, adsorbed, apprentices,
# Nearest to shown: potential, poetically, reactant, explainable, nigger, confers, colonists, heterocyclic,
# Nearest to nobel: prize, follett, niacin, adler, eccles, writers, pion, nikolaevich,
# Nearest to recorded: singers, redford, flicks, intermingled, codifying, reinforcing, skaldic, intersected,
# Nearest to square: expressway, sacred, circumference, caruana, inscription, kroq, quadruple, montoya,
# Nearest to ocean: shortwave, hopewell, intelsat, icebergs, carbide, sea, oligocene, radiotelephone,
# Nearest to rise: frankish, tailback, carmelite, stunningly, optimistic, mstings, hydrology, arithmetical,
# Nearest to channel: ket, cytokinesis, hopper, reportage, timestamp, encrypted, hijjah, npcs,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9523 0.2780 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9442 0.2768 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9479 0.2802 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9808 0.2824 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0036 0.2853 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.8785 0.2860 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9599 0.2844 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9516 0.2878 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9841 0.2859 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9451 0.2884 sec/batch
# Nearest to known: basic, usages, joint, cygnus, stately, break, algae, fringes,
# Nearest to see: list, none, mvp, nyasaland, external, encompassing, organisation, basaltic,
# Nearest to three: one, zero, seven, four, five, eight, two, six,
# Nearest to when: to, drowning, then, woollen, failed, been, was, bahini,
# Nearest to such: delores, of, hamsun, shelved, etter, those, colored, potentiation,
# Nearest to time: absurdities, ices, calculate, thrashing, actuality, sensed, runs, distortion,
# Nearest to first: rusty, was, the, successful, worthies, all, reconstructions, thanksgiving,
# Nearest to at: bachelor, adjusted, dq, students, meandering, andrews, acetaminophen, in,
# Nearest to versions: announcement, xvii, mk, qmail, cnes, adsorbed, apprentices, solaris,
# Nearest to shown: potential, poetically, explainable, reactant, nigger, brushing, heterocyclic, confers,
# Nearest to nobel: prize, follett, niacin, adler, recipient, writers, eccles, nikolaevich,
# Nearest to recorded: singers, flicks, intermingled, redford, pseudalopex, live, skaldic, reinforcing,
# Nearest to square: sacred, expressway, circumference, caruana, kroq, inscription, underground, courtyards,
# Nearest to ocean: shortwave, hopewell, intelsat, icebergs, suppose, carbide, radiotelephone, sea,
# Nearest to rise: frankish, tailback, optimistic, mackey, arithmetical, stunningly, christe, carmelite,
# Nearest to channel: ket, cytokinesis, hopper, encrypted, reportage, timestamp, television, hijjah,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9441 0.2907 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9403 0.2861 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9320 0.2870 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9597 0.2873 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9700 0.2900 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9466 0.2881 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9462 0.2878 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9167 0.2905 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9426 0.2895 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0165 0.2910 sec/batch
# Nearest to known: joint, basic, stately, usages, break, algae, fringes, cygnus,
# Nearest to see: list, nyasaland, external, none, mvp, geography, miscellaneous, listed,
# Nearest to three: one, zero, seven, four, five, eight, two, six,
# Nearest to when: to, drowning, then, woollen, been, failed, in, with,
# Nearest to such: delores, hamsun, imago, buber, etter, shelved, mukti, of,
# Nearest to time: absurdities, calculate, ices, actuality, calculating, thrashing, americano, eventual,
# Nearest to first: was, rusty, the, worthies, mengistu, all, successful, reconstructions,
# Nearest to at: bachelor, adjusted, students, in, acetaminophen, dq, ancillon, meandering,
# Nearest to versions: announcement, mk, xvii, qmail, cnes, solaris, adsorbed, gradius,
# Nearest to shown: poetically, potential, explainable, reactant, nigger, heterocyclic, colonists, unnumbered,
# Nearest to nobel: prize, niacin, follett, adler, writers, recipient, eccles, awarded,
# Nearest to recorded: singers, intermingled, redford, skaldic, flicks, codifying, reinforcing, aisha,
# Nearest to square: expressway, sacred, caruana, inscription, quadruple, kroq, circumference, courtyards,
# Nearest to ocean: shortwave, hopewell, intelsat, radiotelephone, indian, icebergs, sea, intersputnik,
# Nearest to rise: frankish, optimistic, christe, tailback, carmelite, shingon, hydrology, arithmetical,
# ...
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.7966 0.2835 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8073 0.2813 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.7749 0.2799 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.7923 0.2797 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8569 0.2805 sec/batch
# Nearest to known: is, adoption, usages, while, honoring, name, joint, used,
# Nearest to see: list, of, external, links, this, many, article, listed,
# Nearest to three: one, two, four, five, zero, seven, eight, six,
# Nearest to when: to, been, with, learnt, the, was, in, then,
# Nearest to such: of, and, as, is, those, are, this, a,
# Nearest to time: for, to, the, both, in, and, coordinator, years,
# Nearest to first: was, the, in, been, second, later, after, introduced,
# Nearest to at: in, both, bachelor, doctorate, of, the, and, a,
# Nearest to versions: mk, dabney, xvii, part, gradius, announcement, adsorbed, qmail,
# Nearest to shown: colonists, hyperplane, novelization, explainable, sidewise, tortuous, obvious, strikeout,
# Nearest to nobel: prize, recipient, awarded, niacin, adler, biochemist, writers, eccles,
# Nearest to recorded: records, codifying, live, flicks, oxfordshire, pseudalopex, redford, eponymous,
# Nearest to square: courtyards, busts, connery, expressway, shangri, kilometre, caruana, circumference,
# Nearest to ocean: shortwave, intelsat, indian, radiotelephone, emirate, strait, intersputnik, capeverdean,
# Nearest to rise: shingon, frankish, tailback, nostalgic, evident, fortunes, hydrology, coordinates,
# Nearest to channel: television, cytokinesis, ket, encrypted, ctv, timestamp, hereby, pleases,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.7501 0.2841 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8050 0.2797 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.7940 0.2802 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.7963 0.2802 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.7716 0.2779 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8157 0.2788 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8152 0.2789 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8107 0.2792 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8231 0.2776 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8300 0.2774 sec/batch
# Nearest to known: is, adoption, while, usages, name, refers, being, honoring,
# Nearest to see: list, of, external, links, many, article, for, listed,
# Nearest to three: one, two, four, seven, five, zero, eight, six,
# Nearest to when: to, been, the, in, with, learnt, then, drowning,
# Nearest to such: of, and, most, those, also, as, a, there,
# Nearest to time: for, to, both, years, the, was, and, he,
# Nearest to first: was, the, in, been, which, second, later, after,
# Nearest to at: in, both, of, the, doctorate, bachelor, as, from,
# Nearest to versions: mk, xvii, part, dabney, gradius, announcement, version, qmail,
# Nearest to shown: novelization, colonists, obvious, sitcoms, explainable, recur, annoy, poetically,
# Nearest to nobel: prize, awarded, recipient, niacin, adler, biochemist, writers, winners,
# Nearest to recorded: records, codifying, live, pseudalopex, eponymous, calibration, flicks, redford,
# Nearest to square: courtyards, connery, shangri, busts, expressway, yoshitaka, caruana, underground,
# Nearest to ocean: shortwave, intelsat, indian, radiotelephone, emirate, intersputnik, strait, carbide,
# Nearest to rise: shingon, frankish, telecommunication, tailback, evident, nostalgic, unsettling, fortunes,
# Nearest to channel: television, cytokinesis, ket, encrypted, timestamp, ctv, isle, pleases,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8140 0.2799 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.7631 0.2785 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.7801 0.2795 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.7833 0.2767 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8546 0.2780 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8010 0.2754 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9217 0.2768 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8396 0.2770 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8485 0.2775 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7980 0.2753 sec/batch
# Nearest to known: is, while, adoption, name, usages, honoring, used, basic,
# Nearest to see: list, external, links, of, article, references, many, listed,
# Nearest to three: one, two, four, seven, zero, five, eight, six,
# Nearest to when: to, been, learnt, with, then, in, was, the,
# Nearest to such: of, as, and, also, a, those, most, there,
# Nearest to time: for, to, was, both, years, he, weaned, methodically,
# Nearest to first: was, in, the, been, later, after, which, second,
# Nearest to at: in, both, bachelor, of, doctorate, students, dq, as,
# Nearest to versions: mk, part, xvii, dabney, gradius, janus, qmail, adsorbed,
# Nearest to shown: novelization, strikeout, recur, sidewise, obvious, explainable, printmaking, hyperplane,
# Nearest to nobel: prize, recipient, awarded, niacin, biochemist, adler, writers, winners,
# Nearest to recorded: records, codifying, live, redford, pseudalopex, eponymous, defects, cremated,
# Nearest to square: courtyards, connery, busts, expressway, underground, shangri, caruana, yoshitaka,
# Nearest to ocean: shortwave, intelsat, indian, emirate, radiotelephone, strait, intersputnik, capeverdean,
# Nearest to rise: shingon, telecommunication, frankish, evident, tailback, fortunes, nostalgic, hydrology,
# Nearest to channel: ket, cytokinesis, timestamp, television, encrypted, ctv, pleases, hereby,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7328 0.2777 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.7941 0.2749 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7646 0.2763 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8350 0.2753 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.7790 0.2754 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.7894 0.2749 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8149 0.1807 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.7929 0.2751 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.7752 0.2736 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8448 0.2736 sec/batch
# Nearest to known: is, while, name, adoption, usages, used, joint, basic,
# Nearest to see: list, of, external, links, references, also, article, listed,
# Nearest to three: one, two, four, zero, seven, five, eight, six,
# Nearest to when: to, with, been, was, in, learnt, the, then,
# Nearest to such: as, of, and, most, a, also, those, are,
# Nearest to time: for, to, the, both, years, in, was, and,
# Nearest to first: was, the, in, later, after, which, a, been,
# Nearest to at: in, the, of, both, to, a, from, and,
# Nearest to versions: mk, xvii, part, janus, dabney, version, inhabitant, announcement,
# Nearest to shown: explainable, hyperplane, printmaking, obvious, novelization, sidewise, strikeout, annoy,
# Nearest to nobel: prize, recipient, awarded, niacin, biochemist, adler, winners, laureate,
# Nearest to recorded: records, codifying, live, redford, eponymous, calibration, pseudalopex, cremated,
# Nearest to square: courtyards, connery, busts, expressway, sagrada, shangri, kilometre, yoshitaka,
# Nearest to ocean: shortwave, intelsat, emirate, indian, strait, intersputnik, capeverdean, radiotelephone,
# Nearest to rise: shingon, frankish, evident, telecommunication, swath, fortunes, nostalgic, tailback,
# Nearest to channel: ket, cytokinesis, television, timestamp, encrypted, ctv, pbs, pleases,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7536 0.2765 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7670 0.2749 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7308 0.2755 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7576 0.3198 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8015 0.3230 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.7747 0.3245 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8163 0.3290 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.6813 0.3283 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7952 0.3287 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7113 0.3232 sec/batch
# Nearest to known: is, while, name, used, adoption, as, being, basic,
# Nearest to see: list, of, external, links, also, a, for, references,
# Nearest to three: two, one, four, zero, seven, five, eight, six,
# Nearest to when: to, then, the, with, in, been, learnt, was,
# Nearest to such: of, as, and, a, also, is, the, are,
# Nearest to time: to, for, the, in, both, and, was, another,
# Nearest to first: was, the, in, been, later, after, second, all,
# Nearest to at: in, both, as, a, the, of, and, bachelor,
# Nearest to versions: mk, xvii, part, dabney, version, janus, gradius, announcement,
# Nearest to shown: obvious, strikeout, explainable, hyperplane, sidewise, novelization, annoy, colonists,
# Nearest to nobel: prize, recipient, niacin, awarded, biochemist, adler, winners, tongan,
# Nearest to recorded: records, codifying, live, calibration, original, pseudalopex, eponymous, redford,
# Nearest to square: courtyards, busts, kilometre, expressway, shangri, underground, connery, yoshitaka,
# Nearest to ocean: shortwave, intelsat, emirate, indian, intersputnik, capeverdean, strait, radiotelephone,
# Nearest to rise: shingon, telecommunication, evident, tailback, frankish, reminiscent, swath, nostalgic,
# Nearest to channel: television, cytokinesis, ket, timestamp, encrypted, ctv, tromelin, pbs,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7102 0.3277 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7601 0.3296 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.7994 0.3247 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7408 0.3262 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7449 0.3277 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8645 0.3293 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.7463 0.3290 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7431 0.3321 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.7677 0.3323 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.7863 0.3244 sec/batch
# Nearest to known: is, name, while, adoption, used, as, whose, usages,
# Nearest to see: list, of, for, external, links, a, also, many,
# Nearest to three: two, one, four, seven, zero, five, eight, six,
# Nearest to when: to, with, the, then, been, in, was, learnt,
# Nearest to such: of, as, and, also, a, is, the, most,
# Nearest to time: for, to, both, the, in, was, and, another,
# Nearest to first: was, the, in, which, been, after, later, second,
# Nearest to at: both, in, a, as, the, of, francium, dq,
# Nearest to versions: mk, part, xvii, dabney, version, gradius, adsorbed, janus,
# Nearest to shown: obvious, annoy, explainable, strikeout, printmaking, recur, novelization, ideation,
# Nearest to nobel: prize, recipient, awarded, niacin, biochemist, adler, winners, laureate,
# Nearest to recorded: records, codifying, live, eponymous, calibration, pseudalopex, flicks, cremated,
# Nearest to square: courtyards, connery, shangri, busts, yoshitaka, underground, expressway, kilometre,
# Nearest to ocean: shortwave, intelsat, emirate, capeverdean, intersputnik, indian, fetched, radiotelephone,
# Nearest to rise: shingon, telecommunication, evident, tailback, nostalgic, frankish, swath, apostate,
# Nearest to channel: television, ket, cytokinesis, timestamp, ctv, encrypted, tromelin, pbs,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8108 0.3324 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.7881 0.3320 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7817 0.3314 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.7496 0.3348 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8142 0.3399 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8192 0.3331 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.7699 0.3355 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.7866 0.3355 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7543 0.3361 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.6978 0.3393 sec/batch
# Nearest to known: is, while, name, adoption, in, throughout, as, refers,
# Nearest to see: list, of, links, external, for, also, a, many,
# Nearest to three: one, two, four, five, seven, zero, eight, six,
# Nearest to when: to, in, with, the, then, been, of, which,
# Nearest to such: as, of, and, most, is, also, the, a,
# Nearest to time: for, to, the, both, in, and, years, was,
# Nearest to first: was, in, the, been, later, after, which, introduced,
# Nearest to at: in, both, of, a, the, from, as, to,
# Nearest to versions: mk, dabney, gradius, version, xvii, part, adsorbed, qmail,
# Nearest to shown: obvious, annoy, strikeout, novelization, explainable, printmaking, colonists, sidewise,
# Nearest to nobel: prize, awarded, recipient, niacin, winners, biochemist, adler, tongan,
# Nearest to recorded: codifying, records, calibration, live, eponymous, pseudalopex, redford, oxfordshire,
# Nearest to square: courtyards, shangri, connery, yoshitaka, busts, underground, expressway, kilometre,
# Nearest to ocean: shortwave, intelsat, indian, intersputnik, emirate, strait, eutelsat, radiotelephone,
# Nearest to rise: shingon, telecommunication, frankish, evident, become, reminiscent, gab, nostalgic,
# Nearest to channel: ket, television, timestamp, cytokinesis, encrypted, ctv, pbs, hereby,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8324 0.3433 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7959 0.3388 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9228 0.3382 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8369 0.3407 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8404 0.3384 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.7607 0.3395 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7055 0.3378 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.7593 0.3362 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.6969 0.3385 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8133 0.3419 sec/batch
# Nearest to known: is, adoption, while, name, as, refers, usages, whose,
# Nearest to see: list, of, links, external, also, for, article, references,
# Nearest to three: two, one, four, zero, five, seven, eight, six,
# Nearest to when: to, been, with, in, the, was, then, learnt,
# Nearest to such: as, and, of, most, a, is, the, also,
# Nearest to time: for, to, the, years, was, in, both, until,
# Nearest to first: was, in, the, after, later, been, introduced, second,
# Nearest to at: in, both, the, of, a, from, as, graduation,
# Nearest to versions: mk, part, dabney, xvii, gradius, adsorbed, qmail, version,
# Nearest to shown: obvious, annoy, strikeout, recur, ddd, sidewise, explainable, leventhal,
# Nearest to nobel: prize, recipient, awarded, niacin, biochemist, laureate, adler, physiology,
# Nearest to recorded: records, live, codifying, eponymous, calibration, pseudalopex, cremated, redford,
# Nearest to square: courtyards, connery, shangri, yoshitaka, busts, underground, expressway, sagrada,
# Nearest to ocean: shortwave, intelsat, intersputnik, emirate, indian, radiotelephone, eutelsat, capeverdean,
# Nearest to rise: shingon, evident, telecommunication, become, gab, frankish, april, hydrology,
# Nearest to channel: ket, timestamp, ctv, cytokinesis, encrypted, television, tromelin, hereby,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.7887 0.3431 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.7988 0.3437 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
